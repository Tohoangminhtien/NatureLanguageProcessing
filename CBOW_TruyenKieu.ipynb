# %% [markdown]
# ## 1. Tải dữ liệu

# %%
# !wget --no-check-certificate \
    https://gist.githubusercontent.com/khacanh/4c4662fa226db87a4664dfc2f70bc63e/raw/5d8a1d890c73a1e92e6898137db28f3dc0676975/kieu.txt \
    -O ./kieu.txt
# Out:
# --2023-03-26 03:41:05--  https://gist.githubusercontent.com/khacanh/4c4662fa226db87a4664dfc2f70bc63e/raw/5d8a1d890c73a1e92e6898137db28f3dc0676975/kieu.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 135832 (133K) [text/plain]
# Saving to: ‘./kieu.txt’
#
# ./kieu.txt          100%[===================>] 132.65K  --.-KB/s    in 0.002s
#
# 2023-03-26 03:41:05 (53.2 MB/s) - ‘./kieu.txt’ saved [135832/135832]

# %% [markdown]
# Load các dòng thơ

# %%
corpus = []
f = open("kieu.txt", "r")
for line in f:
  corpus.append(line)

# %%
len(corpus)
# Out:
# 3254

# %%
corpus = corpus[:500]

# %% [markdown]
# Kiểm tra các dòng thơ

# %%
corpus
# Out:
# ['Trăm năm trong cõi người ta,\n',
#  'Chữ tài chữ mệnh khéo là ghét nhau.\n',
#  'Trải qua một cuộc bể dâu,\n',
#  'Những điều trông thấy mà đau đớn lòng.\n',
#  'Lạ gì bỉ sắc tư phong,\n',
#  'Trời xanh quen thói má hồng đánh ghen.\n',
#  'Cảo thơm lần giỞ trước đèn,\n',
#  'Phong tình có lục còn truyền sử xanh.\n',
#  'Rằng năm Gia Tĩnh triều Minh,\n',
#  'Bốn phương phẳng lặng, hai kinh vững vàng.\n',
#  'Có nhà viên ngoại họ Vương,\n',
#  'Gia tư nghĩ cũng thường thường bực trung.\n',
#  'Một trai con thứ rốt lòng,\n',
#  'Vương Quan là chữ, nối dòng nho gia.\n',
#  'Đầu lòng hai ả tố nga,\n',
#  'Thúy Kiều là chị, em là Thúy Vân.\n',
#  'Mai cốt cách, tuyết tinh thần,\n',
#  'Một người một vẻ, mười phân vẹn mười.\n',
#  'Vân xem trang trọng khác vời,\n',
#  'Khuôn trăng đầy đặn, nét ngài nỞ nang.\n',
#  'Hoa cười ngọc thốt đoan trang,\n',
#  'Mây thua nước tóc, tuyết nhường màu da.\n',
#  'Kiều càng sắc sảo, mặn mà,\n',
#  'So bề tài, sắc, lại là phần hơn.\n',
#  'Làn thu thủy, nét xuân sơn,\n',
#  'Hoa ghen thua thắm, liễu hờn kém xanh.\n',
#  'Một, hai nghiêng nước nghiêng thành,\n',
#  'Sắc đành đòi một, tài đành họa hai.\n',
#  'Thông minh vốn sẵn tư trời,\n',
#  'Pha nghề thi họa, đủ mùi ca ngâm.\n',
#  'Cung thương làu bậc ngũ âm,\n',
#  'Nghề riêng ăn đứt Hồ cầm một trương.\n',
#  'Khúc nhà tay lựa nên chương,\n',
#  'Một thiên bạc mệnh, lại càng não nhân.\n',
#  'Phong lưu rất mực hồng quần,\n',
#  'Xuân xanh sấp xỉ tới tuần cập kê\n',
#  'Êm đềm trướng rủ màn che,\n',
#  'Tường đông ong bướm đi về mặc ai.\n',
#  'Ngày xuân con én đưa thoi,\n',
#  'Thiều quang chín chục đã ngoài sáu mươi.\n',
#  'Cỏ non xanh tận chân trời,\n',
#  'Cành lê trắng điểm một vài bông hoa.\n',
#  'Thanh minh trong tiết tháng ba,\n',
#  'Lễ là tảo mộ, hội là đạp Thanh.\n',
#  'Gần xa nô nức yến anh,\n',
#  'Chị em sắm sửa bộ hành chơi xuân.\n',
#  'Dập dìu tài tử, giai nhân,\n',
#  'Ngựa xe như nước áo quần như nêm.\n',
#  'Ngổn ngang gò đống kéo lên,\n',
#  'Thoi vàng vó rắc tro tiền giấy bay.\n',
#  'Tà tà bóng ngả về tây,\n',
#  'Chị em thơ thẩn dan tay ra về.\n',
#  'Bước dần theo ngọn tiểu khê,\n',
#  'Lần xem phong cảnh có bề thanh thanh.\n',
#  'Nao nao dòng nước uốn quanh,\n',
#  'Dịp cầu nho nhỏ cuối ghềnh bắc ngang.\n',
#  'Sè sè nấm đất bên đàng,\n',
#  'Dàu dàu ngọn cỏ nửa vàng nửa xanh.\n',
#  'Rằng: Sao trong tiết thanh minh,\n',
#  'Mà đây hương khói vắng tanh thế mà?\n',
#  'Vương Quan mới dẫn gần xa:\n',
#  'Đạm Tiên nàng ấy xưa là ca nhi.\n',
#  'Nổi danh tài sắc một thì,\n',
#  'Xôn xao ngoài cửa hiếm gì yến anh.\n',
#  'Kiếp hồng nhan có mong manh,\n',
#  'Nửa chừng xuân thoắt gãy cành thiên hương.\n',
#  'Có người khách Ở viễn phương,\n',
#  'Xa nghe cũng nức tiếng nàng tìm chơi.\n',
#  'Thuyền tình vừa ghé tới nơi,\n',
#  'Thì đà trâm gẫy bình rơi bao giờ.\n',
#  'Buồng không lạnh ngắt như tờ,\n',
#  'Dấu xe ngựa đã rêu lờ mờ xanh.\n',
#  'Khóc than khôn xiết sự tình,\n',
#  'Khéo vô duyên ấy là mình với ta.\n',
#  'Đã không duyên trước chăng mà,\n',
#  'Thì chi chút ước gọi là duyên sau.\n',
#  'Sắm xanh nếp tử xe trâu\n',
#  'Vùi nông một nấm mặc dầu cỏ hoa.\n',
#  'Trải bao thỏ lặn ác tà,\n',
#  'Ấy mồ vô chủ, ai mà viếng thăm!\n',
#  'Lòng đâu sẵn mối thương tâm,\n',
#  'Thoắt nghe Kiều đã đầm đầm châu sa.\n',
#  'Đau đớn thay phận đàn bà!\n',
#  'Lời rằng bạc mệnh cũng là lời chung.\n',
#  'Phũ phàng chi bấy hoá công,\n',
#  'Ngày xanh mòn mỏi má hồng phôi pha.\n',
#  'Sống làm vợ khắp người ta,\n',
#  'Khéo thay thác xuống làm ma không chồng.\n',
#  'Nào người phượng chạ loan chung,\n',
#  'Nào người tích lục tham hồng là ai?\n',
#  'Đã không kẻ đoái người hoài,\n',
#  'Sẵn đây ta kiếm một vài nén hương.\n',
#  'Gọi là gặp gỡ giữa đường,\n',
#  'Họa là người dưới suối vàng biết cho.\n',
#  'Lầm rầm khấn khứa nhỏ to,\n',
#  'Sụp ngồi vài gật trước mồ bước ra.\n',
#  'Một vùng cỏ áy bóng tà,\n',
#  'Gió hiu hiu thổi một vài bông lau.\n',
#  'Rút trâm sẵn giắt mái đầu,\n',
#  'Vạch da cây vịnh bốn câu ba vần.\n',
#  'Lại càng mê mẩn tâm thần\n',
#  'Lại càng đứng lặng tần ngần chẳng ra.\n',
#  'Lại càng ủ dột nét hoa,\n',
#  'Sầu tuôn đứt nối, châu sa vắn dài.\n',
#  'Vân rằng: Chị cũng nực cười,\n',
#  'Khéo dư nước mắt khóc người đời xưa.\n',
#  'Rằng: Hồng nhan tự thuỞ xưa,\n',
#  'Cái điều bạc mệnh có chừa ai đâu?\n',
#  'Nỗi niềm tưỞng đến mà đau,\n',
#  'Thấy người nằm đó biết sau thế nào?\n',
#  'Quan rằng: Chị nói hay sao,\n',
#  'Một lời là một vận vào khó nghe.\n',
#  'Ở đây âm khí nặng nề,\n',
#  'Bóng chiều đã ngả dậm về còn xa.\n',
#  'Kiều rằng: Những đấng tài hoa,\n',
#  'Thác là thể phách, còn là tinh anh,\n',
#  'Dễ hay tình lại gặp tình,\n',
#  'Chờ xem ắt thấy hiển linh bây giờ.\n',
#  'Một lời nói chửa kịp thưa,\n',
#  'Thoắt đâu trận gió cuốn cờ đến ngay.\n',
#  'Ào ào đổ lộc rung cây,\n',
#  'Ở trong dường có hương bay ít nhiều.\n',
#  'Đè chừng ngọn gió lần theo,\n',
#  'Dấu giày từng bước in rêu rành rành.\n',
#  'Mắt nhìn ai nấy đều kinh,\n',
#  'Nàng rằng: Này thực tinh thành chẳng xa.\n',
#  'Hữu tình ta lại gặp ta,\n',
#  'Chớ nề u hiển mới là chị em.\n',
#  'Đã lòng hiển hiện cho xem,\n',
#  'Tạ lòng nàng lại nối thêm vài lời.\n',
#  'Lòng thơ lai láng bồi hồi,\n',
#  'Gốc cây lại vạch một bài cổ thi.\n',
#  'Dùng dằng nửa Ở nửa về,\n',
#  'Nhạc vàng đâu đã tiếng nghe gần gần.\n',
#  'Trông chừng thấy một văn nhân,\n',
#  'Lỏng buông tay khấu bước lần dặm băng.\n',
#  'Đề huề lưng túi gió trăng,\n',
#  'Sau chân theo một vài thằng con con.\n',
#  'Tuyết in sắc ngựa câu giòn,\n',
#  'Cỏ pha màu áo nhuộm non da trời.\n',
#  'Nẻo xa mới tỏ mặt người,\n',
#  'Khách đà xuống ngựa tới nơi tự tình.\n',
#  'Hài văn lần bước dặm xanh,\n',
#  'Một vùng như thể cây quỳnh cành dao.\n',
#  'Chàng Vương quen mặt ra chào,\n',
#  'Hai Kiều e lệ nép vào dưới hoa.\n',
#  'Nguyên người quanh quất đâu xa,\n',
#  'Họ Kim tên Trọng vốn nhà trâm anh.\n',
#  'Nền phú hậu, bậc tài danh,\n',
#  'Văn chương nết đất, thông minh tính trời.\n',
#  'Phong tư tài mạo tót vời,\n',
#  'Vào trong phong nhã, ra ngoài hào hoa.\n',
#  'Chung quanh vẫn đất nước nhà,\n',
#  'Với Vương Quan trước vẫn là đồng thân.\n',
#  'Vẫn nghe thơm nức hương lân,\n',
#  'Một nền đồng Tước khoá xuân hai Kiều.\n',
#  'Nước non cách mấy buồng thêu,\n',
#  'Những là trộm nhớ thầm yêu chốc mòng.\n',
#  'May thay giải cấu tương phùng,\n',
#  'Gặp tuần đố lá thoả lòng tìm hoa.\n',
#  'Bóng hồng nhác thấy nẻo xa,\n',
#  'Xuân lan thu cúc mặn mà cả hai.\n',
#  'Người quốc sắc, kẻ thiên tài,\n',
#  'Tình trong như đã, mặt ngoài còn e.\n',
#  'Chập chờn cơn tỉnh cơn mê.\n',
#  'Rốn ngồi chẳng tiện, dứt về chỉn khôn.\n',
#  'Bóng tà như giục cơn buồn,\n',
#  'Khách đà lên ngựa, người còn nghé theo.\n',
#  'Dưới cầu nước chảy trong veo,\n',
#  'Bên cầu tơ liễu bóng chiều thướt tha.\n',
#  'Kiều từ trỞ gót trướng hoa,\n',
#  'Mặt trời gác núi chiêng đà thu không.\n',
#  'Gương nga chênh chếch dòm song,\n',
#  'Vàng gieo ngấn nước, cây lồng bóng sân.\n',
#  'Hải đường lả ngọn đông lân,\n',
#  'Giọt sương gieo nặng cành xuân la đà.\n',
#  'Một mình lặng ngắm bóng nga,\n',
#  'Rộn đường gần với nỗi xa bời bời:\n',
#  'Người mà đến thế thì thôi,\n',
#  'Đời phồn hoa cũng là đời bỏ đi!\n',
#  'Người đâu gặp gỡ làm chi,\n',
#  'Trăm năm biết có duyên gì hay không?\n',
#  'Ngổn ngang trăm mối bên lòng,\n',
#  'Nên câu tuyệt diệu ngụ trong tính tình.\n',
#  'Chênh chênh bóng nguyệt xế mành,\n',
#  'Tựa nương bên triện một mình thiu thiu.\n',
#  'Thoắt đâu thấy một tiểu kiều,\n',
#  'Có chiều thanh vận, có chiều thanh tân.\n',
#  'Sương in mặt, tuyết pha thân,\n',
#  'Sen vàng lãng đãng như gần như xa.\n',
#  'Chào mừng đón hỏi dò la:\n',
#  'Đào nguyên lạc lối đâu mà đến đây?\n',
#  'Thưa rằng: Thanh khí xưa nay,\n',
#  'Mới cùng nhau lúc ban ngày đã quên.\n',
#  'Hàn gia Ở mé tây thiên,\n',
#  'Dưới dòng nước chảy bên trên có cầu.\n',
#  'Mấy lòng hạ cố đến nhau,\n',
#  'Mấy lời hạ tứ ném châu gieo vàng.\n',
#  'Vâng trình hội chủ xem tường,\n',
#  'Mà sao trong sổ đoạn trường có tên.\n',
#  'Âu đành quả kiếp nhân duyên,\n',
#  'Cùng người một hội, một thuyền đâu xa!\n',
#  'Này mười bài mới mới ra,\n',
#  'Câu thần lại mượn bút hoa vẽ vời.\n',
#  'Kiều vâng lĩnh ý đề bài,\n',
#  'Tay tiên một vẫy đủ mười khúc ngâm.\n',
#  'Xem thơ nức nỞ khen thầm:\n',
#  'Giá đành tú khẩu cẩm tâm khác thường\n',
#  'Ví đem vào tập đoạn Trường\n',
#  'Thì treo giải nhất chi nhường cho ai.\n',
#  'Thềm hoa khách đã trỞ hài,\n',
#  'Nàng còn cầm lại một hai tự tình.\n',
#  'Gió đâu xịch bức mành mành,\n',
#  'Tỉnh ra mới biết rằng mình chiêm bao.\n',
#  'Trông theo nào thấy đâu nào\n',
#  'Hương thừa dường hãy ra vào đâu đây.\n',
#  'Một mình lưỡng lự canh chầy,\n',
#  'Đường xa nghĩ nỗi sau này mà kinh.\n',
#  'Hoa trôi bèo dạt đã đành,\n',
#  'Biết duyên mình, biết phận mình thế thôi!\n',
#  'Nỗi riêng lớp lớp sóng dồi,\n',
#  'Nghĩ đòi cơn lại sụt sùi đòi cơn.\n',
#  'Giọng Kiều rền rĩ trướng loan,\n',
#  'Nhà Huyên chợt tỉnh hỏi: Cơn cớ gì?\n',
#  'Cớ sao trằn trọc canh khuya,\n',
#  'Màu hoa lê hãy dầm dề giọt mưa?\n',
#  'Thưa rằng: Chút phận ngây thơ,\n',
#  'Dưỡng sinh đôi nợ tóc tơ chưa đền.\n',
#  'Buổi ngày chơi mả đạm Tiên,\n',
#  'Nhắp đi thoắt thấy ứng liền chiêm bao.\n',
#  'Đoạn trường là số thế nào,\n',
#  'Bài ra thế ấy, vịnh vào thế kia.\n',
#  'Cứ trong mộng triệu mà suy,\n',
#  'Phận con thôi có ra gì mai sau!\n',
#  'Dạy rằng: Mộng triệu cớ đâu,\n',
#  'Bỗng không mua não chuốc sầu nghĩ nao.\n',
#  'Vâng lời khuyên giải thấp cao,\n',
#  'Chưa xong điều nghĩ đã dào mạch Tương.\n',
#  'Ngoài song thỏ thẻ oanh vàng,\n',
#  'Nách tường bông liễu bay ngang trước mành.\n',
#  'Hiên tà gác bóng chênh chênh,\n',
#  'Nỗi riêng, riêng trạnh tấc riêng một mình.\n',
#  'Cho hay là thói hữu tình,\n',
#  'Đố ai gỡ mối tơ mành cho xong.\n',
#  'Chàng Kim từ lại thư song,\n',
#  'Nỗi nàng canh cánh bên lòng biếng khuây.\n',
#  'Sầu đong càng lắc càng đầy,\n',
#  'Ba thu dồn lại một ngày dài ghê.\n',
#  'Mây Tần khóa kín song the,\n',
#  'Bụi hồng lẽo đẽo đi về chiêm bao.\n',
#  'Tuần trăng khuyết, đĩa dầu hao,\n',
#  'Mặt mơ tưỞng mặt, lòng ngao ngán lòng.\n',
#  'Buồng văn hơi giá như đồng,\n',
#  'Trúc se ngọn thỏ, tơ chùng phím loan.\n',
#  'Mành Tương phất phất gió đàn,\n',
#  'Hương gây mùi nhớ, trà khan giọng tình.\n',
#  'Vì chăng duyên nợ ba sinh,\n',
#  'Thì chi đem thói khuynh thành trêu ngươi.\n',
#  'Bâng khuâng nhớ cảnh, nhớ người,\n',
#  'Nhớ nơi kỳ ngộ vội dời chân đi.\n',
#  'Một vùng cỏ mọc xanh rì,\n',
#  'Nước ngâm trong vắt, thấy gì nữa đâu!\n',
#  'Gió chiều như gợi cơn sầu,\n',
#  'Vi lô hiu hắt như màu khảy trêu.\n',
#  'Nghề riêng nhớ ít tưỞng nhiều,\n',
#  'Xăm xăm đè nẻo Lam Kiều lần sang.\n',
#  'Thâm nghiêm kín cổng cao tường,\n',
#  'Cạn dòng lá thắm dứt đường chim xanh.\n',
#  'Lơ thơ tơ liễu buông mành,\n',
#  'Con oanh học nói trên cành mỉa mai.\n',
#  'Mấy lần cửa đóng then cài,\n',
#  'Đầy thềm hoa rụng, biết người Ở đâu?\n',
#  'Tần ngần đứng suốt giờ lâu,\n',
#  'Dạo quanh chợt thấy mái sau có nhà.\n',
#  'Là nhà Ngô Việt thương gia,\n',
#  'Buồng không để đó người xa chưa về.\n',
#  'Lấy điều du học hỏi thuê,\n',
#  'Túi đàn cặp sách đề huề dọn sang.\n',
#  'Có cây, có đá sẵn sàng,\n',
#  'Có hiên Lãm thúy, nét vàng chưa phai.\n',
#  'Mừng thầm chốn ấy chữ bài,\n',
#  'Ba sinh âu hẳn duyên trời chi đây.\n',
#  'Song hồ nửa khép cánh mây,\n',
#  'Tường đông ghé mắt ngày ngày hằng trông.\n',
#  'Tấc gang động khóa nguồn phong,\n',
#  'Tịt mù nào thấy bóng hồng vào ra.\n',
#  'Nhẫn từ quán khách lân la,\n',
#  'Tuần trăng thấm thoắt nay đà thèm hai.\n',
#  'Cách tường phải buổi êm trời,\n',
#  'Dưới đào dường có bóng người thướt tha.\n',
#  'Buông cầm xốc áo vội ra,\n',
#  'Hương còn thơm nức, người đà vắng tanh.\n',
#  'Lần theo tường gấm dạo quanh,\n',
#  'Trên đào nhác thấy một cành kim thoa.\n',
#  'Giơ tay với lấy về nhà:\n',
#  'Này trong khuê các đâu mà đến đây?\n',
#  'Ngẫm âu người ấy báu này,\n',
#  'Chẳng duyên chưa dễ vào tay ai cầm!\n',
#  'Liền tay ngắm nghía biếng nằm,\n',
#  'Hãy còn thoang thoảng hương trầm chưa phai.\n',
#  'Tan sương đã thấy bóng người,\n',
#  'Quanh tường ra ý tìm tòi ngẩn ngơ.\n',
#  'Sinh đà có ý đợi chờ,\n',
#  'Cách tường lên tiếng xa đưa ướm lòng:\n',
#  'Thoa này bắt được hư không,\n',
#  'Biết đâu Hợp Phố mà mong châu về?\n',
#  'Tiếng Kiều nghe lọt bên kia:\n',
#  '“Ơn lòng quân tử sá gì của rơi,\n',
#  'Chiếc thoa nào của mấy mươi\n',
#  'Mà lòng trọng nghĩa khinh tài xiết bao!”\n',
#  'Sinh rằng: “Lân lý ra vào,\n',
#  'Gần đây nào phải người nào xa xôi,\n',
#  'Rày nhờ được chút thơm rơi\n',
#  'Kể đà thiểu não lòng người bấy nay!\n',
#  'Bấy lâu mới được một ngày,\n',
#  'Dừng chân gạn chút niềm tây gọi là”\n',
#  'Vội về thêm lấy của nhà,\n',
#  'Khuyến vàng đôi chiếc, khăn là một vuông\n',
#  'Thang mây qua bước ngọn tường,\n',
#  'Phải người hôm nọ rõ ràng chẳng như.\n',
#  'Sượng sùng giữ ý rụt rè,\n',
#  'Kẻ nhìn rõ mặt, người e cúi đầu\n',
#  'Rằng: “Từ ngẫu nhỉ gặp nhau\n',
#  'Thầm trông trộm nhớ bấy lâu đã chồn,\n',
#  'Xương mai tính đã rũ mòn\n',
#  'Lần lừa ai biết hãy còn hôm nay!\n',
#  'Vuông tròn nhờ cậy cung mây\n',
#  'Trần trần một phận ấp cây đã liều!\n',
#  'Tiện đây xin một đôi điều\n',
#  'Đài gương soi đến dấu bèo cho chăng?”\n',
#  'Ngần ngừ nàng mới thưa rằng:\n',
#  '“Thói nhà băng tuyết, chất hằng phỉ phong\n',
#  'Dù khi lá thắm chỉ hồng\n',
#  'Nên chăng thì cũng tại lòng mẹ cha\n',
#  'Nặng lòng xót liễu vì hoa\n',
#  'Trẻ thơ đã biết đâu mà dám thưa!”\n',
#  'Sinh rằng: Rày gió mai mưa,\n',
#  'Ngày xuân đã dễ tình cờ mấy khi!\n',
#  'Dù chăng xét tấm tình si,\n',
#  'Thiệt đây mà có ích gì cho ai?\n',
#  'Chút chi gắn bó một hai,\n',
#  'Cho đành rồi sẽ liệu bài mối manh,\n',
#  'Khuôn thiên dù phụ tấc thành,\n',
#  'Cũng liều bỏ quá xuân xanh một đời,\n',
#  'Lượng xuân dù quyết hẹp hòi\n',
#  'Công đeo đuổi chẳng thiệt thòi lắm ru?”\n',
#  'Lặng nghe lời nói như ru,\n',
#  'Chiều xuân dễ khiến nét thu ngại ngùng\n',
#  'Rằng: “Trong buổi mới lạ lùng,\n',
#  'Nể lòng có lẽ, cầm lòng cho đang?\n',
#  'Đã lòng quân tử đa mang\n',
#  'Một lời vâng tạc đá vàng thủy chung!”\n',
#  'Được lời như cỞi tấm lòng,\n',
#  'GiỞ kim thoa với khăn hồng trao tay,\n',
#  'Rằng: “Trăm năm cũng từ đây,\n',
#  'Của tin gọi một chút này làm ghi”.\n',
#  'Sẵn tay bả quạt hoa quì,\n',
#  'Với cành thoa ấy tức thì đổi trao.\n',
#  'Một lời gắn bó tất giao\n',
#  'Mé sau nhường có xôn xao tiếng người,\n',
#  'Vội vàng lá rụng hoa rơi\n',
#  'Chàng về viện sách, nàng dời lầu trang.\n',
#  'Từ phen đá biết tuổi vàng,\n',
#  'Tình càng thấm thía lòng càng ngẩn ngơ.\n',
#  'Sông Tương một dải nông sờ,\n',
#  'Bên trông đầu nọ, bên chờ cuối kia\n',
#  'Một tuồng tuyết chỞ  sương che\n',
#  'Tin xuân đâu dễ đi về cho năng\n',
#  'Lần lần ngày gió đêm trăng\n',
#  'Thưa hồng rậm lục đã chừng xuân qua.\n',
#  'Ngày vừa sinh nhật ngoại gia,\n',
#  'Trên hai đường, dưới nữa là hai em,\n',
#  'Tưng bừng sắm sửa áo xiêm,\n',
#  'Biện dâng một lễ, xa đem tấc thành.\n',
#  'Nhà hương thanh vắng một mình\n',
#  'Ngẫm cơ hội ngộ đã dành hôm nay.\n',
#  'Thời trân thức thức sẵn bày,\n',
#  'Gót sen thoăn thoắt dạo ngay mé tường.\n',
#  'Cách hoa sẽ dặng tiếng vàng,\n',
#  'Dưới hoa đã thấy có chàng đứng trông:\n',
#  '“Trách lòng hờ hững với lòng,\n',
#  'Lửa hương chốc để lạnh lùng bấy lâu,\n',
#  'Những là đắp nhớ đổi sầu,\n',
#  'Tuyết sương nhuốm nửa mái đầu hoa râm”.\n',
#  'Nàng rằng: “Gió bắt mưa cầm,\n',
#  'Đã cam tệ với tri âm bấy chầy,\n',
#  'Vắng nhà được buổi hôm nay,\n',
#  'Lấy lòng gọi chút ra đây tạ lòng\n',
#  'Lần theo núi giả đi vòng,\n',
#  'Cuối tường nhường có nẻo thông mới rào,\n',
#  'Xắn tay mỞ khóa động đào,\n',
#  'Rẽ mây trông tỏ lối vào Thiên Thai.\n',
#  'Mặt nhìn mặt, càng thêm tươi,\n',
#  'Bên lời vạn phúc, bên lời hàn huyên\n',
#  'Sánh vai về chốn tư hiên,\n',
#  'Góp lời phong nguyệt, nặng nguyền non sông.\n',
#  'Trên yên bút giá thi đồng,\n',
#  'Đạm thanh một bức trang tùng treo trên.\n',
#  'Phong sương được vẻ thiên nhiên,\n',
#  'Mặn khen nét bút càng nhìn càng tươi,\n',
#  'Sinh rằng: “Phác họa vừa rồi,\n',
#  'Phẩm đề xin một vài lời thêm hoa!”\n',
#  'Tay tiên gió táp mưa sa\n',
#  'Khoảng trên dừng bút thảo và bốn câu.\n',
#  'Khen: “Tài nhả ngọc, phun châu,\n',
#  'Nàng Ban ả Tạ cũng đâu thế này!\n',
#  'Kiếp tu xưa ví chưa dày,\n',
#  'Phúc nào nhắc được giá này cho ngang!\n',
#  'Nàng rằng: Trộm liếc dung quang,\n',
#  'Chẳng sân bội ngọc cũng phường kim môn.\n',
#  'Nghĩ mình phận mỏng cánh chuồn,\n',
#  'Khuôn xanh biết có vuông tròn mà hay?\n',
#  'Nhớ từ năm hãy thơ ngây,\n',
#  'Có người tướng sĩ đoán ngay một lời:\n',
#  'Anh hoa phát tiết ra ngoài,\n',
#  'Nghìn thu bạc mệnh một đời tài hoa.\n',
#  'Trông người lại ngẫm đến ta,\n',
#  "Một dầy một mỏng biết là có nên ?'\n",
#  'Sinh rằng: Giải cấu là duyên,\n',
#  'Xưa nay nhân định thắng nhiên cũng nhiều.\n',
#  'Ví dù giải kết đến điều,\n',
#  'Thì đem vàng đá mà liều với thân!\n',
#  'Đủ điều trung khúc ân cần,\n',
#  'Lòng xuân phơi phới chén xuân tàng tàng.\n',
#  'Ngày vui ngắn chẳng đầy gang,\n',
#  'Trông ra ác đã ngậm gương non đoài.\n',
#  'Vắng nhà chẳng tiện ngồi dai,\n',
#  'Giã chàng nàng mới kíp dời song sa.\n',
#  'Đến nhà vừa thấy tin nhà,\n',
#  'Hai thân còn dỞ tiệc hoa chưa về.\n',
#  'Cửa ngoài vội rủ rèm the,\n',
#  'Xăm xăm băng lối vườn khuya một mình.\n',
#  'Nhặt thưa gương giọi đầu cành,\n',
#  'Ngọn đèn trông lọt trướng huỳnh hắt hiu.\n',
#  'Sinh vừa tựa án thiu thiu,\n',
#  'DỞ chiều như tỉnh dỞ chiều như mê.\n',
#  'Tiếng sen sẽ động giấc hòe,\n',
#  'Bóng trăng đã xế hoa lê lại gần.\n',
#  'Bâng khuâng đỉnh Giáp non Thần,\n',
#  'Còn ngờ giấc mộng đêm xuân mơ màng.\n',
#  'Nàng rằng: Khoảng vắng đêm trường,\n',
#  'Vì hoa nên phải đánh đường tìm hoa.\n',
#  'Bây giờ rõ mặt đôi ta,\n',
#  'Biết đâu rồi nữa chẳng là chiêm bao?\n',
#  'Vội mừng làm lễ rước vào,\n',
#  'Đài sen nối sáp song đào thêm hương.\n',
#  'Tiên thề cùng thảo một chương,\n',
#  'Tóc mây một món dao vàng chia đôi.\n',
#  'Vầng trăng vằng vặc giữa trời,\n',
#  'Đinh ninh hai mặt một lời song song.\n',
#  'Tóc tơ căn vặn tấc lòng,\n',
#  'Trăm năm tạc một chữ đồng đến xương.\n',
#  'Chén hà sánh giọng quỳnh tương,\n',
#  'Dải là hương lộn bình gương bóng lồng.\n',
#  'Sinh rằng: Gió mát trăng trong,\n',
#  'Bấy lâu nay một chút lòng chưa cam.\n',
#  'Chày sương chưa nện cầu Lam,\n',
#  'Sợ lần khân quá ra sàm sỡ chăng?\n',
#  'Nàng rằng: Hồng diệp xích thằng,\n',
#  'Một lời cũng đã tiếng rằng tương tri.\n',
#  'Đừng điều nguyệt nọ hoa kia.\n',
#  'Ngoài ra ai lại tiếc gì với ai.\n',
#  'Rằng: Nghe nổi tiếng cầm đài,\n',
#  'Nước non luống những lắng tai Chung Kỳ.\n',
#  'Thưa rằng: Tiện kỹ sá chi,\n',
#  'Đã lòng dạy đến dạy thì phải vâng.\n',
#  'Hiên sau treo sẵn cầm trăng,\n',
#  'Vội vàng Sinh đã tay nâng ngang mày.\n',
#  'Nàng rằng: Nghề mọn riêng tay,\n',
#  'Làm chi cho bận lòng này lắm thân!\n',
#  'So dần dây vũ dây văn,\n',
#  'Bốn dây to nhỏ theo vần cung thương.\n',
#  'Khúc đâu Hán SỞ chiến trường,\n',
#  'Nghe ra tiếng sắt tiếng vàng chen nhau.\n',
#  'Khúc đâu Tư mã Phượng cầu,\n',
#  'Nghe ra như oán như sầu phải chăng!\n',
#  'Kê Khang này khúc Quảng lăng,\n',
#  'Một rằng lưu thủy hai rằng hành vân.\n',
#  'Qua quan này khúc Chiêu Quân,\n',
#  'Nửa phần luyến chúa nửa phần tư gia.\n',
#  'Trong như tiếng hạc bay qua,\n',
#  'Đục như tiếng suối mới sa nửa vời.\n',
#  'Tiếng khoan như gió thoảng ngoài,\n',
#  'Tiếng mau sầm sập như trời đổ mưa.\n',
#  'Ngọn đèn khi tỏ khi mờ,\n',
#  'Khiến người ngồi đó cũng ngơ ngẩn sầu.\n',
#  'Khi tựa gối khi cúi đầu,\n',
#  'Khi vò chín khúc khi chau đôi mày.\n',
#  'Rằng: Hay thì thật là hay,\n',
#  'Nghe ra ngậm đắng nuốt cay thế nào!\n',
#  'Lựa chi những bậc tiêu tao,\n',
#  'Dột lòng mình cũng nao nao lòng người?\n',
#  'Rằng: Quen mất nết đi rồi,\n',
#  'Tẻ vui thôi cũng tính trời biết sao!\n',
#  'Lời vàng âm lĩnh ý cao,\n',
#  'Họa dần dần bớt chút nào được không.\n',
#  'Hoa hương càng tỏ thức hồng,\n',
#  'Đầu mày cuối mắt càng nồng tấm yêu.\n',
#  'Sóng tình dường đã xiêu xiêu,\n',
#  'Xem trong âu yếm có chiều lả lơi.\n']

# %% [markdown]
# ## 2. Xây dựng tokenizer

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
for i in range(len(corpus)):
  corpus[i] = text_to_word_sequence(corpus[i])

# %%
corpus
# Out:
# [['trăm', 'năm', 'trong', 'cõi', 'người', 'ta'],
#  ['chữ', 'tài', 'chữ', 'mệnh', 'khéo', 'là', 'ghét', 'nhau'],
#  ['trải', 'qua', 'một', 'cuộc', 'bể', 'dâu'],
#  ['những', 'điều', 'trông', 'thấy', 'mà', 'đau', 'đớn', 'lòng'],
#  ['lạ', 'gì', 'bỉ', 'sắc', 'tư', 'phong'],
#  ['trời', 'xanh', 'quen', 'thói', 'má', 'hồng', 'đánh', 'ghen'],
#  ['cảo', 'thơm', 'lần', 'giở', 'trước', 'đèn'],
#  ['phong', 'tình', 'có', 'lục', 'còn', 'truyền', 'sử', 'xanh'],
#  ['rằng', 'năm', 'gia', 'tĩnh', 'triều', 'minh'],
#  ['bốn', 'phương', 'phẳng', 'lặng', 'hai', 'kinh', 'vững', 'vàng'],
#  ['có', 'nhà', 'viên', 'ngoại', 'họ', 'vương'],
#  ['gia', 'tư', 'nghĩ', 'cũng', 'thường', 'thường', 'bực', 'trung'],
#  ['một', 'trai', 'con', 'thứ', 'rốt', 'lòng'],
#  ['vương', 'quan', 'là', 'chữ', 'nối', 'dòng', 'nho', 'gia'],
#  ['đầu', 'lòng', 'hai', 'ả', 'tố', 'nga'],
#  ['thúy', 'kiều', 'là', 'chị', 'em', 'là', 'thúy', 'vân'],
#  ['mai', 'cốt', 'cách', 'tuyết', 'tinh', 'thần'],
#  ['một', 'người', 'một', 'vẻ', 'mười', 'phân', 'vẹn', 'mười'],
#  ['vân', 'xem', 'trang', 'trọng', 'khác', 'vời'],
#  ['khuôn', 'trăng', 'đầy', 'đặn', 'nét', 'ngài', 'nở', 'nang'],
#  ['hoa', 'cười', 'ngọc', 'thốt', 'đoan', 'trang'],
#  ['mây', 'thua', 'nước', 'tóc', 'tuyết', 'nhường', 'màu', 'da'],
#  ['kiều', 'càng', 'sắc', 'sảo', 'mặn', 'mà'],
#  ['so', 'bề', 'tài', 'sắc', 'lại', 'là', 'phần', 'hơn'],
#  ['làn', 'thu', 'thủy', 'nét', 'xuân', 'sơn'],
#  ['hoa', 'ghen', 'thua', 'thắm', 'liễu', 'hờn', 'kém', 'xanh'],
#  ['một', 'hai', 'nghiêng', 'nước', 'nghiêng', 'thành'],
#  ['sắc', 'đành', 'đòi', 'một', 'tài', 'đành', 'họa', 'hai'],
#  ['thông', 'minh', 'vốn', 'sẵn', 'tư', 'trời'],
#  ['pha', 'nghề', 'thi', 'họa', 'đủ', 'mùi', 'ca', 'ngâm'],
#  ['cung', 'thương', 'làu', 'bậc', 'ngũ', 'âm'],
#  ['nghề', 'riêng', 'ăn', 'đứt', 'hồ', 'cầm', 'một', 'trương'],
#  ['khúc', 'nhà', 'tay', 'lựa', 'nên', 'chương'],
#  ['một', 'thiên', 'bạc', 'mệnh', 'lại', 'càng', 'não', 'nhân'],
#  ['phong', 'lưu', 'rất', 'mực', 'hồng', 'quần'],
#  ['xuân', 'xanh', 'sấp', 'xỉ', 'tới', 'tuần', 'cập', 'kê'],
#  ['êm', 'đềm', 'trướng', 'rủ', 'màn', 'che'],
#  ['tường', 'đông', 'ong', 'bướm', 'đi', 'về', 'mặc', 'ai'],
#  ['ngày', 'xuân', 'con', 'én', 'đưa', 'thoi'],
#  ['thiều', 'quang', 'chín', 'chục', 'đã', 'ngoài', 'sáu', 'mươi'],
#  ['cỏ', 'non', 'xanh', 'tận', 'chân', 'trời'],
#  ['cành', 'lê', 'trắng', 'điểm', 'một', 'vài', 'bông', 'hoa'],
#  ['thanh', 'minh', 'trong', 'tiết', 'tháng', 'ba'],
#  ['lễ', 'là', 'tảo', 'mộ', 'hội', 'là', 'đạp', 'thanh'],
#  ['gần', 'xa', 'nô', 'nức', 'yến', 'anh'],
#  ['chị', 'em', 'sắm', 'sửa', 'bộ', 'hành', 'chơi', 'xuân'],
#  ['dập', 'dìu', 'tài', 'tử', 'giai', 'nhân'],
#  ['ngựa', 'xe', 'như', 'nước', 'áo', 'quần', 'như', 'nêm'],
#  ['ngổn', 'ngang', 'gò', 'đống', 'kéo', 'lên'],
#  ['thoi', 'vàng', 'vó', 'rắc', 'tro', 'tiền', 'giấy', 'bay'],
#  ['tà', 'tà', 'bóng', 'ngả', 'về', 'tây'],
#  ['chị', 'em', 'thơ', 'thẩn', 'dan', 'tay', 'ra', 'về'],
#  ['bước', 'dần', 'theo', 'ngọn', 'tiểu', 'khê'],
#  ['lần', 'xem', 'phong', 'cảnh', 'có', 'bề', 'thanh', 'thanh'],
#  ['nao', 'nao', 'dòng', 'nước', 'uốn', 'quanh'],
#  ['dịp', 'cầu', 'nho', 'nhỏ', 'cuối', 'ghềnh', 'bắc', 'ngang'],
#  ['sè', 'sè', 'nấm', 'đất', 'bên', 'đàng'],
#  ['dàu', 'dàu', 'ngọn', 'cỏ', 'nửa', 'vàng', 'nửa', 'xanh'],
#  ['rằng', 'sao', 'trong', 'tiết', 'thanh', 'minh'],
#  ['mà', 'đây', 'hương', 'khói', 'vắng', 'tanh', 'thế', 'mà'],
#  ['vương', 'quan', 'mới', 'dẫn', 'gần', 'xa'],
#  ['đạm', 'tiên', 'nàng', 'ấy', 'xưa', 'là', 'ca', 'nhi'],
#  ['nổi', 'danh', 'tài', 'sắc', 'một', 'thì'],
#  ['xôn', 'xao', 'ngoài', 'cửa', 'hiếm', 'gì', 'yến', 'anh'],
#  ['kiếp', 'hồng', 'nhan', 'có', 'mong', 'manh'],
#  ['nửa', 'chừng', 'xuân', 'thoắt', 'gãy', 'cành', 'thiên', 'hương'],
#  ['có', 'người', 'khách', 'ở', 'viễn', 'phương'],
#  ['xa', 'nghe', 'cũng', 'nức', 'tiếng', 'nàng', 'tìm', 'chơi'],
#  ['thuyền', 'tình', 'vừa', 'ghé', 'tới', 'nơi'],
#  ['thì', 'đà', 'trâm', 'gẫy', 'bình', 'rơi', 'bao', 'giờ'],
#  ['buồng', 'không', 'lạnh', 'ngắt', 'như', 'tờ'],
#  ['dấu', 'xe', 'ngựa', 'đã', 'rêu', 'lờ', 'mờ', 'xanh'],
#  ['khóc', 'than', 'khôn', 'xiết', 'sự', 'tình'],
#  ['khéo', 'vô', 'duyên', 'ấy', 'là', 'mình', 'với', 'ta'],
#  ['đã', 'không', 'duyên', 'trước', 'chăng', 'mà'],
#  ['thì', 'chi', 'chút', 'ước', 'gọi', 'là', 'duyên', 'sau'],
#  ['sắm', 'xanh', 'nếp', 'tử', 'xe', 'trâu'],
#  ['vùi', 'nông', 'một', 'nấm', 'mặc', 'dầu', 'cỏ', 'hoa'],
#  ['trải', 'bao', 'thỏ', 'lặn', 'ác', 'tà'],
#  ['ấy', 'mồ', 'vô', 'chủ', 'ai', 'mà', 'viếng', 'thăm'],
#  ['lòng', 'đâu', 'sẵn', 'mối', 'thương', 'tâm'],
#  ['thoắt', 'nghe', 'kiều', 'đã', 'đầm', 'đầm', 'châu', 'sa'],
#  ['đau', 'đớn', 'thay', 'phận', 'đàn', 'bà'],
#  ['lời', 'rằng', 'bạc', 'mệnh', 'cũng', 'là', 'lời', 'chung'],
#  ['phũ', 'phàng', 'chi', 'bấy', 'hoá', 'công'],
#  ['ngày', 'xanh', 'mòn', 'mỏi', 'má', 'hồng', 'phôi', 'pha'],
#  ['sống', 'làm', 'vợ', 'khắp', 'người', 'ta'],
#  ['khéo', 'thay', 'thác', 'xuống', 'làm', 'ma', 'không', 'chồng'],
#  ['nào', 'người', 'phượng', 'chạ', 'loan', 'chung'],
#  ['nào', 'người', 'tích', 'lục', 'tham', 'hồng', 'là', 'ai'],
#  ['đã', 'không', 'kẻ', 'đoái', 'người', 'hoài'],
#  ['sẵn', 'đây', 'ta', 'kiếm', 'một', 'vài', 'nén', 'hương'],
#  ['gọi', 'là', 'gặp', 'gỡ', 'giữa', 'đường'],
#  ['họa', 'là', 'người', 'dưới', 'suối', 'vàng', 'biết', 'cho'],
#  ['lầm', 'rầm', 'khấn', 'khứa', 'nhỏ', 'to'],
#  ['sụp', 'ngồi', 'vài', 'gật', 'trước', 'mồ', 'bước', 'ra'],
#  ['một', 'vùng', 'cỏ', 'áy', 'bóng', 'tà'],
#  ['gió', 'hiu', 'hiu', 'thổi', 'một', 'vài', 'bông', 'lau'],
#  ['rút', 'trâm', 'sẵn', 'giắt', 'mái', 'đầu'],
#  ['vạch', 'da', 'cây', 'vịnh', 'bốn', 'câu', 'ba', 'vần'],
#  ['lại', 'càng', 'mê', 'mẩn', 'tâm', 'thần'],
#  ['lại', 'càng', 'đứng', 'lặng', 'tần', 'ngần', 'chẳng', 'ra'],
#  ['lại', 'càng', 'ủ', 'dột', 'nét', 'hoa'],
#  ['sầu', 'tuôn', 'đứt', 'nối', 'châu', 'sa', 'vắn', 'dài'],
#  ['vân', 'rằng', 'chị', 'cũng', 'nực', 'cười'],
#  ['khéo', 'dư', 'nước', 'mắt', 'khóc', 'người', 'đời', 'xưa'],
#  ['rằng', 'hồng', 'nhan', 'tự', 'thuở', 'xưa'],
#  ['cái', 'điều', 'bạc', 'mệnh', 'có', 'chừa', 'ai', 'đâu'],
#  ['nỗi', 'niềm', 'tưởng', 'đến', 'mà', 'đau'],
#  ['thấy', 'người', 'nằm', 'đó', 'biết', 'sau', 'thế', 'nào'],
#  ['quan', 'rằng', 'chị', 'nói', 'hay', 'sao'],
#  ['một', 'lời', 'là', 'một', 'vận', 'vào', 'khó', 'nghe'],
#  ['ở', 'đây', 'âm', 'khí', 'nặng', 'nề'],
#  ['bóng', 'chiều', 'đã', 'ngả', 'dậm', 'về', 'còn', 'xa'],
#  ['kiều', 'rằng', 'những', 'đấng', 'tài', 'hoa'],
#  ['thác', 'là', 'thể', 'phách', 'còn', 'là', 'tinh', 'anh'],
#  ['dễ', 'hay', 'tình', 'lại', 'gặp', 'tình'],
#  ['chờ', 'xem', 'ắt', 'thấy', 'hiển', 'linh', 'bây', 'giờ'],
#  ['một', 'lời', 'nói', 'chửa', 'kịp', 'thưa'],
#  ['thoắt', 'đâu', 'trận', 'gió', 'cuốn', 'cờ', 'đến', 'ngay'],
#  ['ào', 'ào', 'đổ', 'lộc', 'rung', 'cây'],
#  ['ở', 'trong', 'dường', 'có', 'hương', 'bay', 'ít', 'nhiều'],
#  ['đè', 'chừng', 'ngọn', 'gió', 'lần', 'theo'],
#  ['dấu', 'giày', 'từng', 'bước', 'in', 'rêu', 'rành', 'rành'],
#  ['mắt', 'nhìn', 'ai', 'nấy', 'đều', 'kinh'],
#  ['nàng', 'rằng', 'này', 'thực', 'tinh', 'thành', 'chẳng', 'xa'],
#  ['hữu', 'tình', 'ta', 'lại', 'gặp', 'ta'],
#  ['chớ', 'nề', 'u', 'hiển', 'mới', 'là', 'chị', 'em'],
#  ['đã', 'lòng', 'hiển', 'hiện', 'cho', 'xem'],
#  ['tạ', 'lòng', 'nàng', 'lại', 'nối', 'thêm', 'vài', 'lời'],
#  ['lòng', 'thơ', 'lai', 'láng', 'bồi', 'hồi'],
#  ['gốc', 'cây', 'lại', 'vạch', 'một', 'bài', 'cổ', 'thi'],
#  ['dùng', 'dằng', 'nửa', 'ở', 'nửa', 'về'],
#  ['nhạc', 'vàng', 'đâu', 'đã', 'tiếng', 'nghe', 'gần', 'gần'],
#  ['trông', 'chừng', 'thấy', 'một', 'văn', 'nhân'],
#  ['lỏng', 'buông', 'tay', 'khấu', 'bước', 'lần', 'dặm', 'băng'],
#  ['đề', 'huề', 'lưng', 'túi', 'gió', 'trăng'],
#  ['sau', 'chân', 'theo', 'một', 'vài', 'thằng', 'con', 'con'],
#  ['tuyết', 'in', 'sắc', 'ngựa', 'câu', 'giòn'],
#  ['cỏ', 'pha', 'màu', 'áo', 'nhuộm', 'non', 'da', 'trời'],
#  ['nẻo', 'xa', 'mới', 'tỏ', 'mặt', 'người'],
#  ['khách', 'đà', 'xuống', 'ngựa', 'tới', 'nơi', 'tự', 'tình'],
#  ['hài', 'văn', 'lần', 'bước', 'dặm', 'xanh'],
#  ['một', 'vùng', 'như', 'thể', 'cây', 'quỳnh', 'cành', 'dao'],
#  ['chàng', 'vương', 'quen', 'mặt', 'ra', 'chào'],
#  ['hai', 'kiều', 'e', 'lệ', 'nép', 'vào', 'dưới', 'hoa'],
#  ['nguyên', 'người', 'quanh', 'quất', 'đâu', 'xa'],
#  ['họ', 'kim', 'tên', 'trọng', 'vốn', 'nhà', 'trâm', 'anh'],
#  ['nền', 'phú', 'hậu', 'bậc', 'tài', 'danh'],
#  ['văn', 'chương', 'nết', 'đất', 'thông', 'minh', 'tính', 'trời'],
#  ['phong', 'tư', 'tài', 'mạo', 'tót', 'vời'],
#  ['vào', 'trong', 'phong', 'nhã', 'ra', 'ngoài', 'hào', 'hoa'],
#  ['chung', 'quanh', 'vẫn', 'đất', 'nước', 'nhà'],
#  ['với', 'vương', 'quan', 'trước', 'vẫn', 'là', 'đồng', 'thân'],
#  ['vẫn', 'nghe', 'thơm', 'nức', 'hương', 'lân'],
#  ['một', 'nền', 'đồng', 'tước', 'khoá', 'xuân', 'hai', 'kiều'],
#  ['nước', 'non', 'cách', 'mấy', 'buồng', 'thêu'],
#  ['những', 'là', 'trộm', 'nhớ', 'thầm', 'yêu', 'chốc', 'mòng'],
#  ['may', 'thay', 'giải', 'cấu', 'tương', 'phùng'],
#  ['gặp', 'tuần', 'đố', 'lá', 'thoả', 'lòng', 'tìm', 'hoa'],
#  ['bóng', 'hồng', 'nhác', 'thấy', 'nẻo', 'xa'],
#  ['xuân', 'lan', 'thu', 'cúc', 'mặn', 'mà', 'cả', 'hai'],
#  ['người', 'quốc', 'sắc', 'kẻ', 'thiên', 'tài'],
#  ['tình', 'trong', 'như', 'đã', 'mặt', 'ngoài', 'còn', 'e'],
#  ['chập', 'chờn', 'cơn', 'tỉnh', 'cơn', 'mê'],
#  ['rốn', 'ngồi', 'chẳng', 'tiện', 'dứt', 'về', 'chỉn', 'khôn'],
#  ['bóng', 'tà', 'như', 'giục', 'cơn', 'buồn'],
#  ['khách', 'đà', 'lên', 'ngựa', 'người', 'còn', 'nghé', 'theo'],
#  ['dưới', 'cầu', 'nước', 'chảy', 'trong', 'veo'],
#  ['bên', 'cầu', 'tơ', 'liễu', 'bóng', 'chiều', 'thướt', 'tha'],
#  ['kiều', 'từ', 'trở', 'gót', 'trướng', 'hoa'],
#  ['mặt', 'trời', 'gác', 'núi', 'chiêng', 'đà', 'thu', 'không'],
#  ['gương', 'nga', 'chênh', 'chếch', 'dòm', 'song'],
#  ['vàng', 'gieo', 'ngấn', 'nước', 'cây', 'lồng', 'bóng', 'sân'],
#  ['hải', 'đường', 'lả', 'ngọn', 'đông', 'lân'],
#  ['giọt', 'sương', 'gieo', 'nặng', 'cành', 'xuân', 'la', 'đà'],
#  ['một', 'mình', 'lặng', 'ngắm', 'bóng', 'nga'],
#  ['rộn', 'đường', 'gần', 'với', 'nỗi', 'xa', 'bời', 'bời'],
#  ['người', 'mà', 'đến', 'thế', 'thì', 'thôi'],
#  ['đời', 'phồn', 'hoa', 'cũng', 'là', 'đời', 'bỏ', 'đi'],
#  ['người', 'đâu', 'gặp', 'gỡ', 'làm', 'chi'],
#  ['trăm', 'năm', 'biết', 'có', 'duyên', 'gì', 'hay', 'không'],
#  ['ngổn', 'ngang', 'trăm', 'mối', 'bên', 'lòng'],
#  ['nên', 'câu', 'tuyệt', 'diệu', 'ngụ', 'trong', 'tính', 'tình'],
#  ['chênh', 'chênh', 'bóng', 'nguyệt', 'xế', 'mành'],
#  ['tựa', 'nương', 'bên', 'triện', 'một', 'mình', 'thiu', 'thiu'],
#  ['thoắt', 'đâu', 'thấy', 'một', 'tiểu', 'kiều'],
#  ['có', 'chiều', 'thanh', 'vận', 'có', 'chiều', 'thanh', 'tân'],
#  ['sương', 'in', 'mặt', 'tuyết', 'pha', 'thân'],
#  ['sen', 'vàng', 'lãng', 'đãng', 'như', 'gần', 'như', 'xa'],
#  ['chào', 'mừng', 'đón', 'hỏi', 'dò', 'la'],
#  ['đào', 'nguyên', 'lạc', 'lối', 'đâu', 'mà', 'đến', 'đây'],
#  ['thưa', 'rằng', 'thanh', 'khí', 'xưa', 'nay'],
#  ['mới', 'cùng', 'nhau', 'lúc', 'ban', 'ngày', 'đã', 'quên'],
#  ['hàn', 'gia', 'ở', 'mé', 'tây', 'thiên'],
#  ['dưới', 'dòng', 'nước', 'chảy', 'bên', 'trên', 'có', 'cầu'],
#  ['mấy', 'lòng', 'hạ', 'cố', 'đến', 'nhau'],
#  ['mấy', 'lời', 'hạ', 'tứ', 'ném', 'châu', 'gieo', 'vàng'],
#  ['vâng', 'trình', 'hội', 'chủ', 'xem', 'tường'],
#  ['mà', 'sao', 'trong', 'sổ', 'đoạn', 'trường', 'có', 'tên'],
#  ['âu', 'đành', 'quả', 'kiếp', 'nhân', 'duyên'],
#  ['cùng', 'người', 'một', 'hội', 'một', 'thuyền', 'đâu', 'xa'],
#  ['này', 'mười', 'bài', 'mới', 'mới', 'ra'],
#  ['câu', 'thần', 'lại', 'mượn', 'bút', 'hoa', 'vẽ', 'vời'],
#  ['kiều', 'vâng', 'lĩnh', 'ý', 'đề', 'bài'],
#  ['tay', 'tiên', 'một', 'vẫy', 'đủ', 'mười', 'khúc', 'ngâm'],
#  ['xem', 'thơ', 'nức', 'nở', 'khen', 'thầm'],
#  ['giá', 'đành', 'tú', 'khẩu', 'cẩm', 'tâm', 'khác', 'thường'],
#  ['ví', 'đem', 'vào', 'tập', 'đoạn', 'trường'],
#  ['thì', 'treo', 'giải', 'nhất', 'chi', 'nhường', 'cho', 'ai'],
#  ['thềm', 'hoa', 'khách', 'đã', 'trở', 'hài'],
#  ['nàng', 'còn', 'cầm', 'lại', 'một', 'hai', 'tự', 'tình'],
#  ['gió', 'đâu', 'xịch', 'bức', 'mành', 'mành'],
#  ['tỉnh', 'ra', 'mới', 'biết', 'rằng', 'mình', 'chiêm', 'bao'],
#  ['trông', 'theo', 'nào', 'thấy', 'đâu', 'nào'],
#  ['hương', 'thừa', 'dường', 'hãy', 'ra', 'vào', 'đâu', 'đây'],
#  ['một', 'mình', 'lưỡng', 'lự', 'canh', 'chầy'],
#  ['đường', 'xa', 'nghĩ', 'nỗi', 'sau', 'này', 'mà', 'kinh'],
#  ['hoa', 'trôi', 'bèo', 'dạt', 'đã', 'đành'],
#  ['biết', 'duyên', 'mình', 'biết', 'phận', 'mình', 'thế', 'thôi'],
#  ['nỗi', 'riêng', 'lớp', 'lớp', 'sóng', 'dồi'],
#  ['nghĩ', 'đòi', 'cơn', 'lại', 'sụt', 'sùi', 'đòi', 'cơn'],
#  ['giọng', 'kiều', 'rền', 'rĩ', 'trướng', 'loan'],
#  ['nhà', 'huyên', 'chợt', 'tỉnh', 'hỏi', 'cơn', 'cớ', 'gì'],
#  ['cớ', 'sao', 'trằn', 'trọc', 'canh', 'khuya'],
#  ['màu', 'hoa', 'lê', 'hãy', 'dầm', 'dề', 'giọt', 'mưa'],
#  ['thưa', 'rằng', 'chút', 'phận', 'ngây', 'thơ'],
#  ['dưỡng', 'sinh', 'đôi', 'nợ', 'tóc', 'tơ', 'chưa', 'đền'],
#  ['buổi', 'ngày', 'chơi', 'mả', 'đạm', 'tiên'],
#  ['nhắp', 'đi', 'thoắt', 'thấy', 'ứng', 'liền', 'chiêm', 'bao'],
#  ['đoạn', 'trường', 'là', 'số', 'thế', 'nào'],
#  ['bài', 'ra', 'thế', 'ấy', 'vịnh', 'vào', 'thế', 'kia'],
#  ['cứ', 'trong', 'mộng', 'triệu', 'mà', 'suy'],
#  ['phận', 'con', 'thôi', 'có', 'ra', 'gì', 'mai', 'sau'],
#  ['dạy', 'rằng', 'mộng', 'triệu', 'cớ', 'đâu'],
#  ['bỗng', 'không', 'mua', 'não', 'chuốc', 'sầu', 'nghĩ', 'nao'],
#  ['vâng', 'lời', 'khuyên', 'giải', 'thấp', 'cao'],
#  ['chưa', 'xong', 'điều', 'nghĩ', 'đã', 'dào', 'mạch', 'tương'],
#  ['ngoài', 'song', 'thỏ', 'thẻ', 'oanh', 'vàng'],
#  ['nách', 'tường', 'bông', 'liễu', 'bay', 'ngang', 'trước', 'mành'],
#  ['hiên', 'tà', 'gác', 'bóng', 'chênh', 'chênh'],
#  ['nỗi', 'riêng', 'riêng', 'trạnh', 'tấc', 'riêng', 'một', 'mình'],
#  ['cho', 'hay', 'là', 'thói', 'hữu', 'tình'],
#  ['đố', 'ai', 'gỡ', 'mối', 'tơ', 'mành', 'cho', 'xong'],
#  ['chàng', 'kim', 'từ', 'lại', 'thư', 'song'],
#  ['nỗi', 'nàng', 'canh', 'cánh', 'bên', 'lòng', 'biếng', 'khuây'],
#  ['sầu', 'đong', 'càng', 'lắc', 'càng', 'đầy'],
#  ['ba', 'thu', 'dồn', 'lại', 'một', 'ngày', 'dài', 'ghê'],
#  ['mây', 'tần', 'khóa', 'kín', 'song', 'the'],
#  ['bụi', 'hồng', 'lẽo', 'đẽo', 'đi', 'về', 'chiêm', 'bao'],
#  ['tuần', 'trăng', 'khuyết', 'đĩa', 'dầu', 'hao'],
#  ['mặt', 'mơ', 'tưởng', 'mặt', 'lòng', 'ngao', 'ngán', 'lòng'],
#  ['buồng', 'văn', 'hơi', 'giá', 'như', 'đồng'],
#  ['trúc', 'se', 'ngọn', 'thỏ', 'tơ', 'chùng', 'phím', 'loan'],
#  ['mành', 'tương', 'phất', 'phất', 'gió', 'đàn'],
#  ['hương', 'gây', 'mùi', 'nhớ', 'trà', 'khan', 'giọng', 'tình'],
#  ['vì', 'chăng', 'duyên', 'nợ', 'ba', 'sinh'],
#  ['thì', 'chi', 'đem', 'thói', 'khuynh', 'thành', 'trêu', 'ngươi'],
#  ['bâng', 'khuâng', 'nhớ', 'cảnh', 'nhớ', 'người'],
#  ['nhớ', 'nơi', 'kỳ', 'ngộ', 'vội', 'dời', 'chân', 'đi'],
#  ['một', 'vùng', 'cỏ', 'mọc', 'xanh', 'rì'],
#  ['nước', 'ngâm', 'trong', 'vắt', 'thấy', 'gì', 'nữa', 'đâu'],
#  ['gió', 'chiều', 'như', 'gợi', 'cơn', 'sầu'],
#  ['vi', 'lô', 'hiu', 'hắt', 'như', 'màu', 'khảy', 'trêu'],
#  ['nghề', 'riêng', 'nhớ', 'ít', 'tưởng', 'nhiều'],
#  ['xăm', 'xăm', 'đè', 'nẻo', 'lam', 'kiều', 'lần', 'sang'],
#  ['thâm', 'nghiêm', 'kín', 'cổng', 'cao', 'tường'],
#  ['cạn', 'dòng', 'lá', 'thắm', 'dứt', 'đường', 'chim', 'xanh'],
#  ['lơ', 'thơ', 'tơ', 'liễu', 'buông', 'mành'],
#  ['con', 'oanh', 'học', 'nói', 'trên', 'cành', 'mỉa', 'mai'],
#  ['mấy', 'lần', 'cửa', 'đóng', 'then', 'cài'],
#  ['đầy', 'thềm', 'hoa', 'rụng', 'biết', 'người', 'ở', 'đâu'],
#  ['tần', 'ngần', 'đứng', 'suốt', 'giờ', 'lâu'],
#  ['dạo', 'quanh', 'chợt', 'thấy', 'mái', 'sau', 'có', 'nhà'],
#  ['là', 'nhà', 'ngô', 'việt', 'thương', 'gia'],
#  ['buồng', 'không', 'để', 'đó', 'người', 'xa', 'chưa', 'về'],
#  ['lấy', 'điều', 'du', 'học', 'hỏi', 'thuê'],
#  ['túi', 'đàn', 'cặp', 'sách', 'đề', 'huề', 'dọn', 'sang'],
#  ['có', 'cây', 'có', 'đá', 'sẵn', 'sàng'],
#  ['có', 'hiên', 'lãm', 'thúy', 'nét', 'vàng', 'chưa', 'phai'],
#  ['mừng', 'thầm', 'chốn', 'ấy', 'chữ', 'bài'],
#  ['ba', 'sinh', 'âu', 'hẳn', 'duyên', 'trời', 'chi', 'đây'],
#  ['song', 'hồ', 'nửa', 'khép', 'cánh', 'mây'],
#  ['tường', 'đông', 'ghé', 'mắt', 'ngày', 'ngày', 'hằng', 'trông'],
#  ['tấc', 'gang', 'động', 'khóa', 'nguồn', 'phong'],
#  ['tịt', 'mù', 'nào', 'thấy', 'bóng', 'hồng', 'vào', 'ra'],
#  ['nhẫn', 'từ', 'quán', 'khách', 'lân', 'la'],
#  ['tuần', 'trăng', 'thấm', 'thoắt', 'nay', 'đà', 'thèm', 'hai'],
#  ['cách', 'tường', 'phải', 'buổi', 'êm', 'trời'],
#  ['dưới', 'đào', 'dường', 'có', 'bóng', 'người', 'thướt', 'tha'],
#  ['buông', 'cầm', 'xốc', 'áo', 'vội', 'ra'],
#  ['hương', 'còn', 'thơm', 'nức', 'người', 'đà', 'vắng', 'tanh'],
#  ['lần', 'theo', 'tường', 'gấm', 'dạo', 'quanh'],
#  ['trên', 'đào', 'nhác', 'thấy', 'một', 'cành', 'kim', 'thoa'],
#  ['giơ', 'tay', 'với', 'lấy', 'về', 'nhà'],
#  ['này', 'trong', 'khuê', 'các', 'đâu', 'mà', 'đến', 'đây'],
#  ['ngẫm', 'âu', 'người', 'ấy', 'báu', 'này'],
#  ['chẳng', 'duyên', 'chưa', 'dễ', 'vào', 'tay', 'ai', 'cầm'],
#  ['liền', 'tay', 'ngắm', 'nghía', 'biếng', 'nằm'],
#  ['hãy', 'còn', 'thoang', 'thoảng', 'hương', 'trầm', 'chưa', 'phai'],
#  ['tan', 'sương', 'đã', 'thấy', 'bóng', 'người'],
#  ['quanh', 'tường', 'ra', 'ý', 'tìm', 'tòi', 'ngẩn', 'ngơ'],
#  ['sinh', 'đà', 'có', 'ý', 'đợi', 'chờ'],
#  ['cách', 'tường', 'lên', 'tiếng', 'xa', 'đưa', 'ướm', 'lòng'],
#  ['thoa', 'này', 'bắt', 'được', 'hư', 'không'],
#  ['biết', 'đâu', 'hợp', 'phố', 'mà', 'mong', 'châu', 'về'],
#  ['tiếng', 'kiều', 'nghe', 'lọt', 'bên', 'kia'],
#  ['“ơn', 'lòng', 'quân', 'tử', 'sá', 'gì', 'của', 'rơi'],
#  ['chiếc', 'thoa', 'nào', 'của', 'mấy', 'mươi'],
#  ['mà', 'lòng', 'trọng', 'nghĩa', 'khinh', 'tài', 'xiết', 'bao', '”'],
#  ['sinh', 'rằng', '“lân', 'lý', 'ra', 'vào'],
#  ['gần', 'đây', 'nào', 'phải', 'người', 'nào', 'xa', 'xôi'],
#  ['rày', 'nhờ', 'được', 'chút', 'thơm', 'rơi'],
#  ['kể', 'đà', 'thiểu', 'não', 'lòng', 'người', 'bấy', 'nay'],
#  ['bấy', 'lâu', 'mới', 'được', 'một', 'ngày'],
#  ['dừng', 'chân', 'gạn', 'chút', 'niềm', 'tây', 'gọi', 'là”'],
#  ['vội', 'về', 'thêm', 'lấy', 'của', 'nhà'],
#  ['khuyến', 'vàng', 'đôi', 'chiếc', 'khăn', 'là', 'một', 'vuông'],
#  ['thang', 'mây', 'qua', 'bước', 'ngọn', 'tường'],
#  ['phải', 'người', 'hôm', 'nọ', 'rõ', 'ràng', 'chẳng', 'như'],
#  ['sượng', 'sùng', 'giữ', 'ý', 'rụt', 'rè'],
#  ['kẻ', 'nhìn', 'rõ', 'mặt', 'người', 'e', 'cúi', 'đầu'],
#  ['rằng', '“từ', 'ngẫu', 'nhỉ', 'gặp', 'nhau'],
#  ['thầm', 'trông', 'trộm', 'nhớ', 'bấy', 'lâu', 'đã', 'chồn'],
#  ['xương', 'mai', 'tính', 'đã', 'rũ', 'mòn'],
#  ['lần', 'lừa', 'ai', 'biết', 'hãy', 'còn', 'hôm', 'nay'],
#  ['vuông', 'tròn', 'nhờ', 'cậy', 'cung', 'mây'],
#  ['trần', 'trần', 'một', 'phận', 'ấp', 'cây', 'đã', 'liều'],
#  ['tiện', 'đây', 'xin', 'một', 'đôi', 'điều'],
#  ['đài', 'gương', 'soi', 'đến', 'dấu', 'bèo', 'cho', 'chăng', '”'],
#  ['ngần', 'ngừ', 'nàng', 'mới', 'thưa', 'rằng'],
#  ['“thói', 'nhà', 'băng', 'tuyết', 'chất', 'hằng', 'phỉ', 'phong'],
#  ['dù', 'khi', 'lá', 'thắm', 'chỉ', 'hồng'],
#  ['nên', 'chăng', 'thì', 'cũng', 'tại', 'lòng', 'mẹ', 'cha'],
#  ['nặng', 'lòng', 'xót', 'liễu', 'vì', 'hoa'],
#  ['trẻ', 'thơ', 'đã', 'biết', 'đâu', 'mà', 'dám', 'thưa', '”'],
#  ['sinh', 'rằng', 'rày', 'gió', 'mai', 'mưa'],
#  ['ngày', 'xuân', 'đã', 'dễ', 'tình', 'cờ', 'mấy', 'khi'],
#  ['dù', 'chăng', 'xét', 'tấm', 'tình', 'si'],
#  ['thiệt', 'đây', 'mà', 'có', 'ích', 'gì', 'cho', 'ai'],
#  ['chút', 'chi', 'gắn', 'bó', 'một', 'hai'],
#  ['cho', 'đành', 'rồi', 'sẽ', 'liệu', 'bài', 'mối', 'manh'],
#  ['khuôn', 'thiên', 'dù', 'phụ', 'tấc', 'thành'],
#  ['cũng', 'liều', 'bỏ', 'quá', 'xuân', 'xanh', 'một', 'đời'],
#  ['lượng', 'xuân', 'dù', 'quyết', 'hẹp', 'hòi'],
#  ['công', 'đeo', 'đuổi', 'chẳng', 'thiệt', 'thòi', 'lắm', 'ru', '”'],
#  ['lặng', 'nghe', 'lời', 'nói', 'như', 'ru'],
#  ['chiều', 'xuân', 'dễ', 'khiến', 'nét', 'thu', 'ngại', 'ngùng'],
#  ['rằng', '“trong', 'buổi', 'mới', 'lạ', 'lùng'],
#  ['nể', 'lòng', 'có', 'lẽ', 'cầm', 'lòng', 'cho', 'đang'],
#  ['đã', 'lòng', 'quân', 'tử', 'đa', 'mang'],
#  ['một', 'lời', 'vâng', 'tạc', 'đá', 'vàng', 'thủy', 'chung', '”'],
#  ['được', 'lời', 'như', 'cởi', 'tấm', 'lòng'],
#  ['giở', 'kim', 'thoa', 'với', 'khăn', 'hồng', 'trao', 'tay'],
#  ['rằng', '“trăm', 'năm', 'cũng', 'từ', 'đây'],
#  ['của', 'tin', 'gọi', 'một', 'chút', 'này', 'làm', 'ghi”'],
#  ['sẵn', 'tay', 'bả', 'quạt', 'hoa', 'quì'],
#  ['với', 'cành', 'thoa', 'ấy', 'tức', 'thì', 'đổi', 'trao'],
#  ['một', 'lời', 'gắn', 'bó', 'tất', 'giao'],
#  ['mé', 'sau', 'nhường', 'có', 'xôn', 'xao', 'tiếng', 'người'],
#  ['vội', 'vàng', 'lá', 'rụng', 'hoa', 'rơi'],
#  ['chàng', 'về', 'viện', 'sách', 'nàng', 'dời', 'lầu', 'trang'],
#  ['từ', 'phen', 'đá', 'biết', 'tuổi', 'vàng'],
#  ['tình', 'càng', 'thấm', 'thía', 'lòng', 'càng', 'ngẩn', 'ngơ'],
#  ['sông', 'tương', 'một', 'dải', 'nông', 'sờ'],
#  ['bên', 'trông', 'đầu', 'nọ', 'bên', 'chờ', 'cuối', 'kia'],
#  ['một', 'tuồng', 'tuyết', 'chở', 'sương', 'che'],
#  ['tin', 'xuân', 'đâu', 'dễ', 'đi', 'về', 'cho', 'năng'],
#  ['lần', 'lần', 'ngày', 'gió', 'đêm', 'trăng'],
#  ['thưa', 'hồng', 'rậm', 'lục', 'đã', 'chừng', 'xuân', 'qua'],
#  ['ngày', 'vừa', 'sinh', 'nhật', 'ngoại', 'gia'],
#  ['trên', 'hai', 'đường', 'dưới', 'nữa', 'là', 'hai', 'em'],
#  ['tưng', 'bừng', 'sắm', 'sửa', 'áo', 'xiêm'],
#  ['biện', 'dâng', 'một', 'lễ', 'xa', 'đem', 'tấc', 'thành'],
#  ['nhà', 'hương', 'thanh', 'vắng', 'một', 'mình'],
#  ['ngẫm', 'cơ', 'hội', 'ngộ', 'đã', 'dành', 'hôm', 'nay'],
#  ['thời', 'trân', 'thức', 'thức', 'sẵn', 'bày'],
#  ['gót', 'sen', 'thoăn', 'thoắt', 'dạo', 'ngay', 'mé', 'tường'],
#  ['cách', 'hoa', 'sẽ', 'dặng', 'tiếng', 'vàng'],
#  ['dưới', 'hoa', 'đã', 'thấy', 'có', 'chàng', 'đứng', 'trông'],
#  ['“trách', 'lòng', 'hờ', 'hững', 'với', 'lòng'],
#  ['lửa', 'hương', 'chốc', 'để', 'lạnh', 'lùng', 'bấy', 'lâu'],
#  ['những', 'là', 'đắp', 'nhớ', 'đổi', 'sầu'],
#  ['tuyết', 'sương', 'nhuốm', 'nửa', 'mái', 'đầu', 'hoa', 'râm”'],
#  ['nàng', 'rằng', '“gió', 'bắt', 'mưa', 'cầm'],
#  ['đã', 'cam', 'tệ', 'với', 'tri', 'âm', 'bấy', 'chầy'],
#  ['vắng', 'nhà', 'được', 'buổi', 'hôm', 'nay'],
#  ['lấy', 'lòng', 'gọi', 'chút', 'ra', 'đây', 'tạ', 'lòng'],
#  ['lần', 'theo', 'núi', 'giả', 'đi', 'vòng'],
#  ['cuối', 'tường', 'nhường', 'có', 'nẻo', 'thông', 'mới', 'rào'],
#  ['xắn', 'tay', 'mở', 'khóa', 'động', 'đào'],
#  ['rẽ', 'mây', 'trông', 'tỏ', 'lối', 'vào', 'thiên', 'thai'],
#  ['mặt', 'nhìn', 'mặt', 'càng', 'thêm', 'tươi'],
#  ['bên', 'lời', 'vạn', 'phúc', 'bên', 'lời', 'hàn', 'huyên'],
#  ['sánh', 'vai', 'về', 'chốn', 'tư', 'hiên'],
#  ['góp', 'lời', 'phong', 'nguyệt', 'nặng', 'nguyền', 'non', 'sông'],
#  ['trên', 'yên', 'bút', 'giá', 'thi', 'đồng'],
#  ['đạm', 'thanh', 'một', 'bức', 'trang', 'tùng', 'treo', 'trên'],
#  ['phong', 'sương', 'được', 'vẻ', 'thiên', 'nhiên'],
#  ['mặn', 'khen', 'nét', 'bút', 'càng', 'nhìn', 'càng', 'tươi'],
#  ['sinh', 'rằng', '“phác', 'họa', 'vừa', 'rồi'],
#  ['phẩm', 'đề', 'xin', 'một', 'vài', 'lời', 'thêm', 'hoa', '”'],
#  ['tay', 'tiên', 'gió', 'táp', 'mưa', 'sa'],
#  ['khoảng', 'trên', 'dừng', 'bút', 'thảo', 'và', 'bốn', 'câu'],
#  ['khen', '“tài', 'nhả', 'ngọc', 'phun', 'châu'],
#  ['nàng', 'ban', 'ả', 'tạ', 'cũng', 'đâu', 'thế', 'này'],
#  ['kiếp', 'tu', 'xưa', 'ví', 'chưa', 'dày'],
#  ['phúc', 'nào', 'nhắc', 'được', 'giá', 'này', 'cho', 'ngang'],
#  ['nàng', 'rằng', 'trộm', 'liếc', 'dung', 'quang'],
#  ['chẳng', 'sân', 'bội', 'ngọc', 'cũng', 'phường', 'kim', 'môn'],
#  ['nghĩ', 'mình', 'phận', 'mỏng', 'cánh', 'chuồn'],
#  ['khuôn', 'xanh', 'biết', 'có', 'vuông', 'tròn', 'mà', 'hay'],
#  ['nhớ', 'từ', 'năm', 'hãy', 'thơ', 'ngây'],
#  ['có', 'người', 'tướng', 'sĩ', 'đoán', 'ngay', 'một', 'lời'],
#  ['anh', 'hoa', 'phát', 'tiết', 'ra', 'ngoài'],
#  ['nghìn', 'thu', 'bạc', 'mệnh', 'một', 'đời', 'tài', 'hoa'],
#  ['trông', 'người', 'lại', 'ngẫm', 'đến', 'ta'],
#  ['một', 'dầy', 'một', 'mỏng', 'biết', 'là', 'có', 'nên', "'"],
#  ['sinh', 'rằng', 'giải', 'cấu', 'là', 'duyên'],
#  ['xưa', 'nay', 'nhân', 'định', 'thắng', 'nhiên', 'cũng', 'nhiều'],
#  ['ví', 'dù', 'giải', 'kết', 'đến', 'điều'],
#  ['thì', 'đem', 'vàng', 'đá', 'mà', 'liều', 'với', 'thân'],
#  ['đủ', 'điều', 'trung', 'khúc', 'ân', 'cần'],
#  ['lòng', 'xuân', 'phơi', 'phới', 'chén', 'xuân', 'tàng', 'tàng'],
#  ['ngày', 'vui', 'ngắn', 'chẳng', 'đầy', 'gang'],
#  ['trông', 'ra', 'ác', 'đã', 'ngậm', 'gương', 'non', 'đoài'],
#  ['vắng', 'nhà', 'chẳng', 'tiện', 'ngồi', 'dai'],
#  ['giã', 'chàng', 'nàng', 'mới', 'kíp', 'dời', 'song', 'sa'],
#  ['đến', 'nhà', 'vừa', 'thấy', 'tin', 'nhà'],
#  ['hai', 'thân', 'còn', 'dở', 'tiệc', 'hoa', 'chưa', 'về'],
#  ['cửa', 'ngoài', 'vội', 'rủ', 'rèm', 'the'],
#  ['xăm', 'xăm', 'băng', 'lối', 'vườn', 'khuya', 'một', 'mình'],
#  ['nhặt', 'thưa', 'gương', 'giọi', 'đầu', 'cành'],
#  ['ngọn', 'đèn', 'trông', 'lọt', 'trướng', 'huỳnh', 'hắt', 'hiu'],
#  ['sinh', 'vừa', 'tựa', 'án', 'thiu', 'thiu'],
#  ['dở', 'chiều', 'như', 'tỉnh', 'dở', 'chiều', 'như', 'mê'],
#  ['tiếng', 'sen', 'sẽ', 'động', 'giấc', 'hòe'],
#  ['bóng', 'trăng', 'đã', 'xế', 'hoa', 'lê', 'lại', 'gần'],
#  ['bâng', 'khuâng', 'đỉnh', 'giáp', 'non', 'thần'],
#  ['còn', 'ngờ', 'giấc', 'mộng', 'đêm', 'xuân', 'mơ', 'màng'],
#  ['nàng', 'rằng', 'khoảng', 'vắng', 'đêm', 'trường'],
#  ['vì', 'hoa', 'nên', 'phải', 'đánh', 'đường', 'tìm', 'hoa'],
#  ['bây', 'giờ', 'rõ', 'mặt', 'đôi', 'ta'],
#  ['biết', 'đâu', 'rồi', 'nữa', 'chẳng', 'là', 'chiêm', 'bao'],
#  ['vội', 'mừng', 'làm', 'lễ', 'rước', 'vào'],
#  ['đài', 'sen', 'nối', 'sáp', 'song', 'đào', 'thêm', 'hương'],
#  ['tiên', 'thề', 'cùng', 'thảo', 'một', 'chương'],
#  ['tóc', 'mây', 'một', 'món', 'dao', 'vàng', 'chia', 'đôi'],
#  ['vầng', 'trăng', 'vằng', 'vặc', 'giữa', 'trời'],
#  ['đinh', 'ninh', 'hai', 'mặt', 'một', 'lời', 'song', 'song'],
#  ['tóc', 'tơ', 'căn', 'vặn', 'tấc', 'lòng'],
#  ['trăm', 'năm', 'tạc', 'một', 'chữ', 'đồng', 'đến', 'xương'],
#  ['chén', 'hà', 'sánh', 'giọng', 'quỳnh', 'tương'],
#  ['dải', 'là', 'hương', 'lộn', 'bình', 'gương', 'bóng', 'lồng'],
#  ['sinh', 'rằng', 'gió', 'mát', 'trăng', 'trong'],
#  ['bấy', 'lâu', 'nay', 'một', 'chút', 'lòng', 'chưa', 'cam'],
#  ['chày', 'sương', 'chưa', 'nện', 'cầu', 'lam'],
#  ['sợ', 'lần', 'khân', 'quá', 'ra', 'sàm', 'sỡ', 'chăng'],
#  ['nàng', 'rằng', 'hồng', 'diệp', 'xích', 'thằng'],
#  ['một', 'lời', 'cũng', 'đã', 'tiếng', 'rằng', 'tương', 'tri'],
#  ['đừng', 'điều', 'nguyệt', 'nọ', 'hoa', 'kia'],
#  ['ngoài', 'ra', 'ai', 'lại', 'tiếc', 'gì', 'với', 'ai'],
#  ['rằng', 'nghe', 'nổi', 'tiếng', 'cầm', 'đài'],
#  ['nước', 'non', 'luống', 'những', 'lắng', 'tai', 'chung', 'kỳ'],
#  ['thưa', 'rằng', 'tiện', 'kỹ', 'sá', 'chi'],
#  ['đã', 'lòng', 'dạy', 'đến', 'dạy', 'thì', 'phải', 'vâng'],
#  ['hiên', 'sau', 'treo', 'sẵn', 'cầm', 'trăng'],
#  ['vội', 'vàng', 'sinh', 'đã', 'tay', 'nâng', 'ngang', 'mày'],
#  ['nàng', 'rằng', 'nghề', 'mọn', 'riêng', 'tay'],
#  ['làm', 'chi', 'cho', 'bận', 'lòng', 'này', 'lắm', 'thân'],
#  ['so', 'dần', 'dây', 'vũ', 'dây', 'văn'],
#  ['bốn', 'dây', 'to', 'nhỏ', 'theo', 'vần', 'cung', 'thương'],
#  ['khúc', 'đâu', 'hán', 'sở', 'chiến', 'trường'],
#  ['nghe', 'ra', 'tiếng', 'sắt', 'tiếng', 'vàng', 'chen', 'nhau'],
#  ['khúc', 'đâu', 'tư', 'mã', 'phượng', 'cầu'],
#  ['nghe', 'ra', 'như', 'oán', 'như', 'sầu', 'phải', 'chăng'],
#  ['kê', 'khang', 'này', 'khúc', 'quảng', 'lăng'],
#  ['một', 'rằng', 'lưu', 'thủy', 'hai', 'rằng', 'hành', 'vân'],
#  ['qua', 'quan', 'này', 'khúc', 'chiêu', 'quân'],
#  ['nửa', 'phần', 'luyến', 'chúa', 'nửa', 'phần', 'tư', 'gia'],
#  ['trong', 'như', 'tiếng', 'hạc', 'bay', 'qua'],
#  ['đục', 'như', 'tiếng', 'suối', 'mới', 'sa', 'nửa', 'vời'],
#  ['tiếng', 'khoan', 'như', 'gió', 'thoảng', 'ngoài'],
#  ['tiếng', 'mau', 'sầm', 'sập', 'như', 'trời', 'đổ', 'mưa'],
#  ['ngọn', 'đèn', 'khi', 'tỏ', 'khi', 'mờ'],
#  ['khiến', 'người', 'ngồi', 'đó', 'cũng', 'ngơ', 'ngẩn', 'sầu'],
#  ['khi', 'tựa', 'gối', 'khi', 'cúi', 'đầu'],
#  ['khi', 'vò', 'chín', 'khúc', 'khi', 'chau', 'đôi', 'mày'],
#  ['rằng', 'hay', 'thì', 'thật', 'là', 'hay'],
#  ['nghe', 'ra', 'ngậm', 'đắng', 'nuốt', 'cay', 'thế', 'nào'],
#  ['lựa', 'chi', 'những', 'bậc', 'tiêu', 'tao'],
#  ['dột', 'lòng', 'mình', 'cũng', 'nao', 'nao', 'lòng', 'người'],
#  ['rằng', 'quen', 'mất', 'nết', 'đi', 'rồi'],
#  ['tẻ', 'vui', 'thôi', 'cũng', 'tính', 'trời', 'biết', 'sao'],
#  ['lời', 'vàng', 'âm', 'lĩnh', 'ý', 'cao'],
#  ['họa', 'dần', 'dần', 'bớt', 'chút', 'nào', 'được', 'không'],
#  ['hoa', 'hương', 'càng', 'tỏ', 'thức', 'hồng'],
#  ['đầu', 'mày', 'cuối', 'mắt', 'càng', 'nồng', 'tấm', 'yêu'],
#  ['sóng', 'tình', 'dường', 'đã', 'xiêu', 'xiêu'],
#  ['xem', 'trong', 'âu', 'yếm', 'có', 'chiều', 'lả', 'lơi']]

# %%
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(corpus)
w2id = tokenizer.word_index

# %%
w2id
# Out:
# {'<OOV>': 1,
#  'một': 2,
#  'lòng': 3,
#  'người': 4,
#  'rằng': 5,
#  'là': 6,
#  'hoa': 7,
#  'đã': 8,
#  'có': 9,
#  'đâu': 10,
#  'như': 11,
#  'ra': 12,
#  'mà': 13,
#  'vàng': 14,
#  'lời': 15,
#  'lại': 16,
#  'xuân': 17,
#  'tình': 18,
#  'xa': 19,
#  'trong': 20,
#  'thấy': 21,
#  'hai': 22,
#  'nhà': 23,
#  'cũng': 24,
#  'về': 25,
#  'bóng': 26,
#  'nàng': 27,
#  'tiếng': 28,
#  'biết': 29,
#  'xanh': 30,
#  'hồng': 31,
#  'càng': 32,
#  'hương': 33,
#  'lần': 34,
#  'tay': 35,
#  'mới': 36,
#  'nào': 37,
#  'kiều': 38,
#  'nước': 39,
#  'tường': 40,
#  'ai': 41,
#  'ngày': 42,
#  'đây': 43,
#  'mình': 44,
#  'cho': 45,
#  'gió': 46,
#  'đến': 47,
#  'này': 48,
#  'mặt': 49,
#  'sinh': 50,
#  'tài': 51,
#  'trông': 52,
#  'trời': 53,
#  'còn': 54,
#  'bên': 55,
#  'thì': 56,
#  'nghe': 57,
#  'vào': 58,
#  'phong': 59,
#  'thanh': 60,
#  'nửa': 61,
#  'không': 62,
#  'duyên': 63,
#  'với': 64,
#  'chi': 65,
#  'chẳng': 66,
#  'chưa': 67,
#  'gì': 68,
#  'trăng': 69,
#  'ngoài': 70,
#  'thế': 71,
#  'đà': 72,
#  'chút': 73,
#  'chiều': 74,
#  'nhớ': 75,
#  'song': 76,
#  'ta': 77,
#  'điều': 78,
#  'đầu': 79,
#  'sẵn': 80,
#  'cầm': 81,
#  'khúc': 82,
#  'đi': 83,
#  'cành': 84,
#  'gần': 85,
#  'theo': 86,
#  'ngọn': 87,
#  'sau': 88,
#  'thưa': 89,
#  'nay': 90,
#  'được': 91,
#  'khi': 92,
#  'sắc': 93,
#  'tư': 94,
#  'gia': 95,
#  'tuyết': 96,
#  'xem': 97,
#  'mây': 98,
#  'riêng': 99,
#  'thiên': 100,
#  'non': 101,
#  'vài': 102,
#  'thơ': 103,
#  'ấy': 104,
#  'thoắt': 105,
#  'bao': 106,
#  'chăng': 107,
#  'bấy': 108,
#  'đường': 109,
#  'dưới': 110,
#  'cây': 111,
#  'sầu': 112,
#  'hay': 113,
#  'cơn': 114,
#  'sương': 115,
#  'mành': 116,
#  'trên': 117,
#  'vội': 118,
#  'năm': 119,
#  'những': 120,
#  'nghĩ': 121,
#  'con': 122,
#  'chị': 123,
#  'nét': 124,
#  'thu': 125,
#  'đành': 126,
#  'cỏ': 127,
#  'ngang': 128,
#  'tà': 129,
#  'bước': 130,
#  'quanh': 131,
#  'cầu': 132,
#  'vắng': 133,
#  'xưa': 134,
#  'ở': 135,
#  'phận': 136,
#  'làm': 137,
#  'gặp': 138,
#  'nỗi': 139,
#  'bài': 140,
#  'mấy': 141,
#  'tương': 142,
#  'tơ': 143,
#  'từ': 144,
#  'đôi': 145,
#  'phải': 146,
#  '”': 147,
#  'chữ': 148,
#  'mệnh': 149,
#  'nhau': 150,
#  'qua': 151,
#  'trước': 152,
#  'minh': 153,
#  'vương': 154,
#  'quan': 155,
#  'em': 156,
#  'mai': 157,
#  'cách': 158,
#  'liễu': 159,
#  'thành': 160,
#  'họa': 161,
#  'nên': 162,
#  'nhân': 163,
#  'ba': 164,
#  'nức': 165,
#  'anh': 166,
#  'ngựa': 167,
#  'nao': 168,
#  'sao': 169,
#  'tiên': 170,
#  'khách': 171,
#  'vừa': 172,
#  'gọi': 173,
#  'châu': 174,
#  'sa': 175,
#  'chung': 176,
#  'câu': 177,
#  'đời': 178,
#  'dễ': 179,
#  'thêm': 180,
#  'văn': 181,
#  'chàng': 182,
#  'kim': 183,
#  'đồng': 184,
#  'thân': 185,
#  'giải': 186,
#  'gương': 187,
#  'chênh': 188,
#  'đào': 189,
#  'vâng': 190,
#  'trường': 191,
#  'ý': 192,
#  'hãy': 193,
#  'mưa': 194,
#  'tấc': 195,
#  'lâu': 196,
#  'thoa': 197,
#  'dù': 198,
#  'trăm': 199,
#  'khéo': 200,
#  'thơm': 201,
#  'bốn': 202,
#  'lặng': 203,
#  'nối': 204,
#  'dòng': 205,
#  'vân': 206,
#  'thần': 207,
#  'mười': 208,
#  'trang': 209,
#  'vời': 210,
#  'đầy': 211,
#  'tóc': 212,
#  'nhường': 213,
#  'màu': 214,
#  'pha': 215,
#  'nghề': 216,
#  'thương': 217,
#  'âm': 218,
#  'bạc': 219,
#  'tuần': 220,
#  'trướng': 221,
#  'chân': 222,
#  'hội': 223,
#  'tử': 224,
#  'áo': 225,
#  'bay': 226,
#  'dần': 227,
#  'cuối': 228,
#  'chừng': 229,
#  'tìm': 230,
#  'rơi': 231,
#  'giờ': 232,
#  'buồng': 233,
#  'mối': 234,
#  'ngồi': 235,
#  'hiu': 236,
#  'mắt': 237,
#  'nói': 238,
#  'nặng': 239,
#  'dường': 240,
#  'nhìn': 241,
#  'đề': 242,
#  'nẻo': 243,
#  'tỏ': 244,
#  'tính': 245,
#  'thầm': 246,
#  'lá': 247,
#  'tỉnh': 248,
#  'tiện': 249,
#  'thôi': 250,
#  'thiu': 251,
#  'sen': 252,
#  'âu': 253,
#  'bút': 254,
#  'giá': 255,
#  'đem': 256,
#  'chiêm': 257,
#  'buổi': 258,
#  'kia': 259,
#  'hiên': 260,
#  'xăm': 261,
#  'lấy': 262,
#  'đá': 263,
#  'của': 264,
#  'hôm': 265,
#  'rồi': 266,
#  'đau': 267,
#  'quen': 268,
#  'thói': 269,
#  'đèn': 270,
#  'lục': 271,
#  'kinh': 272,
#  'thường': 273,
#  'nga': 274,
#  'thúy': 275,
#  'tinh': 276,
#  'trọng': 277,
#  'khuôn': 278,
#  'ngọc': 279,
#  'da': 280,
#  'mặn': 281,
#  'phần': 282,
#  'thủy': 283,
#  'thắm': 284,
#  'đòi': 285,
#  'thông': 286,
#  'thi': 287,
#  'đủ': 288,
#  'ngâm': 289,
#  'cung': 290,
#  'bậc': 291,
#  'chương': 292,
#  'não': 293,
#  'tới': 294,
#  'đông': 295,
#  'lê': 296,
#  'bông': 297,
#  'tiết': 298,
#  'lễ': 299,
#  'sắm': 300,
#  'chơi': 301,
#  'xe': 302,
#  'lên': 303,
#  'tây': 304,
#  'nhỏ': 305,
#  'đất': 306,
#  'đạm': 307,
#  'cửa': 308,
#  'kiếp': 309,
#  'nơi': 310,
#  'trâm': 311,
#  'dấu': 312,
#  'thỏ': 313,
#  'tâm': 314,
#  'thay': 315,
#  'đàn': 316,
#  'loan': 317,
#  'kẻ': 318,
#  'gỡ': 319,
#  'vùng': 320,
#  'mái': 321,
#  'mê': 322,
#  'đứng': 323,
#  'tần': 324,
#  'ngần': 325,
#  'tự': 326,
#  'tưởng': 327,
#  'đó': 328,
#  'chờ': 329,
#  'hiển': 330,
#  'ngay': 331,
#  'nhiều': 332,
#  'in': 333,
#  'tạ': 334,
#  'buông': 335,
#  'băng': 336,
#  'e': 337,
#  'vẫn': 338,
#  'lân': 339,
#  'trộm': 340,
#  'gieo': 341,
#  'la': 342,
#  'nguyệt': 343,
#  'tựa': 344,
#  'mừng': 345,
#  'hỏi': 346,
#  'lối': 347,
#  'cùng': 348,
#  'mé': 349,
#  'đoạn': 350,
#  'khen': 351,
#  'ví': 352,
#  'treo': 353,
#  'canh': 354,
#  'giọng': 355,
#  'cớ': 356,
#  'mộng': 357,
#  'dạy': 358,
#  'cao': 359,
#  'cánh': 360,
#  'khóa': 361,
#  'vì': 362,
#  'dời': 363,
#  'nữa': 364,
#  'dạo': 365,
#  'động': 366,
#  'ngẫm': 367,
#  'ngẩn': 368,
#  'ngơ': 369,
#  'quân': 370,
#  'vuông': 371,
#  'nọ': 372,
#  'rõ': 373,
#  'liều': 374,
#  'đài': 375,
#  'tấm': 376,
#  'sẽ': 377,
#  'tin': 378,
#  'đêm': 379,
#  'thức': 380,
#  'dở': 381,
#  'mày': 382,
#  'dây': 383,
#  'trải': 384,
#  'đớn': 385,
#  'lạ': 386,
#  'má': 387,
#  'đánh': 388,
#  'ghen': 389,
#  'giở': 390,
#  'phương': 391,
#  'ngoại': 392,
#  'họ': 393,
#  'trung': 394,
#  'nho': 395,
#  'ả': 396,
#  'vẻ': 397,
#  'khác': 398,
#  'nở': 399,
#  'cười': 400,
#  'thua': 401,
#  'so': 402,
#  'bề': 403,
#  'nghiêng': 404,
#  'vốn': 405,
#  'mùi': 406,
#  'ca': 407,
#  'đứt': 408,
#  'hồ': 409,
#  'lựa': 410,
#  'lưu': 411,
#  'quần': 412,
#  'kê': 413,
#  'êm': 414,
#  'rủ': 415,
#  'che': 416,
#  'mặc': 417,
#  'đưa': 418,
#  'thoi': 419,
#  'quang': 420,
#  'chín': 421,
#  'mươi': 422,
#  'yến': 423,
#  'sửa': 424,
#  'hành': 425,
#  'ngổn': 426,
#  'ngả': 427,
#  'tiểu': 428,
#  'cảnh': 429,
#  'sè': 430,
#  'nấm': 431,
#  'dàu': 432,
#  'tanh': 433,
#  'nổi': 434,
#  'danh': 435,
#  'xôn': 436,
#  'xao': 437,
#  'nhan': 438,
#  'mong': 439,
#  'manh': 440,
#  'thuyền': 441,
#  'ghé': 442,
#  'bình': 443,
#  'lạnh': 444,
#  'rêu': 445,
#  'mờ': 446,
#  'khóc': 447,
#  'khôn': 448,
#  'xiết': 449,
#  'vô': 450,
#  'nông': 451,
#  'dầu': 452,
#  'ác': 453,
#  'mồ': 454,
#  'chủ': 455,
#  'đầm': 456,
#  'công': 457,
#  'mòn': 458,
#  'thác': 459,
#  'xuống': 460,
#  'phượng': 461,
#  'giữa': 462,
#  'suối': 463,
#  'to': 464,
#  'vạch': 465,
#  'vịnh': 466,
#  'vần': 467,
#  'dột': 468,
#  'dài': 469,
#  'niềm': 470,
#  'nằm': 471,
#  'vận': 472,
#  'khí': 473,
#  'nề': 474,
#  'thể': 475,
#  'bây': 476,
#  'cờ': 477,
#  'ào': 478,
#  'đổ': 479,
#  'ít': 480,
#  'đè': 481,
#  'rành': 482,
#  'hữu': 483,
#  'dặm': 484,
#  'huề': 485,
#  'túi': 486,
#  'thằng': 487,
#  'hài': 488,
#  'quỳnh': 489,
#  'dao': 490,
#  'chào': 491,
#  'nguyên': 492,
#  'tên': 493,
#  'nền': 494,
#  'nết': 495,
#  'yêu': 496,
#  'chốc': 497,
#  'cấu': 498,
#  'đố': 499,
#  'nhác': 500,
#  'dứt': 501,
#  'chảy': 502,
#  'thướt': 503,
#  'tha': 504,
#  'trở': 505,
#  'gót': 506,
#  'gác': 507,
#  'núi': 508,
#  'lồng': 509,
#  'sân': 510,
#  'lả': 511,
#  'giọt': 512,
#  'ngắm': 513,
#  'bời': 514,
#  'bỏ': 515,
#  'xế': 516,
#  'ban': 517,
#  'hàn': 518,
#  'hạ': 519,
#  'lĩnh': 520,
#  'thềm': 521,
#  'bức': 522,
#  'chầy': 523,
#  'bèo': 524,
#  'lớp': 525,
#  'sóng': 526,
#  'huyên': 527,
#  'chợt': 528,
#  'khuya': 529,
#  'ngây': 530,
#  'nợ': 531,
#  'liền': 532,
#  'triệu': 533,
#  'xong': 534,
#  'oanh': 535,
#  'biếng': 536,
#  'kín': 537,
#  'the': 538,
#  'mơ': 539,
#  'phất': 540,
#  'trêu': 541,
#  'bâng': 542,
#  'khuâng': 543,
#  'kỳ': 544,
#  'ngộ': 545,
#  'hắt': 546,
#  'lam': 547,
#  'sang': 548,
#  'học': 549,
#  'rụng': 550,
#  'để': 551,
#  'sách': 552,
#  'phai': 553,
#  'chốn': 554,
#  'hằng': 555,
#  'gang': 556,
#  'thấm': 557,
#  'thoảng': 558,
#  'bắt': 559,
#  'lọt': 560,
#  'sá': 561,
#  'chiếc': 562,
#  'rày': 563,
#  'nhờ': 564,
#  'dừng': 565,
#  'khăn': 566,
#  'cúi': 567,
#  'xương': 568,
#  'tròn': 569,
#  'trần': 570,
#  'xin': 571,
#  'thiệt': 572,
#  'gắn': 573,
#  'bó': 574,
#  'quá': 575,
#  'lắm': 576,
#  'ru': 577,
#  'khiến': 578,
#  'lùng': 579,
#  'tạc': 580,
#  'trao': 581,
#  'đổi': 582,
#  'sông': 583,
#  'dải': 584,
#  'cam': 585,
#  'tri': 586,
#  'tươi': 587,
#  'phúc': 588,
#  'sánh': 589,
#  'nhiên': 590,
#  'khoảng': 591,
#  'thảo': 592,
#  'mỏng': 593,
#  'chén': 594,
#  'tàng': 595,
#  'vui': 596,
#  'ngậm': 597,
#  'giấc': 598,
#  'xiêu': 599,
#  'cõi': 600,
#  'ghét': 601,
#  'cuộc': 602,
#  'bể': 603,
#  'dâu': 604,
#  'bỉ': 605,
#  'cảo': 606,
#  'truyền': 607,
#  'sử': 608,
#  'tĩnh': 609,
#  'triều': 610,
#  'phẳng': 611,
#  'vững': 612,
#  'viên': 613,
#  'bực': 614,
#  'trai': 615,
#  'thứ': 616,
#  'rốt': 617,
#  'tố': 618,
#  'cốt': 619,
#  'phân': 620,
#  'vẹn': 621,
#  'đặn': 622,
#  'ngài': 623,
#  'nang': 624,
#  'thốt': 625,
#  'đoan': 626,
#  'sảo': 627,
#  'hơn': 628,
#  'làn': 629,
#  'sơn': 630,
#  'hờn': 631,
#  'kém': 632,
#  'làu': 633,
#  'ngũ': 634,
#  'ăn': 635,
#  'trương': 636,
#  'rất': 637,
#  'mực': 638,
#  'sấp': 639,
#  'xỉ': 640,
#  'cập': 641,
#  'đềm': 642,
#  'màn': 643,
#  'ong': 644,
#  'bướm': 645,
#  'én': 646,
#  'thiều': 647,
#  'chục': 648,
#  'sáu': 649,
#  'tận': 650,
#  'trắng': 651,
#  'điểm': 652,
#  'tháng': 653,
#  'tảo': 654,
#  'mộ': 655,
#  'đạp': 656,
#  'nô': 657,
#  'bộ': 658,
#  'dập': 659,
#  'dìu': 660,
#  'giai': 661,
#  'nêm': 662,
#  'gò': 663,
#  'đống': 664,
#  'kéo': 665,
#  'vó': 666,
#  'rắc': 667,
#  'tro': 668,
#  'tiền': 669,
#  'giấy': 670,
#  'thẩn': 671,
#  'dan': 672,
#  'khê': 673,
#  'uốn': 674,
#  'dịp': 675,
#  'ghềnh': 676,
#  'bắc': 677,
#  'đàng': 678,
#  'khói': 679,
#  'dẫn': 680,
#  'nhi': 681,
#  'hiếm': 682,
#  'gãy': 683,
#  'viễn': 684,
#  'gẫy': 685,
#  'ngắt': 686,
#  'tờ': 687,
#  'lờ': 688,
#  'than': 689,
#  'sự': 690,
#  'ước': 691,
#  'nếp': 692,
#  'trâu': 693,
#  'vùi': 694,
#  'lặn': 695,
#  'viếng': 696,
#  'thăm': 697,
#  'bà': 698,
#  'phũ': 699,
#  'phàng': 700,
#  'hoá': 701,
#  'mỏi': 702,
#  'phôi': 703,
#  'sống': 704,
#  'vợ': 705,
#  'khắp': 706,
#  'ma': 707,
#  'chồng': 708,
#  'chạ': 709,
#  'tích': 710,
#  'tham': 711,
#  'đoái': 712,
#  'hoài': 713,
#  'kiếm': 714,
#  'nén': 715,
#  'lầm': 716,
#  'rầm': 717,
#  'khấn': 718,
#  'khứa': 719,
#  'sụp': 720,
#  'gật': 721,
#  'áy': 722,
#  'thổi': 723,
#  'lau': 724,
#  'rút': 725,
#  'giắt': 726,
#  'mẩn': 727,
#  'ủ': 728,
#  'tuôn': 729,
#  'vắn': 730,
#  'nực': 731,
#  'dư': 732,
#  'thuở': 733,
#  'cái': 734,
#  'chừa': 735,
#  'khó': 736,
#  'dậm': 737,
#  'đấng': 738,
#  'phách': 739,
#  'ắt': 740,
#  'linh': 741,
#  'chửa': 742,
#  'kịp': 743,
#  'trận': 744,
#  'cuốn': 745,
#  'lộc': 746,
#  'rung': 747,
#  'giày': 748,
#  'từng': 749,
#  'nấy': 750,
#  'đều': 751,
#  'thực': 752,
#  'chớ': 753,
#  'u': 754,
#  'hiện': 755,
#  'lai': 756,
#  'láng': 757,
#  'bồi': 758,
#  'hồi': 759,
#  'gốc': 760,
#  'cổ': 761,
#  'dùng': 762,
#  'dằng': 763,
#  'nhạc': 764,
#  'lỏng': 765,
#  'khấu': 766,
#  'lưng': 767,
#  'giòn': 768,
#  'nhuộm': 769,
#  'lệ': 770,
#  'nép': 771,
#  'quất': 772,
#  'phú': 773,
#  'hậu': 774,
#  'mạo': 775,
#  'tót': 776,
#  'nhã': 777,
#  'hào': 778,
#  'tước': 779,
#  'khoá': 780,
#  'thêu': 781,
#  'mòng': 782,
#  'may': 783,
#  'phùng': 784,
#  'thoả': 785,
#  'lan': 786,
#  'cúc': 787,
#  'cả': 788,
#  'quốc': 789,
#  'chập': 790,
#  'chờn': 791,
#  'rốn': 792,
#  'chỉn': 793,
#  'giục': 794,
#  'buồn': 795,
#  'nghé': 796,
#  'veo': 797,
#  'chiêng': 798,
#  'chếch': 799,
#  'dòm': 800,
#  'ngấn': 801,
#  'hải': 802,
#  'rộn': 803,
#  'phồn': 804,
#  'tuyệt': 805,
#  'diệu': 806,
#  'ngụ': 807,
#  'nương': 808,
#  'triện': 809,
#  'tân': 810,
#  'lãng': 811,
#  'đãng': 812,
#  'đón': 813,
#  'dò': 814,
#  'lạc': 815,
#  'lúc': 816,
#  'quên': 817,
#  'cố': 818,
#  'tứ': 819,
#  'ném': 820,
#  'trình': 821,
#  'sổ': 822,
#  'quả': 823,
#  'mượn': 824,
#  'vẽ': 825,
#  'vẫy': 826,
#  'tú': 827,
#  'khẩu': 828,
#  'cẩm': 829,
#  'tập': 830,
#  'nhất': 831,
#  'xịch': 832,
#  'thừa': 833,
#  'lưỡng': 834,
#  'lự': 835,
#  'trôi': 836,
#  'dạt': 837,
#  'dồi': 838,
#  'sụt': 839,
#  'sùi': 840,
#  'rền': 841,
#  'rĩ': 842,
#  'trằn': 843,
#  'trọc': 844,
#  'dầm': 845,
#  'dề': 846,
#  'dưỡng': 847,
#  'đền': 848,
#  'mả': 849,
#  'nhắp': 850,
#  'ứng': 851,
#  'số': 852,
#  'cứ': 853,
#  'suy': 854,
#  'bỗng': 855,
#  'mua': 856,
#  'chuốc': 857,
#  'khuyên': 858,
#  'thấp': 859,
#  'dào': 860,
#  'mạch': 861,
#  'thẻ': 862,
#  'nách': 863,
#  'trạnh': 864,
#  'thư': 865,
#  'khuây': 866,
#  'đong': 867,
#  'lắc': 868,
#  'dồn': 869,
#  'ghê': 870,
#  'bụi': 871,
#  'lẽo': 872,
#  'đẽo': 873,
#  'khuyết': 874,
#  'đĩa': 875,
#  'hao': 876,
#  'ngao': 877,
#  'ngán': 878,
#  'hơi': 879,
#  'trúc': 880,
#  'se': 881,
#  'chùng': 882,
#  'phím': 883,
#  'gây': 884,
#  'trà': 885,
#  'khan': 886,
#  'khuynh': 887,
#  'ngươi': 888,
#  'mọc': 889,
#  'rì': 890,
#  'vắt': 891,
#  'gợi': 892,
#  'vi': 893,
#  'lô': 894,
#  'khảy': 895,
#  'thâm': 896,
#  'nghiêm': 897,
#  'cổng': 898,
#  'cạn': 899,
#  'chim': 900,
#  'lơ': 901,
#  'mỉa': 902,
#  'đóng': 903,
#  'then': 904,
#  'cài': 905,
#  'suốt': 906,
#  'ngô': 907,
#  'việt': 908,
#  'du': 909,
#  'thuê': 910,
#  'cặp': 911,
#  'dọn': 912,
#  'sàng': 913,
#  'lãm': 914,
#  'hẳn': 915,
#  'khép': 916,
#  'nguồn': 917,
#  'tịt': 918,
#  'mù': 919,
#  'nhẫn': 920,
#  'quán': 921,
#  'thèm': 922,
#  'xốc': 923,
#  'gấm': 924,
#  'giơ': 925,
#  'khuê': 926,
#  'các': 927,
#  'báu': 928,
#  'nghía': 929,
#  'thoang': 930,
#  'trầm': 931,
#  'tan': 932,
#  'tòi': 933,
#  'đợi': 934,
#  'ướm': 935,
#  'hư': 936,
#  'hợp': 937,
#  'phố': 938,
#  '“ơn': 939,
#  'nghĩa': 940,
#  'khinh': 941,
#  '“lân': 942,
#  'lý': 943,
#  'xôi': 944,
#  'kể': 945,
#  'thiểu': 946,
#  'gạn': 947,
#  'là”': 948,
#  'khuyến': 949,
#  'thang': 950,
#  'ràng': 951,
#  'sượng': 952,
#  'sùng': 953,
#  'giữ': 954,
#  'rụt': 955,
#  'rè': 956,
#  '“từ': 957,
#  'ngẫu': 958,
#  'nhỉ': 959,
#  'chồn': 960,
#  'rũ': 961,
#  'lừa': 962,
#  'cậy': 963,
#  'ấp': 964,
#  'soi': 965,
#  'ngừ': 966,
#  '“thói': 967,
#  'chất': 968,
#  'phỉ': 969,
#  'chỉ': 970,
#  'tại': 971,
#  'mẹ': 972,
#  'cha': 973,
#  'xót': 974,
#  'trẻ': 975,
#  'dám': 976,
#  'xét': 977,
#  'si': 978,
#  'ích': 979,
#  'liệu': 980,
#  'phụ': 981,
#  'lượng': 982,
#  'quyết': 983,
#  'hẹp': 984,
#  'hòi': 985,
#  'đeo': 986,
#  'đuổi': 987,
#  'thòi': 988,
#  'ngại': 989,
#  'ngùng': 990,
#  '“trong': 991,
#  'nể': 992,
#  'lẽ': 993,
#  'đang': 994,
#  'đa': 995,
#  'mang': 996,
#  'cởi': 997,
#  '“trăm': 998,
#  'ghi”': 999,
#  'bả': 1000,
#  ...}

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## 3. Xử lý dữ liệu cho CBOW

# %%
vocab_size = len(tokenizer.word_index) + 1
window_size = 2

# %%
import numpy as np
def generate_pairs(window_size, corpus):
  """
  Tiến hành lấy 1 từ khỏi câu làm nhãn và sử dụng câu bao
  gồm k từ bên trái và k từ bên phải (trường hợp này window_size = k) làm đầu vào

  Đầu vào:
    window_size:
      Dạng: Python integer
      Miêu tả: k từ bên trái/phải được giữ lại
    corpus:
      Dạng: Python Dictionary
      Miêu tả: từ điển nối từ và id
  """
  X = []
  y = []
  for words in corpus:
    start = 0
    while start + window_size * 2 < len(words):
      end = start + window_size * 2
      tar_i = start + window_size

      # Lựa chọn từ ở vị trí hiện tại làm nhãn
      label = words[tar_i]

      # Nối k từ bên trái và k từ bên phải của từ này thành 1 câu
      x = [" ".join(words[start:tar_i] + words[tar_i+1:end+1])]

      print(words)
      print(x, "--->", label)
      start += 1
      X.append(tokenizer.texts_to_sequences(x)[0])
      y.append(to_categorical( tokenizer.word_index[label], len(tokenizer.word_index) + 1))

  return tf.convert_to_tensor(X) , tf.convert_to_tensor(y)

# %%
X_train, y_train = generate_pairs(window_size, corpus)
# Out:
# ['trăm', 'năm', 'trong', 'cõi', 'người', 'ta']
# ['trăm năm cõi người'] ---> trong
# ['trăm', 'năm', 'trong', 'cõi', 'người', 'ta']
# ['năm trong người ta'] ---> cõi
# ['chữ', 'tài', 'chữ', 'mệnh', 'khéo', 'là', 'ghét', 'nhau']
# ['chữ tài mệnh khéo'] ---> chữ
# ['chữ', 'tài', 'chữ', 'mệnh', 'khéo', 'là', 'ghét', 'nhau']
# ['tài chữ khéo là'] ---> mệnh
# ['chữ', 'tài', 'chữ', 'mệnh', 'khéo', 'là', 'ghét', 'nhau']
# ['chữ mệnh là ghét'] ---> khéo
# ['chữ', 'tài', 'chữ', 'mệnh', 'khéo', 'là', 'ghét', 'nhau']
# ['mệnh khéo ghét nhau'] ---> là
# ['trải', 'qua', 'một', 'cuộc', 'bể', 'dâu']
# ['trải qua cuộc bể'] ---> một
# ['trải', 'qua', 'một', 'cuộc', 'bể', 'dâu']
# ['qua một bể dâu'] ---> cuộc
# ['những', 'điều', 'trông', 'thấy', 'mà', 'đau', 'đớn', 'lòng']
# ['những điều thấy mà'] ---> trông
# ['những', 'điều', 'trông', 'thấy', 'mà', 'đau', 'đớn', 'lòng']
# ['điều trông mà đau'] ---> thấy
# ['những', 'điều', 'trông', 'thấy', 'mà', 'đau', 'đớn', 'lòng']
# ['trông thấy đau đớn'] ---> mà
# ['những', 'điều', 'trông', 'thấy', 'mà', 'đau', 'đớn', 'lòng']
# ['thấy mà đớn lòng'] ---> đau
# ['lạ', 'gì', 'bỉ', 'sắc', 'tư', 'phong']
# ['lạ gì sắc tư'] ---> bỉ
# ['lạ', 'gì', 'bỉ', 'sắc', 'tư', 'phong']
# ['gì bỉ tư phong'] ---> sắc
# ['trời', 'xanh', 'quen', 'thói', 'má', 'hồng', 'đánh', 'ghen']
# ['trời xanh thói má'] ---> quen
# ['trời', 'xanh', 'quen', 'thói', 'má', 'hồng', 'đánh', 'ghen']
# ['xanh quen má hồng'] ---> thói
# ['trời', 'xanh', 'quen', 'thói', 'má', 'hồng', 'đánh', 'ghen']
# ['quen thói hồng đánh'] ---> má
# ['trời', 'xanh', 'quen', 'thói', 'má', 'hồng', 'đánh', 'ghen']
# ['thói má đánh ghen'] ---> hồng
# ['cảo', 'thơm', 'lần', 'giở', 'trước', 'đèn']
# ['cảo thơm giở trước'] ---> lần
# ['cảo', 'thơm', 'lần', 'giở', 'trước', 'đèn']
# ['thơm lần trước đèn'] ---> giở
# ['phong', 'tình', 'có', 'lục', 'còn', 'truyền', 'sử', 'xanh']
# ['phong tình lục còn'] ---> có
# ['phong', 'tình', 'có', 'lục', 'còn', 'truyền', 'sử', 'xanh']
# ['tình có còn truyền'] ---> lục
# ['phong', 'tình', 'có', 'lục', 'còn', 'truyền', 'sử', 'xanh']
# ['có lục truyền sử'] ---> còn
# ['phong', 'tình', 'có', 'lục', 'còn', 'truyền', 'sử', 'xanh']
# ['lục còn sử xanh'] ---> truyền
# ['rằng', 'năm', 'gia', 'tĩnh', 'triều', 'minh']
# ['rằng năm tĩnh triều'] ---> gia
# ['rằng', 'năm', 'gia', 'tĩnh', 'triều', 'minh']
# ['năm gia triều minh'] ---> tĩnh
# ['bốn', 'phương', 'phẳng', 'lặng', 'hai', 'kinh', 'vững', 'vàng']
# ['bốn phương lặng hai'] ---> phẳng
# ['bốn', 'phương', 'phẳng', 'lặng', 'hai', 'kinh', 'vững', 'vàng']
# ['phương phẳng hai kinh'] ---> lặng
# ['bốn', 'phương', 'phẳng', 'lặng', 'hai', 'kinh', 'vững', 'vàng']
# ['phẳng lặng kinh vững'] ---> hai
# ['bốn', 'phương', 'phẳng', 'lặng', 'hai', 'kinh', 'vững', 'vàng']
# ['lặng hai vững vàng'] ---> kinh
# ['có', 'nhà', 'viên', 'ngoại', 'họ', 'vương']
# ['có nhà ngoại họ'] ---> viên
# ['có', 'nhà', 'viên', 'ngoại', 'họ', 'vương']
# ['nhà viên họ vương'] ---> ngoại
# ['gia', 'tư', 'nghĩ', 'cũng', 'thường', 'thường', 'bực', 'trung']
# ['gia tư cũng thường'] ---> nghĩ
# ['gia', 'tư', 'nghĩ', 'cũng', 'thường', 'thường', 'bực', 'trung']
# ['tư nghĩ thường thường'] ---> cũng
# ['gia', 'tư', 'nghĩ', 'cũng', 'thường', 'thường', 'bực', 'trung']
# ['nghĩ cũng thường bực'] ---> thường
# ['gia', 'tư', 'nghĩ', 'cũng', 'thường', 'thường', 'bực', 'trung']
# ['cũng thường bực trung'] ---> thường
# ['một', 'trai', 'con', 'thứ', 'rốt', 'lòng']
# ['một trai thứ rốt'] ---> con
# ['một', 'trai', 'con', 'thứ', 'rốt', 'lòng']
# ['trai con rốt lòng'] ---> thứ
# ['vương', 'quan', 'là', 'chữ', 'nối', 'dòng', 'nho', 'gia']
# ['vương quan chữ nối'] ---> là
# ['vương', 'quan', 'là', 'chữ', 'nối', 'dòng', 'nho', 'gia']
# ['quan là nối dòng'] ---> chữ
# ['vương', 'quan', 'là', 'chữ', 'nối', 'dòng', 'nho', 'gia']
# ['là chữ dòng nho'] ---> nối
# ['vương', 'quan', 'là', 'chữ', 'nối', 'dòng', 'nho', 'gia']
# ['chữ nối nho gia'] ---> dòng
# ['đầu', 'lòng', 'hai', 'ả', 'tố', 'nga']
# ['đầu lòng ả tố'] ---> hai
# ['đầu', 'lòng', 'hai', 'ả', 'tố', 'nga']
# ['lòng hai tố nga'] ---> ả
# ['thúy', 'kiều', 'là', 'chị', 'em', 'là', 'thúy', 'vân']
# ['thúy kiều chị em'] ---> là
# ['thúy', 'kiều', 'là', 'chị', 'em', 'là', 'thúy', 'vân']
# ['kiều là em là'] ---> chị
# ['thúy', 'kiều', 'là', 'chị', 'em', 'là', 'thúy', 'vân']
# ['là chị là thúy'] ---> em
# ['thúy', 'kiều', 'là', 'chị', 'em', 'là', 'thúy', 'vân']
# ['chị em thúy vân'] ---> là
# ['mai', 'cốt', 'cách', 'tuyết', 'tinh', 'thần']
# ['mai cốt tuyết tinh'] ---> cách
# ['mai', 'cốt', 'cách', 'tuyết', 'tinh', 'thần']
# ['cốt cách tinh thần'] ---> tuyết
# ['một', 'người', 'một', 'vẻ', 'mười', 'phân', 'vẹn', 'mười']
# ['một người vẻ mười'] ---> một
# ['một', 'người', 'một', 'vẻ', 'mười', 'phân', 'vẹn', 'mười']
# ['người một mười phân'] ---> vẻ
# ['một', 'người', 'một', 'vẻ', 'mười', 'phân', 'vẹn', 'mười']
# ['một vẻ phân vẹn'] ---> mười
# ['một', 'người', 'một', 'vẻ', 'mười', 'phân', 'vẹn', 'mười']
# ['vẻ mười vẹn mười'] ---> phân
# ['vân', 'xem', 'trang', 'trọng', 'khác', 'vời']
# ['vân xem trọng khác'] ---> trang
# ['vân', 'xem', 'trang', 'trọng', 'khác', 'vời']
# ['xem trang khác vời'] ---> trọng
# ['khuôn', 'trăng', 'đầy', 'đặn', 'nét', 'ngài', 'nở', 'nang']
# ['khuôn trăng đặn nét'] ---> đầy
# ['khuôn', 'trăng', 'đầy', 'đặn', 'nét', 'ngài', 'nở', 'nang']
# ['trăng đầy nét ngài'] ---> đặn
# ['khuôn', 'trăng', 'đầy', 'đặn', 'nét', 'ngài', 'nở', 'nang']
# ['đầy đặn ngài nở'] ---> nét
# ['khuôn', 'trăng', 'đầy', 'đặn', 'nét', 'ngài', 'nở', 'nang']
# ['đặn nét nở nang'] ---> ngài
# ['hoa', 'cười', 'ngọc', 'thốt', 'đoan', 'trang']
# ['hoa cười thốt đoan'] ---> ngọc
# ['hoa', 'cười', 'ngọc', 'thốt', 'đoan', 'trang']
# ['cười ngọc đoan trang'] ---> thốt
# ['mây', 'thua', 'nước', 'tóc', 'tuyết', 'nhường', 'màu', 'da']
# ['mây thua tóc tuyết'] ---> nước
# ['mây', 'thua', 'nước', 'tóc', 'tuyết', 'nhường', 'màu', 'da']
# ['thua nước tuyết nhường'] ---> tóc
# ['mây', 'thua', 'nước', 'tóc', 'tuyết', 'nhường', 'màu', 'da']
# ['nước tóc nhường màu'] ---> tuyết
# ['mây', 'thua', 'nước', 'tóc', 'tuyết', 'nhường', 'màu', 'da']
# ['tóc tuyết màu da'] ---> nhường
# ['kiều', 'càng', 'sắc', 'sảo', 'mặn', 'mà']
# ['kiều càng sảo mặn'] ---> sắc
# ['kiều', 'càng', 'sắc', 'sảo', 'mặn', 'mà']
# ['càng sắc mặn mà'] ---> sảo
# ['so', 'bề', 'tài', 'sắc', 'lại', 'là', 'phần', 'hơn']
# ['so bề sắc lại'] ---> tài
# ['so', 'bề', 'tài', 'sắc', 'lại', 'là', 'phần', 'hơn']
# ['bề tài lại là'] ---> sắc
# ['so', 'bề', 'tài', 'sắc', 'lại', 'là', 'phần', 'hơn']
# ['tài sắc là phần'] ---> lại
# ['so', 'bề', 'tài', 'sắc', 'lại', 'là', 'phần', 'hơn']
# ['sắc lại phần hơn'] ---> là
# ['làn', 'thu', 'thủy', 'nét', 'xuân', 'sơn']
# ['làn thu nét xuân'] ---> thủy
# ['làn', 'thu', 'thủy', 'nét', 'xuân', 'sơn']
# ['thu thủy xuân sơn'] ---> nét
# ['hoa', 'ghen', 'thua', 'thắm', 'liễu', 'hờn', 'kém', 'xanh']
# ['hoa ghen thắm liễu'] ---> thua
# ['hoa', 'ghen', 'thua', 'thắm', 'liễu', 'hờn', 'kém', 'xanh']
# ['ghen thua liễu hờn'] ---> thắm
# ['hoa', 'ghen', 'thua', 'thắm', 'liễu', 'hờn', 'kém', 'xanh']
# ['thua thắm hờn kém'] ---> liễu
# ['hoa', 'ghen', 'thua', 'thắm', 'liễu', 'hờn', 'kém', 'xanh']
# ['thắm liễu kém xanh'] ---> hờn
# ['một', 'hai', 'nghiêng', 'nước', 'nghiêng', 'thành']
# ['một hai nước nghiêng'] ---> nghiêng
# ['một', 'hai', 'nghiêng', 'nước', 'nghiêng', 'thành']
# ['hai nghiêng nghiêng thành'] ---> nước
# ['sắc', 'đành', 'đòi', 'một', 'tài', 'đành', 'họa', 'hai']
# ['sắc đành một tài'] ---> đòi
# ['sắc', 'đành', 'đòi', 'một', 'tài', 'đành', 'họa', 'hai']
# ['đành đòi tài đành'] ---> một
# ['sắc', 'đành', 'đòi', 'một', 'tài', 'đành', 'họa', 'hai']
# ['đòi một đành họa'] ---> tài
# ['sắc', 'đành', 'đòi', 'một', 'tài', 'đành', 'họa', 'hai']
# ['một tài họa hai'] ---> đành
# ['thông', 'minh', 'vốn', 'sẵn', 'tư', 'trời']
# ['thông minh sẵn tư'] ---> vốn
# ['thông', 'minh', 'vốn', 'sẵn', 'tư', 'trời']
# ['minh vốn tư trời'] ---> sẵn
# ['pha', 'nghề', 'thi', 'họa', 'đủ', 'mùi', 'ca', 'ngâm']
# ['pha nghề họa đủ'] ---> thi
# ['pha', 'nghề', 'thi', 'họa', 'đủ', 'mùi', 'ca', 'ngâm']
# ['nghề thi đủ mùi'] ---> họa
# ['pha', 'nghề', 'thi', 'họa', 'đủ', 'mùi', 'ca', 'ngâm']
# ['thi họa mùi ca'] ---> đủ
# ['pha', 'nghề', 'thi', 'họa', 'đủ', 'mùi', 'ca', 'ngâm']
# ['họa đủ ca ngâm'] ---> mùi
# ['cung', 'thương', 'làu', 'bậc', 'ngũ', 'âm']
# ['cung thương bậc ngũ'] ---> làu
# ['cung', 'thương', 'làu', 'bậc', 'ngũ', 'âm']
# ['thương làu ngũ âm'] ---> bậc
# ['nghề', 'riêng', 'ăn', 'đứt', 'hồ', 'cầm', 'một', 'trương']
# ['nghề riêng đứt hồ'] ---> ăn
# ['nghề', 'riêng', 'ăn', 'đứt', 'hồ', 'cầm', 'một', 'trương']
# ['riêng ăn hồ cầm'] ---> đứt
# ['nghề', 'riêng', 'ăn', 'đứt', 'hồ', 'cầm', 'một', 'trương']
# ['ăn đứt cầm một'] ---> hồ
# ['nghề', 'riêng', 'ăn', 'đứt', 'hồ', 'cầm', 'một', 'trương']
# ['đứt hồ một trương'] ---> cầm
# ['khúc', 'nhà', 'tay', 'lựa', 'nên', 'chương']
# ['khúc nhà lựa nên'] ---> tay
# ['khúc', 'nhà', 'tay', 'lựa', 'nên', 'chương']
# ['nhà tay nên chương'] ---> lựa
# ['một', 'thiên', 'bạc', 'mệnh', 'lại', 'càng', 'não', 'nhân']
# ['một thiên mệnh lại'] ---> bạc
# ['một', 'thiên', 'bạc', 'mệnh', 'lại', 'càng', 'não', 'nhân']
# ['thiên bạc lại càng'] ---> mệnh
# ['một', 'thiên', 'bạc', 'mệnh', 'lại', 'càng', 'não', 'nhân']
# ['bạc mệnh càng não'] ---> lại
# ['một', 'thiên', 'bạc', 'mệnh', 'lại', 'càng', 'não', 'nhân']
# ['mệnh lại não nhân'] ---> càng
# ['phong', 'lưu', 'rất', 'mực', 'hồng', 'quần']
# ['phong lưu mực hồng'] ---> rất
# ['phong', 'lưu', 'rất', 'mực', 'hồng', 'quần']
# ['lưu rất hồng quần'] ---> mực
# ['xuân', 'xanh', 'sấp', 'xỉ', 'tới', 'tuần', 'cập', 'kê']
# ['xuân xanh xỉ tới'] ---> sấp
# ['xuân', 'xanh', 'sấp', 'xỉ', 'tới', 'tuần', 'cập', 'kê']
# ['xanh sấp tới tuần'] ---> xỉ
# ['xuân', 'xanh', 'sấp', 'xỉ', 'tới', 'tuần', 'cập', 'kê']
# ['sấp xỉ tuần cập'] ---> tới
# ['xuân', 'xanh', 'sấp', 'xỉ', 'tới', 'tuần', 'cập', 'kê']
# ['xỉ tới cập kê'] ---> tuần
# ['êm', 'đềm', 'trướng', 'rủ', 'màn', 'che']
# ['êm đềm rủ màn'] ---> trướng
# ['êm', 'đềm', 'trướng', 'rủ', 'màn', 'che']
# ['đềm trướng màn che'] ---> rủ
# ['tường', 'đông', 'ong', 'bướm', 'đi', 'về', 'mặc', 'ai']
# ['tường đông bướm đi'] ---> ong
# ['tường', 'đông', 'ong', 'bướm', 'đi', 'về', 'mặc', 'ai']
# ['đông ong đi về'] ---> bướm
# ['tường', 'đông', 'ong', 'bướm', 'đi', 'về', 'mặc', 'ai']
# ['ong bướm về mặc'] ---> đi
# ['tường', 'đông', 'ong', 'bướm', 'đi', 'về', 'mặc', 'ai']
# ['bướm đi mặc ai'] ---> về
# ['ngày', 'xuân', 'con', 'én', 'đưa', 'thoi']
# ['ngày xuân én đưa'] ---> con
# ['ngày', 'xuân', 'con', 'én', 'đưa', 'thoi']
# ['xuân con đưa thoi'] ---> én
# ['thiều', 'quang', 'chín', 'chục', 'đã', 'ngoài', 'sáu', 'mươi']
# ['thiều quang chục đã'] ---> chín
# ['thiều', 'quang', 'chín', 'chục', 'đã', 'ngoài', 'sáu', 'mươi']
# ['quang chín đã ngoài'] ---> chục
# ['thiều', 'quang', 'chín', 'chục', 'đã', 'ngoài', 'sáu', 'mươi']
# ['chín chục ngoài sáu'] ---> đã
# ['thiều', 'quang', 'chín', 'chục', 'đã', 'ngoài', 'sáu', 'mươi']
# ['chục đã sáu mươi'] ---> ngoài
# ['cỏ', 'non', 'xanh', 'tận', 'chân', 'trời']
# ['cỏ non tận chân'] ---> xanh
# ['cỏ', 'non', 'xanh', 'tận', 'chân', 'trời']
# ['non xanh chân trời'] ---> tận
# ['cành', 'lê', 'trắng', 'điểm', 'một', 'vài', 'bông', 'hoa']
# ['cành lê điểm một'] ---> trắng
# ['cành', 'lê', 'trắng', 'điểm', 'một', 'vài', 'bông', 'hoa']
# ['lê trắng một vài'] ---> điểm
# ['cành', 'lê', 'trắng', 'điểm', 'một', 'vài', 'bông', 'hoa']
# ['trắng điểm vài bông'] ---> một
# ['cành', 'lê', 'trắng', 'điểm', 'một', 'vài', 'bông', 'hoa']
# ['điểm một bông hoa'] ---> vài
# ['thanh', 'minh', 'trong', 'tiết', 'tháng', 'ba']
# ['thanh minh tiết tháng'] ---> trong
# ['thanh', 'minh', 'trong', 'tiết', 'tháng', 'ba']
# ['minh trong tháng ba'] ---> tiết
# ['lễ', 'là', 'tảo', 'mộ', 'hội', 'là', 'đạp', 'thanh']
# ['lễ là mộ hội'] ---> tảo
# ['lễ', 'là', 'tảo', 'mộ', 'hội', 'là', 'đạp', 'thanh']
# ['là tảo hội là'] ---> mộ
# ['lễ', 'là', 'tảo', 'mộ', 'hội', 'là', 'đạp', 'thanh']
# ['tảo mộ là đạp'] ---> hội
# ['lễ', 'là', 'tảo', 'mộ', 'hội', 'là', 'đạp', 'thanh']
# ['mộ hội đạp thanh'] ---> là
# ['gần', 'xa', 'nô', 'nức', 'yến', 'anh']
# ['gần xa nức yến'] ---> nô
# ['gần', 'xa', 'nô', 'nức', 'yến', 'anh']
# ['xa nô yến anh'] ---> nức
# ['chị', 'em', 'sắm', 'sửa', 'bộ', 'hành', 'chơi', 'xuân']
# ['chị em sửa bộ'] ---> sắm
# ['chị', 'em', 'sắm', 'sửa', 'bộ', 'hành', 'chơi', 'xuân']
# ['em sắm bộ hành'] ---> sửa
# ['chị', 'em', 'sắm', 'sửa', 'bộ', 'hành', 'chơi', 'xuân']
# ['sắm sửa hành chơi'] ---> bộ
# ['chị', 'em', 'sắm', 'sửa', 'bộ', 'hành', 'chơi', 'xuân']
# ['sửa bộ chơi xuân'] ---> hành
# ['dập', 'dìu', 'tài', 'tử', 'giai', 'nhân']
# ['dập dìu tử giai'] ---> tài
# ['dập', 'dìu', 'tài', 'tử', 'giai', 'nhân']
# ['dìu tài giai nhân'] ---> tử
# ['ngựa', 'xe', 'như', 'nước', 'áo', 'quần', 'như', 'nêm']
# ['ngựa xe nước áo'] ---> như
# ['ngựa', 'xe', 'như', 'nước', 'áo', 'quần', 'như', 'nêm']
# ['xe như áo quần'] ---> nước
# ['ngựa', 'xe', 'như', 'nước', 'áo', 'quần', 'như', 'nêm']
# ['như nước quần như'] ---> áo
# ['ngựa', 'xe', 'như', 'nước', 'áo', 'quần', 'như', 'nêm']
# ['nước áo như nêm'] ---> quần
# ['ngổn', 'ngang', 'gò', 'đống', 'kéo', 'lên']
# ['ngổn ngang đống kéo'] ---> gò
# ['ngổn', 'ngang', 'gò', 'đống', 'kéo', 'lên']
# ['ngang gò kéo lên'] ---> đống
# ['thoi', 'vàng', 'vó', 'rắc', 'tro', 'tiền', 'giấy', 'bay']
# ['thoi vàng rắc tro'] ---> vó
# ['thoi', 'vàng', 'vó', 'rắc', 'tro', 'tiền', 'giấy', 'bay']
# ['vàng vó tro tiền'] ---> rắc
# ['thoi', 'vàng', 'vó', 'rắc', 'tro', 'tiền', 'giấy', 'bay']
# ['vó rắc tiền giấy'] ---> tro
# ['thoi', 'vàng', 'vó', 'rắc', 'tro', 'tiền', 'giấy', 'bay']
# ['rắc tro giấy bay'] ---> tiền
# ['tà', 'tà', 'bóng', 'ngả', 'về', 'tây']
# ['tà tà ngả về'] ---> bóng
# ['tà', 'tà', 'bóng', 'ngả', 'về', 'tây']
# ['tà bóng về tây'] ---> ngả
# ['chị', 'em', 'thơ', 'thẩn', 'dan', 'tay', 'ra', 'về']
# ['chị em thẩn dan'] ---> thơ
# ['chị', 'em', 'thơ', 'thẩn', 'dan', 'tay', 'ra', 'về']
# ['em thơ dan tay'] ---> thẩn
# ['chị', 'em', 'thơ', 'thẩn', 'dan', 'tay', 'ra', 'về']
# ['thơ thẩn tay ra'] ---> dan
# ['chị', 'em', 'thơ', 'thẩn', 'dan', 'tay', 'ra', 'về']
# ['thẩn dan ra về'] ---> tay
# ['bước', 'dần', 'theo', 'ngọn', 'tiểu', 'khê']
# ['bước dần ngọn tiểu'] ---> theo
# ['bước', 'dần', 'theo', 'ngọn', 'tiểu', 'khê']
# ['dần theo tiểu khê'] ---> ngọn
# ['lần', 'xem', 'phong', 'cảnh', 'có', 'bề', 'thanh', 'thanh']
# ['lần xem cảnh có'] ---> phong
# ['lần', 'xem', 'phong', 'cảnh', 'có', 'bề', 'thanh', 'thanh']
# ['xem phong có bề'] ---> cảnh
# ['lần', 'xem', 'phong', 'cảnh', 'có', 'bề', 'thanh', 'thanh']
# ['phong cảnh bề thanh'] ---> có
# ['lần', 'xem', 'phong', 'cảnh', 'có', 'bề', 'thanh', 'thanh']
# ['cảnh có thanh thanh'] ---> bề
# ['nao', 'nao', 'dòng', 'nước', 'uốn', 'quanh']
# ['nao nao nước uốn'] ---> dòng
# ['nao', 'nao', 'dòng', 'nước', 'uốn', 'quanh']
# ['nao dòng uốn quanh'] ---> nước
# ['dịp', 'cầu', 'nho', 'nhỏ', 'cuối', 'ghềnh', 'bắc', 'ngang']
# ['dịp cầu nhỏ cuối'] ---> nho
# ['dịp', 'cầu', 'nho', 'nhỏ', 'cuối', 'ghềnh', 'bắc', 'ngang']
# ['cầu nho cuối ghềnh'] ---> nhỏ
# ['dịp', 'cầu', 'nho', 'nhỏ', 'cuối', 'ghềnh', 'bắc', 'ngang']
# ['nho nhỏ ghềnh bắc'] ---> cuối
# ['dịp', 'cầu', 'nho', 'nhỏ', 'cuối', 'ghềnh', 'bắc', 'ngang']
# ['nhỏ cuối bắc ngang'] ---> ghềnh
# ['sè', 'sè', 'nấm', 'đất', 'bên', 'đàng']
# ['sè sè đất bên'] ---> nấm
# ['sè', 'sè', 'nấm', 'đất', 'bên', 'đàng']
# ['sè nấm bên đàng'] ---> đất
# ['dàu', 'dàu', 'ngọn', 'cỏ', 'nửa', 'vàng', 'nửa', 'xanh']
# ['dàu dàu cỏ nửa'] ---> ngọn
# ['dàu', 'dàu', 'ngọn', 'cỏ', 'nửa', 'vàng', 'nửa', 'xanh']
# ['dàu ngọn nửa vàng'] ---> cỏ
# ['dàu', 'dàu', 'ngọn', 'cỏ', 'nửa', 'vàng', 'nửa', 'xanh']
# ['ngọn cỏ vàng nửa'] ---> nửa
# ['dàu', 'dàu', 'ngọn', 'cỏ', 'nửa', 'vàng', 'nửa', 'xanh']
# ['cỏ nửa nửa xanh'] ---> vàng
# ['rằng', 'sao', 'trong', 'tiết', 'thanh', 'minh']
# ['rằng sao tiết thanh'] ---> trong
# ['rằng', 'sao', 'trong', 'tiết', 'thanh', 'minh']
# ['sao trong thanh minh'] ---> tiết
# ['mà', 'đây', 'hương', 'khói', 'vắng', 'tanh', 'thế', 'mà']
# ['mà đây khói vắng'] ---> hương
# ['mà', 'đây', 'hương', 'khói', 'vắng', 'tanh', 'thế', 'mà']
# ['đây hương vắng tanh'] ---> khói
# ['mà', 'đây', 'hương', 'khói', 'vắng', 'tanh', 'thế', 'mà']
# ['hương khói tanh thế'] ---> vắng
# ['mà', 'đây', 'hương', 'khói', 'vắng', 'tanh', 'thế', 'mà']
# ['khói vắng thế mà'] ---> tanh
# ['vương', 'quan', 'mới', 'dẫn', 'gần', 'xa']
# ['vương quan dẫn gần'] ---> mới
# ['vương', 'quan', 'mới', 'dẫn', 'gần', 'xa']
# ['quan mới gần xa'] ---> dẫn
# ['đạm', 'tiên', 'nàng', 'ấy', 'xưa', 'là', 'ca', 'nhi']
# ['đạm tiên ấy xưa'] ---> nàng
# ['đạm', 'tiên', 'nàng', 'ấy', 'xưa', 'là', 'ca', 'nhi']
# ['tiên nàng xưa là'] ---> ấy
# ['đạm', 'tiên', 'nàng', 'ấy', 'xưa', 'là', 'ca', 'nhi']
# ['nàng ấy là ca'] ---> xưa
# ['đạm', 'tiên', 'nàng', 'ấy', 'xưa', 'là', 'ca', 'nhi']
# ['ấy xưa ca nhi'] ---> là
# ['nổi', 'danh', 'tài', 'sắc', 'một', 'thì']
# ['nổi danh sắc một'] ---> tài
# ['nổi', 'danh', 'tài', 'sắc', 'một', 'thì']
# ['danh tài một thì'] ---> sắc
# ['xôn', 'xao', 'ngoài', 'cửa', 'hiếm', 'gì', 'yến', 'anh']
# ['xôn xao cửa hiếm'] ---> ngoài
# ['xôn', 'xao', 'ngoài', 'cửa', 'hiếm', 'gì', 'yến', 'anh']
# ['xao ngoài hiếm gì'] ---> cửa
# ['xôn', 'xao', 'ngoài', 'cửa', 'hiếm', 'gì', 'yến', 'anh']
# ['ngoài cửa gì yến'] ---> hiếm
# ['xôn', 'xao', 'ngoài', 'cửa', 'hiếm', 'gì', 'yến', 'anh']
# ['cửa hiếm yến anh'] ---> gì
# ['kiếp', 'hồng', 'nhan', 'có', 'mong', 'manh']
# ['kiếp hồng có mong'] ---> nhan
# ['kiếp', 'hồng', 'nhan', 'có', 'mong', 'manh']
# ['hồng nhan mong manh'] ---> có
# ['nửa', 'chừng', 'xuân', 'thoắt', 'gãy', 'cành', 'thiên', 'hương']
# ['nửa chừng thoắt gãy'] ---> xuân
# ['nửa', 'chừng', 'xuân', 'thoắt', 'gãy', 'cành', 'thiên', 'hương']
# ['chừng xuân gãy cành'] ---> thoắt
# ['nửa', 'chừng', 'xuân', 'thoắt', 'gãy', 'cành', 'thiên', 'hương']
# ['xuân thoắt cành thiên'] ---> gãy
# ['nửa', 'chừng', 'xuân', 'thoắt', 'gãy', 'cành', 'thiên', 'hương']
# ['thoắt gãy thiên hương'] ---> cành
# ['có', 'người', 'khách', 'ở', 'viễn', 'phương']
# ['có người ở viễn'] ---> khách
# ['có', 'người', 'khách', 'ở', 'viễn', 'phương']
# ['người khách viễn phương'] ---> ở
# ['xa', 'nghe', 'cũng', 'nức', 'tiếng', 'nàng', 'tìm', 'chơi']
# ['xa nghe nức tiếng'] ---> cũng
# ['xa', 'nghe', 'cũng', 'nức', 'tiếng', 'nàng', 'tìm', 'chơi']
# ['nghe cũng tiếng nàng'] ---> nức
# ['xa', 'nghe', 'cũng', 'nức', 'tiếng', 'nàng', 'tìm', 'chơi']
# ['cũng nức nàng tìm'] ---> tiếng
# ['xa', 'nghe', 'cũng', 'nức', 'tiếng', 'nàng', 'tìm', 'chơi']
# ['nức tiếng tìm chơi'] ---> nàng
# ['thuyền', 'tình', 'vừa', 'ghé', 'tới', 'nơi']
# ['thuyền tình ghé tới'] ---> vừa
# ['thuyền', 'tình', 'vừa', 'ghé', 'tới', 'nơi']
# ['tình vừa tới nơi'] ---> ghé
# ['thì', 'đà', 'trâm', 'gẫy', 'bình', 'rơi', 'bao', 'giờ']
# ['thì đà gẫy bình'] ---> trâm
# ['thì', 'đà', 'trâm', 'gẫy', 'bình', 'rơi', 'bao', 'giờ']
# ['đà trâm bình rơi'] ---> gẫy
# ['thì', 'đà', 'trâm', 'gẫy', 'bình', 'rơi', 'bao', 'giờ']
# ['trâm gẫy rơi bao'] ---> bình
# ['thì', 'đà', 'trâm', 'gẫy', 'bình', 'rơi', 'bao', 'giờ']
# ['gẫy bình bao giờ'] ---> rơi
# ['buồng', 'không', 'lạnh', 'ngắt', 'như', 'tờ']
# ['buồng không ngắt như'] ---> lạnh
# ['buồng', 'không', 'lạnh', 'ngắt', 'như', 'tờ']
# ['không lạnh như tờ'] ---> ngắt
# ['dấu', 'xe', 'ngựa', 'đã', 'rêu', 'lờ', 'mờ', 'xanh']
# ['dấu xe đã rêu'] ---> ngựa
# ['dấu', 'xe', 'ngựa', 'đã', 'rêu', 'lờ', 'mờ', 'xanh']
# ['xe ngựa rêu lờ'] ---> đã
# ['dấu', 'xe', 'ngựa', 'đã', 'rêu', 'lờ', 'mờ', 'xanh']
# ['ngựa đã lờ mờ'] ---> rêu
# ['dấu', 'xe', 'ngựa', 'đã', 'rêu', 'lờ', 'mờ', 'xanh']
# ['đã rêu mờ xanh'] ---> lờ
# ['khóc', 'than', 'khôn', 'xiết', 'sự', 'tình']
# ['khóc than xiết sự'] ---> khôn
# ['khóc', 'than', 'khôn', 'xiết', 'sự', 'tình']
# ['than khôn sự tình'] ---> xiết
# ['khéo', 'vô', 'duyên', 'ấy', 'là', 'mình', 'với', 'ta']
# ['khéo vô ấy là'] ---> duyên
# ['khéo', 'vô', 'duyên', 'ấy', 'là', 'mình', 'với', 'ta']
# ['vô duyên là mình'] ---> ấy
# ['khéo', 'vô', 'duyên', 'ấy', 'là', 'mình', 'với', 'ta']
# ['duyên ấy mình với'] ---> là
# ['khéo', 'vô', 'duyên', 'ấy', 'là', 'mình', 'với', 'ta']
# ['ấy là với ta'] ---> mình
# ['đã', 'không', 'duyên', 'trước', 'chăng', 'mà']
# ['đã không trước chăng'] ---> duyên
# ['đã', 'không', 'duyên', 'trước', 'chăng', 'mà']
# ['không duyên chăng mà'] ---> trước
# ['thì', 'chi', 'chút', 'ước', 'gọi', 'là', 'duyên', 'sau']
# ['thì chi ước gọi'] ---> chút
# ['thì', 'chi', 'chút', 'ước', 'gọi', 'là', 'duyên', 'sau']
# ['chi chút gọi là'] ---> ước
# ['thì', 'chi', 'chút', 'ước', 'gọi', 'là', 'duyên', 'sau']
# ['chút ước là duyên'] ---> gọi
# ['thì', 'chi', 'chút', 'ước', 'gọi', 'là', 'duyên', 'sau']
# ['ước gọi duyên sau'] ---> là
# ['sắm', 'xanh', 'nếp', 'tử', 'xe', 'trâu']
# ['sắm xanh tử xe'] ---> nếp
# ['sắm', 'xanh', 'nếp', 'tử', 'xe', 'trâu']
# ['xanh nếp xe trâu'] ---> tử
# ['vùi', 'nông', 'một', 'nấm', 'mặc', 'dầu', 'cỏ', 'hoa']
# ['vùi nông nấm mặc'] ---> một
# ['vùi', 'nông', 'một', 'nấm', 'mặc', 'dầu', 'cỏ', 'hoa']
# ['nông một mặc dầu'] ---> nấm
# ['vùi', 'nông', 'một', 'nấm', 'mặc', 'dầu', 'cỏ', 'hoa']
# ['một nấm dầu cỏ'] ---> mặc
# ['vùi', 'nông', 'một', 'nấm', 'mặc', 'dầu', 'cỏ', 'hoa']
# ['nấm mặc cỏ hoa'] ---> dầu
# ['trải', 'bao', 'thỏ', 'lặn', 'ác', 'tà']
# ['trải bao lặn ác'] ---> thỏ
# ['trải', 'bao', 'thỏ', 'lặn', 'ác', 'tà']
# ['bao thỏ ác tà'] ---> lặn
# ['ấy', 'mồ', 'vô', 'chủ', 'ai', 'mà', 'viếng', 'thăm']
# ['ấy mồ chủ ai'] ---> vô
# ['ấy', 'mồ', 'vô', 'chủ', 'ai', 'mà', 'viếng', 'thăm']
# ['mồ vô ai mà'] ---> chủ
# ['ấy', 'mồ', 'vô', 'chủ', 'ai', 'mà', 'viếng', 'thăm']
# ['vô chủ mà viếng'] ---> ai
# ['ấy', 'mồ', 'vô', 'chủ', 'ai', 'mà', 'viếng', 'thăm']
# ['chủ ai viếng thăm'] ---> mà
# ['lòng', 'đâu', 'sẵn', 'mối', 'thương', 'tâm']
# ['lòng đâu mối thương'] ---> sẵn
# ['lòng', 'đâu', 'sẵn', 'mối', 'thương', 'tâm']
# ['đâu sẵn thương tâm'] ---> mối
# ['thoắt', 'nghe', 'kiều', 'đã', 'đầm', 'đầm', 'châu', 'sa']
# ['thoắt nghe đã đầm'] ---> kiều
# ['thoắt', 'nghe', 'kiều', 'đã', 'đầm', 'đầm', 'châu', 'sa']
# ['nghe kiều đầm đầm'] ---> đã
# ['thoắt', 'nghe', 'kiều', 'đã', 'đầm', 'đầm', 'châu', 'sa']
# ['kiều đã đầm châu'] ---> đầm
# ['thoắt', 'nghe', 'kiều', 'đã', 'đầm', 'đầm', 'châu', 'sa']
# ['đã đầm châu sa'] ---> đầm
# ['đau', 'đớn', 'thay', 'phận', 'đàn', 'bà']
# ['đau đớn phận đàn'] ---> thay
# ['đau', 'đớn', 'thay', 'phận', 'đàn', 'bà']
# ['đớn thay đàn bà'] ---> phận
# ['lời', 'rằng', 'bạc', 'mệnh', 'cũng', 'là', 'lời', 'chung']
# ['lời rằng mệnh cũng'] ---> bạc
# ['lời', 'rằng', 'bạc', 'mệnh', 'cũng', 'là', 'lời', 'chung']
# ['rằng bạc cũng là'] ---> mệnh
# ['lời', 'rằng', 'bạc', 'mệnh', 'cũng', 'là', 'lời', 'chung']
# ['bạc mệnh là lời'] ---> cũng
# ['lời', 'rằng', 'bạc', 'mệnh', 'cũng', 'là', 'lời', 'chung']
# ['mệnh cũng lời chung'] ---> là
# ['phũ', 'phàng', 'chi', 'bấy', 'hoá', 'công']
# ['phũ phàng bấy hoá'] ---> chi
# ['phũ', 'phàng', 'chi', 'bấy', 'hoá', 'công']
# ['phàng chi hoá công'] ---> bấy
# ['ngày', 'xanh', 'mòn', 'mỏi', 'má', 'hồng', 'phôi', 'pha']
# ['ngày xanh mỏi má'] ---> mòn
# ['ngày', 'xanh', 'mòn', 'mỏi', 'má', 'hồng', 'phôi', 'pha']
# ['xanh mòn má hồng'] ---> mỏi
# ['ngày', 'xanh', 'mòn', 'mỏi', 'má', 'hồng', 'phôi', 'pha']
# ['mòn mỏi hồng phôi'] ---> má
# ['ngày', 'xanh', 'mòn', 'mỏi', 'má', 'hồng', 'phôi', 'pha']
# ['mỏi má phôi pha'] ---> hồng
# ['sống', 'làm', 'vợ', 'khắp', 'người', 'ta']
# ['sống làm khắp người'] ---> vợ
# ['sống', 'làm', 'vợ', 'khắp', 'người', 'ta']
# ['làm vợ người ta'] ---> khắp
# ['khéo', 'thay', 'thác', 'xuống', 'làm', 'ma', 'không', 'chồng']
# ['khéo thay xuống làm'] ---> thác
# ['khéo', 'thay', 'thác', 'xuống', 'làm', 'ma', 'không', 'chồng']
# ['thay thác làm ma'] ---> xuống
# ['khéo', 'thay', 'thác', 'xuống', 'làm', 'ma', 'không', 'chồng']
# ['thác xuống ma không'] ---> làm
# ['khéo', 'thay', 'thác', 'xuống', 'làm', 'ma', 'không', 'chồng']
# ['xuống làm không chồng'] ---> ma
# ['nào', 'người', 'phượng', 'chạ', 'loan', 'chung']
# ['nào người chạ loan'] ---> phượng
# ['nào', 'người', 'phượng', 'chạ', 'loan', 'chung']
# ['người phượng loan chung'] ---> chạ
# ['nào', 'người', 'tích', 'lục', 'tham', 'hồng', 'là', 'ai']
# ['nào người lục tham'] ---> tích
# ['nào', 'người', 'tích', 'lục', 'tham', 'hồng', 'là', 'ai']
# ['người tích tham hồng'] ---> lục
# ['nào', 'người', 'tích', 'lục', 'tham', 'hồng', 'là', 'ai']
# ['tích lục hồng là'] ---> tham
# ['nào', 'người', 'tích', 'lục', 'tham', 'hồng', 'là', 'ai']
# ['lục tham là ai'] ---> hồng
# ['đã', 'không', 'kẻ', 'đoái', 'người', 'hoài']
# ['đã không đoái người'] ---> kẻ
# ['đã', 'không', 'kẻ', 'đoái', 'người', 'hoài']
# ['không kẻ người hoài'] ---> đoái
# ['sẵn', 'đây', 'ta', 'kiếm', 'một', 'vài', 'nén', 'hương']
# ['sẵn đây kiếm một'] ---> ta
# ['sẵn', 'đây', 'ta', 'kiếm', 'một', 'vài', 'nén', 'hương']
# ['đây ta một vài'] ---> kiếm
# ['sẵn', 'đây', 'ta', 'kiếm', 'một', 'vài', 'nén', 'hương']
# ['ta kiếm vài nén'] ---> một
# ['sẵn', 'đây', 'ta', 'kiếm', 'một', 'vài', 'nén', 'hương']
# ['kiếm một nén hương'] ---> vài
# ['gọi', 'là', 'gặp', 'gỡ', 'giữa', 'đường']
# ['gọi là gỡ giữa'] ---> gặp
# ['gọi', 'là', 'gặp', 'gỡ', 'giữa', 'đường']
# ['là gặp giữa đường'] ---> gỡ
# ['họa', 'là', 'người', 'dưới', 'suối', 'vàng', 'biết', 'cho']
# ['họa là dưới suối'] ---> người
# ['họa', 'là', 'người', 'dưới', 'suối', 'vàng', 'biết', 'cho']
# ['là người suối vàng'] ---> dưới
# ['họa', 'là', 'người', 'dưới', 'suối', 'vàng', 'biết', 'cho']
# ['người dưới vàng biết'] ---> suối
# ['họa', 'là', 'người', 'dưới', 'suối', 'vàng', 'biết', 'cho']
# ['dưới suối biết cho'] ---> vàng
# ['lầm', 'rầm', 'khấn', 'khứa', 'nhỏ', 'to']
# ['lầm rầm khứa nhỏ'] ---> khấn
# ['lầm', 'rầm', 'khấn', 'khứa', 'nhỏ', 'to']
# ['rầm khấn nhỏ to'] ---> khứa
# ['sụp', 'ngồi', 'vài', 'gật', 'trước', 'mồ', 'bước', 'ra']
# ['sụp ngồi gật trước'] ---> vài
# ['sụp', 'ngồi', 'vài', 'gật', 'trước', 'mồ', 'bước', 'ra']
# ['ngồi vài trước mồ'] ---> gật
# ['sụp', 'ngồi', 'vài', 'gật', 'trước', 'mồ', 'bước', 'ra']
# ['vài gật mồ bước'] ---> trước
# ['sụp', 'ngồi', 'vài', 'gật', 'trước', 'mồ', 'bước', 'ra']
# ['gật trước bước ra'] ---> mồ
# ['một', 'vùng', 'cỏ', 'áy', 'bóng', 'tà']
# ['một vùng áy bóng'] ---> cỏ
# ['một', 'vùng', 'cỏ', 'áy', 'bóng', 'tà']
# ['vùng cỏ bóng tà'] ---> áy
# ['gió', 'hiu', 'hiu', 'thổi', 'một', 'vài', 'bông', 'lau']
# ['gió hiu thổi một'] ---> hiu
# ['gió', 'hiu', 'hiu', 'thổi', 'một', 'vài', 'bông', 'lau']
# ['hiu hiu một vài'] ---> thổi
# ['gió', 'hiu', 'hiu', 'thổi', 'một', 'vài', 'bông', 'lau']
# ['hiu thổi vài bông'] ---> một
# ['gió', 'hiu', 'hiu', 'thổi', 'một', 'vài', 'bông', 'lau']
# ['thổi một bông lau'] ---> vài
# ['rút', 'trâm', 'sẵn', 'giắt', 'mái', 'đầu']
# ['rút trâm giắt mái'] ---> sẵn
# ['rút', 'trâm', 'sẵn', 'giắt', 'mái', 'đầu']
# ['trâm sẵn mái đầu'] ---> giắt
# ['vạch', 'da', 'cây', 'vịnh', 'bốn', 'câu', 'ba', 'vần']
# ['vạch da vịnh bốn'] ---> cây
# ['vạch', 'da', 'cây', 'vịnh', 'bốn', 'câu', 'ba', 'vần']
# ['da cây bốn câu'] ---> vịnh
# ['vạch', 'da', 'cây', 'vịnh', 'bốn', 'câu', 'ba', 'vần']
# ['cây vịnh câu ba'] ---> bốn
# ['vạch', 'da', 'cây', 'vịnh', 'bốn', 'câu', 'ba', 'vần']
# ['vịnh bốn ba vần'] ---> câu
# ['lại', 'càng', 'mê', 'mẩn', 'tâm', 'thần']
# ['lại càng mẩn tâm'] ---> mê
# ['lại', 'càng', 'mê', 'mẩn', 'tâm', 'thần']
# ['càng mê tâm thần'] ---> mẩn
# ['lại', 'càng', 'đứng', 'lặng', 'tần', 'ngần', 'chẳng', 'ra']
# ['lại càng lặng tần'] ---> đứng
# ['lại', 'càng', 'đứng', 'lặng', 'tần', 'ngần', 'chẳng', 'ra']
# ['càng đứng tần ngần'] ---> lặng
# ['lại', 'càng', 'đứng', 'lặng', 'tần', 'ngần', 'chẳng', 'ra']
# ['đứng lặng ngần chẳng'] ---> tần
# ['lại', 'càng', 'đứng', 'lặng', 'tần', 'ngần', 'chẳng', 'ra']
# ['lặng tần chẳng ra'] ---> ngần
# ['lại', 'càng', 'ủ', 'dột', 'nét', 'hoa']
# ['lại càng dột nét'] ---> ủ
# ['lại', 'càng', 'ủ', 'dột', 'nét', 'hoa']
# ['càng ủ nét hoa'] ---> dột
# ['sầu', 'tuôn', 'đứt', 'nối', 'châu', 'sa', 'vắn', 'dài']
# ['sầu tuôn nối châu'] ---> đứt
# ['sầu', 'tuôn', 'đứt', 'nối', 'châu', 'sa', 'vắn', 'dài']
# ['tuôn đứt châu sa'] ---> nối
# ['sầu', 'tuôn', 'đứt', 'nối', 'châu', 'sa', 'vắn', 'dài']
# ['đứt nối sa vắn'] ---> châu
# ['sầu', 'tuôn', 'đứt', 'nối', 'châu', 'sa', 'vắn', 'dài']
# ['nối châu vắn dài'] ---> sa
# ['vân', 'rằng', 'chị', 'cũng', 'nực', 'cười']
# ['vân rằng cũng nực'] ---> chị
# ['vân', 'rằng', 'chị', 'cũng', 'nực', 'cười']
# ['rằng chị nực cười'] ---> cũng
# ['khéo', 'dư', 'nước', 'mắt', 'khóc', 'người', 'đời', 'xưa']
# ['khéo dư mắt khóc'] ---> nước
# ['khéo', 'dư', 'nước', 'mắt', 'khóc', 'người', 'đời', 'xưa']
# ['dư nước khóc người'] ---> mắt
# ['khéo', 'dư', 'nước', 'mắt', 'khóc', 'người', 'đời', 'xưa']
# ['nước mắt người đời'] ---> khóc
# ['khéo', 'dư', 'nước', 'mắt', 'khóc', 'người', 'đời', 'xưa']
# ['mắt khóc đời xưa'] ---> người
# ['rằng', 'hồng', 'nhan', 'tự', 'thuở', 'xưa']
# ['rằng hồng tự thuở'] ---> nhan
# ['rằng', 'hồng', 'nhan', 'tự', 'thuở', 'xưa']
# ['hồng nhan thuở xưa'] ---> tự
# ['cái', 'điều', 'bạc', 'mệnh', 'có', 'chừa', 'ai', 'đâu']
# ['cái điều mệnh có'] ---> bạc
# ['cái', 'điều', 'bạc', 'mệnh', 'có', 'chừa', 'ai', 'đâu']
# ['điều bạc có chừa'] ---> mệnh
# ['cái', 'điều', 'bạc', 'mệnh', 'có', 'chừa', 'ai', 'đâu']
# ['bạc mệnh chừa ai'] ---> có
# ['cái', 'điều', 'bạc', 'mệnh', 'có', 'chừa', 'ai', 'đâu']
# ['mệnh có ai đâu'] ---> chừa
# ['nỗi', 'niềm', 'tưởng', 'đến', 'mà', 'đau']
# ['nỗi niềm đến mà'] ---> tưởng
# ['nỗi', 'niềm', 'tưởng', 'đến', 'mà', 'đau']
# ['niềm tưởng mà đau'] ---> đến
# ['thấy', 'người', 'nằm', 'đó', 'biết', 'sau', 'thế', 'nào']
# ['thấy người đó biết'] ---> nằm
# ['thấy', 'người', 'nằm', 'đó', 'biết', 'sau', 'thế', 'nào']
# ['người nằm biết sau'] ---> đó
# ['thấy', 'người', 'nằm', 'đó', 'biết', 'sau', 'thế', 'nào']
# ['nằm đó sau thế'] ---> biết
# ['thấy', 'người', 'nằm', 'đó', 'biết', 'sau', 'thế', 'nào']
# ['đó biết thế nào'] ---> sau
# ['quan', 'rằng', 'chị', 'nói', 'hay', 'sao']
# ['quan rằng nói hay'] ---> chị
# ['quan', 'rằng', 'chị', 'nói', 'hay', 'sao']
# ['rằng chị hay sao'] ---> nói
# ['một', 'lời', 'là', 'một', 'vận', 'vào', 'khó', 'nghe']
# ['một lời một vận'] ---> là
# ['một', 'lời', 'là', 'một', 'vận', 'vào', 'khó', 'nghe']
# ['lời là vận vào'] ---> một
# ['một', 'lời', 'là', 'một', 'vận', 'vào', 'khó', 'nghe']
# ['là một vào khó'] ---> vận
# ['một', 'lời', 'là', 'một', 'vận', 'vào', 'khó', 'nghe']
# ['một vận khó nghe'] ---> vào
# ['ở', 'đây', 'âm', 'khí', 'nặng', 'nề']
# ['ở đây khí nặng'] ---> âm
# ['ở', 'đây', 'âm', 'khí', 'nặng', 'nề']
# ['đây âm nặng nề'] ---> khí
# ['bóng', 'chiều', 'đã', 'ngả', 'dậm', 'về', 'còn', 'xa']
# ['bóng chiều ngả dậm'] ---> đã
# ['bóng', 'chiều', 'đã', 'ngả', 'dậm', 'về', 'còn', 'xa']
# ['chiều đã dậm về'] ---> ngả
# ['bóng', 'chiều', 'đã', 'ngả', 'dậm', 'về', 'còn', 'xa']
# ['đã ngả về còn'] ---> dậm
# ['bóng', 'chiều', 'đã', 'ngả', 'dậm', 'về', 'còn', 'xa']
# ['ngả dậm còn xa'] ---> về
# ['kiều', 'rằng', 'những', 'đấng', 'tài', 'hoa']
# ['kiều rằng đấng tài'] ---> những
# ['kiều', 'rằng', 'những', 'đấng', 'tài', 'hoa']
# ['rằng những tài hoa'] ---> đấng
# ['thác', 'là', 'thể', 'phách', 'còn', 'là', 'tinh', 'anh']
# ['thác là phách còn'] ---> thể
# ['thác', 'là', 'thể', 'phách', 'còn', 'là', 'tinh', 'anh']
# ['là thể còn là'] ---> phách
# ['thác', 'là', 'thể', 'phách', 'còn', 'là', 'tinh', 'anh']
# ['thể phách là tinh'] ---> còn
# ['thác', 'là', 'thể', 'phách', 'còn', 'là', 'tinh', 'anh']
# ['phách còn tinh anh'] ---> là
# ['dễ', 'hay', 'tình', 'lại', 'gặp', 'tình']
# ['dễ hay lại gặp'] ---> tình
# ['dễ', 'hay', 'tình', 'lại', 'gặp', 'tình']
# ['hay tình gặp tình'] ---> lại
# ['chờ', 'xem', 'ắt', 'thấy', 'hiển', 'linh', 'bây', 'giờ']
# ['chờ xem thấy hiển'] ---> ắt
# ['chờ', 'xem', 'ắt', 'thấy', 'hiển', 'linh', 'bây', 'giờ']
# ['xem ắt hiển linh'] ---> thấy
# ['chờ', 'xem', 'ắt', 'thấy', 'hiển', 'linh', 'bây', 'giờ']
# ['ắt thấy linh bây'] ---> hiển
# ['chờ', 'xem', 'ắt', 'thấy', 'hiển', 'linh', 'bây', 'giờ']
# ['thấy hiển bây giờ'] ---> linh
# ['một', 'lời', 'nói', 'chửa', 'kịp', 'thưa']
# ['một lời chửa kịp'] ---> nói
# ['một', 'lời', 'nói', 'chửa', 'kịp', 'thưa']
# ['lời nói kịp thưa'] ---> chửa
# ['thoắt', 'đâu', 'trận', 'gió', 'cuốn', 'cờ', 'đến', 'ngay']
# ['thoắt đâu gió cuốn'] ---> trận
# ['thoắt', 'đâu', 'trận', 'gió', 'cuốn', 'cờ', 'đến', 'ngay']
# ['đâu trận cuốn cờ'] ---> gió
# ['thoắt', 'đâu', 'trận', 'gió', 'cuốn', 'cờ', 'đến', 'ngay']
# ['trận gió cờ đến'] ---> cuốn
# ['thoắt', 'đâu', 'trận', 'gió', 'cuốn', 'cờ', 'đến', 'ngay']
# ['gió cuốn đến ngay'] ---> cờ
# ['ào', 'ào', 'đổ', 'lộc', 'rung', 'cây']
# ['ào ào lộc rung'] ---> đổ
# ['ào', 'ào', 'đổ', 'lộc', 'rung', 'cây']
# ['ào đổ rung cây'] ---> lộc
# ['ở', 'trong', 'dường', 'có', 'hương', 'bay', 'ít', 'nhiều']
# ['ở trong có hương'] ---> dường
# ['ở', 'trong', 'dường', 'có', 'hương', 'bay', 'ít', 'nhiều']
# ['trong dường hương bay'] ---> có
# ['ở', 'trong', 'dường', 'có', 'hương', 'bay', 'ít', 'nhiều']
# ['dường có bay ít'] ---> hương
# ['ở', 'trong', 'dường', 'có', 'hương', 'bay', 'ít', 'nhiều']
# ['có hương ít nhiều'] ---> bay
# ['đè', 'chừng', 'ngọn', 'gió', 'lần', 'theo']
# ['đè chừng gió lần'] ---> ngọn
# ['đè', 'chừng', 'ngọn', 'gió', 'lần', 'theo']
# ['chừng ngọn lần theo'] ---> gió
# ['dấu', 'giày', 'từng', 'bước', 'in', 'rêu', 'rành', 'rành']
# ['dấu giày bước in'] ---> từng
# ['dấu', 'giày', 'từng', 'bước', 'in', 'rêu', 'rành', 'rành']
# ['giày từng in rêu'] ---> bước
# ['dấu', 'giày', 'từng', 'bước', 'in', 'rêu', 'rành', 'rành']
# ['từng bước rêu rành'] ---> in
# ['dấu', 'giày', 'từng', 'bước', 'in', 'rêu', 'rành', 'rành']
# ['bước in rành rành'] ---> rêu
# ['mắt', 'nhìn', 'ai', 'nấy', 'đều', 'kinh']
# ['mắt nhìn nấy đều'] ---> ai
# ['mắt', 'nhìn', 'ai', 'nấy', 'đều', 'kinh']
# ['nhìn ai đều kinh'] ---> nấy
# ['nàng', 'rằng', 'này', 'thực', 'tinh', 'thành', 'chẳng', 'xa']
# ['nàng rằng thực tinh'] ---> này
# ['nàng', 'rằng', 'này', 'thực', 'tinh', 'thành', 'chẳng', 'xa']
# ['rằng này tinh thành'] ---> thực
# ['nàng', 'rằng', 'này', 'thực', 'tinh', 'thành', 'chẳng', 'xa']
# ['này thực thành chẳng'] ---> tinh
# ['nàng', 'rằng', 'này', 'thực', 'tinh', 'thành', 'chẳng', 'xa']
# ['thực tinh chẳng xa'] ---> thành
# ['hữu', 'tình', 'ta', 'lại', 'gặp', 'ta']
# ['hữu tình lại gặp'] ---> ta
# ['hữu', 'tình', 'ta', 'lại', 'gặp', 'ta']
# ['tình ta gặp ta'] ---> lại
# ['chớ', 'nề', 'u', 'hiển', 'mới', 'là', 'chị', 'em']
# ['chớ nề hiển mới'] ---> u
# ['chớ', 'nề', 'u', 'hiển', 'mới', 'là', 'chị', 'em']
# ['nề u mới là'] ---> hiển
# ['chớ', 'nề', 'u', 'hiển', 'mới', 'là', 'chị', 'em']
# ['u hiển là chị'] ---> mới
# ['chớ', 'nề', 'u', 'hiển', 'mới', 'là', 'chị', 'em']
# ['hiển mới chị em'] ---> là
# ['đã', 'lòng', 'hiển', 'hiện', 'cho', 'xem']
# ['đã lòng hiện cho'] ---> hiển
# ['đã', 'lòng', 'hiển', 'hiện', 'cho', 'xem']
# ['lòng hiển cho xem'] ---> hiện
# ['tạ', 'lòng', 'nàng', 'lại', 'nối', 'thêm', 'vài', 'lời']
# ['tạ lòng lại nối'] ---> nàng
# ['tạ', 'lòng', 'nàng', 'lại', 'nối', 'thêm', 'vài', 'lời']
# ['lòng nàng nối thêm'] ---> lại
# ['tạ', 'lòng', 'nàng', 'lại', 'nối', 'thêm', 'vài', 'lời']
# ['nàng lại thêm vài'] ---> nối
# ['tạ', 'lòng', 'nàng', 'lại', 'nối', 'thêm', 'vài', 'lời']
# ['lại nối vài lời'] ---> thêm
# ['lòng', 'thơ', 'lai', 'láng', 'bồi', 'hồi']
# ['lòng thơ láng bồi'] ---> lai
# ['lòng', 'thơ', 'lai', 'láng', 'bồi', 'hồi']
# ['thơ lai bồi hồi'] ---> láng
# ['gốc', 'cây', 'lại', 'vạch', 'một', 'bài', 'cổ', 'thi']
# ['gốc cây vạch một'] ---> lại
# ['gốc', 'cây', 'lại', 'vạch', 'một', 'bài', 'cổ', 'thi']
# ['cây lại một bài'] ---> vạch
# ['gốc', 'cây', 'lại', 'vạch', 'một', 'bài', 'cổ', 'thi']
# ['lại vạch bài cổ'] ---> một
# ['gốc', 'cây', 'lại', 'vạch', 'một', 'bài', 'cổ', 'thi']
# ['vạch một cổ thi'] ---> bài
# ['dùng', 'dằng', 'nửa', 'ở', 'nửa', 'về']
# ['dùng dằng ở nửa'] ---> nửa
# ['dùng', 'dằng', 'nửa', 'ở', 'nửa', 'về']
# ['dằng nửa nửa về'] ---> ở
# ['nhạc', 'vàng', 'đâu', 'đã', 'tiếng', 'nghe', 'gần', 'gần']
# ['nhạc vàng đã tiếng'] ---> đâu
# ['nhạc', 'vàng', 'đâu', 'đã', 'tiếng', 'nghe', 'gần', 'gần']
# ['vàng đâu tiếng nghe'] ---> đã
# ['nhạc', 'vàng', 'đâu', 'đã', 'tiếng', 'nghe', 'gần', 'gần']
# ['đâu đã nghe gần'] ---> tiếng
# ['nhạc', 'vàng', 'đâu', 'đã', 'tiếng', 'nghe', 'gần', 'gần']
# ['đã tiếng gần gần'] ---> nghe
# ['trông', 'chừng', 'thấy', 'một', 'văn', 'nhân']
# ['trông chừng một văn'] ---> thấy
# ['trông', 'chừng', 'thấy', 'một', 'văn', 'nhân']
# ['chừng thấy văn nhân'] ---> một
# ['lỏng', 'buông', 'tay', 'khấu', 'bước', 'lần', 'dặm', 'băng']
# ['lỏng buông khấu bước'] ---> tay
# ['lỏng', 'buông', 'tay', 'khấu', 'bước', 'lần', 'dặm', 'băng']
# ['buông tay bước lần'] ---> khấu
# ['lỏng', 'buông', 'tay', 'khấu', 'bước', 'lần', 'dặm', 'băng']
# ['tay khấu lần dặm'] ---> bước
# ['lỏng', 'buông', 'tay', 'khấu', 'bước', 'lần', 'dặm', 'băng']
# ['khấu bước dặm băng'] ---> lần
# ['đề', 'huề', 'lưng', 'túi', 'gió', 'trăng']
# ['đề huề túi gió'] ---> lưng
# ['đề', 'huề', 'lưng', 'túi', 'gió', 'trăng']
# ['huề lưng gió trăng'] ---> túi
# ['sau', 'chân', 'theo', 'một', 'vài', 'thằng', 'con', 'con']
# ['sau chân một vài'] ---> theo
# ['sau', 'chân', 'theo', 'một', 'vài', 'thằng', 'con', 'con']
# ['chân theo vài thằng'] ---> một
# ['sau', 'chân', 'theo', 'một', 'vài', 'thằng', 'con', 'con']
# ['theo một thằng con'] ---> vài
# ['sau', 'chân', 'theo', 'một', 'vài', 'thằng', 'con', 'con']
# ['một vài con con'] ---> thằng
# ['tuyết', 'in', 'sắc', 'ngựa', 'câu', 'giòn']
# ['tuyết in ngựa câu'] ---> sắc
# ['tuyết', 'in', 'sắc', 'ngựa', 'câu', 'giòn']
# ['in sắc câu giòn'] ---> ngựa
# ['cỏ', 'pha', 'màu', 'áo', 'nhuộm', 'non', 'da', 'trời']
# ['cỏ pha áo nhuộm'] ---> màu
# ['cỏ', 'pha', 'màu', 'áo', 'nhuộm', 'non', 'da', 'trời']
# ['pha màu nhuộm non'] ---> áo
# ['cỏ', 'pha', 'màu', 'áo', 'nhuộm', 'non', 'da', 'trời']
# ['màu áo non da'] ---> nhuộm
# ['cỏ', 'pha', 'màu', 'áo', 'nhuộm', 'non', 'da', 'trời']
# ['áo nhuộm da trời'] ---> non
# ['nẻo', 'xa', 'mới', 'tỏ', 'mặt', 'người']
# ['nẻo xa tỏ mặt'] ---> mới
# ['nẻo', 'xa', 'mới', 'tỏ', 'mặt', 'người']
# ['xa mới mặt người'] ---> tỏ
# ['khách', 'đà', 'xuống', 'ngựa', 'tới', 'nơi', 'tự', 'tình']
# ['khách đà ngựa tới'] ---> xuống
# ['khách', 'đà', 'xuống', 'ngựa', 'tới', 'nơi', 'tự', 'tình']
# ['đà xuống tới nơi'] ---> ngựa
# ['khách', 'đà', 'xuống', 'ngựa', 'tới', 'nơi', 'tự', 'tình']
# ['xuống ngựa nơi tự'] ---> tới
# ['khách', 'đà', 'xuống', 'ngựa', 'tới', 'nơi', 'tự', 'tình']
# ['ngựa tới tự tình'] ---> nơi
# ['hài', 'văn', 'lần', 'bước', 'dặm', 'xanh']
# ['hài văn bước dặm'] ---> lần
# ['hài', 'văn', 'lần', 'bước', 'dặm', 'xanh']
# ['văn lần dặm xanh'] ---> bước
# ['một', 'vùng', 'như', 'thể', 'cây', 'quỳnh', 'cành', 'dao']
# ['một vùng thể cây'] ---> như
# ['một', 'vùng', 'như', 'thể', 'cây', 'quỳnh', 'cành', 'dao']
# ['vùng như cây quỳnh'] ---> thể
# ['một', 'vùng', 'như', 'thể', 'cây', 'quỳnh', 'cành', 'dao']
# ['như thể quỳnh cành'] ---> cây
# ['một', 'vùng', 'như', 'thể', 'cây', 'quỳnh', 'cành', 'dao']
# ['thể cây cành dao'] ---> quỳnh
# ['chàng', 'vương', 'quen', 'mặt', 'ra', 'chào']
# ['chàng vương mặt ra'] ---> quen
# ['chàng', 'vương', 'quen', 'mặt', 'ra', 'chào']
# ['vương quen ra chào'] ---> mặt
# ['hai', 'kiều', 'e', 'lệ', 'nép', 'vào', 'dưới', 'hoa']
# ['hai kiều lệ nép'] ---> e
# ['hai', 'kiều', 'e', 'lệ', 'nép', 'vào', 'dưới', 'hoa']
# ['kiều e nép vào'] ---> lệ
# ['hai', 'kiều', 'e', 'lệ', 'nép', 'vào', 'dưới', 'hoa']
# ['e lệ vào dưới'] ---> nép
# ['hai', 'kiều', 'e', 'lệ', 'nép', 'vào', 'dưới', 'hoa']
# ['lệ nép dưới hoa'] ---> vào
# ['nguyên', 'người', 'quanh', 'quất', 'đâu', 'xa']
# ['nguyên người quất đâu'] ---> quanh
# ['nguyên', 'người', 'quanh', 'quất', 'đâu', 'xa']
# ['người quanh đâu xa'] ---> quất
# ['họ', 'kim', 'tên', 'trọng', 'vốn', 'nhà', 'trâm', 'anh']
# ['họ kim trọng vốn'] ---> tên
# ['họ', 'kim', 'tên', 'trọng', 'vốn', 'nhà', 'trâm', 'anh']
# ['kim tên vốn nhà'] ---> trọng
# ['họ', 'kim', 'tên', 'trọng', 'vốn', 'nhà', 'trâm', 'anh']
# ['tên trọng nhà trâm'] ---> vốn
# ['họ', 'kim', 'tên', 'trọng', 'vốn', 'nhà', 'trâm', 'anh']
# ['trọng vốn trâm anh'] ---> nhà
# ['nền', 'phú', 'hậu', 'bậc', 'tài', 'danh']
# ['nền phú bậc tài'] ---> hậu
# ['nền', 'phú', 'hậu', 'bậc', 'tài', 'danh']
# ['phú hậu tài danh'] ---> bậc
# ['văn', 'chương', 'nết', 'đất', 'thông', 'minh', 'tính', 'trời']
# ['văn chương đất thông'] ---> nết
# ['văn', 'chương', 'nết', 'đất', 'thông', 'minh', 'tính', 'trời']
# ['chương nết thông minh'] ---> đất
# ['văn', 'chương', 'nết', 'đất', 'thông', 'minh', 'tính', 'trời']
# ['nết đất minh tính'] ---> thông
# ['văn', 'chương', 'nết', 'đất', 'thông', 'minh', 'tính', 'trời']
# ['đất thông tính trời'] ---> minh
# ['phong', 'tư', 'tài', 'mạo', 'tót', 'vời']
# ['phong tư mạo tót'] ---> tài
# ['phong', 'tư', 'tài', 'mạo', 'tót', 'vời']
# ['tư tài tót vời'] ---> mạo
# ['vào', 'trong', 'phong', 'nhã', 'ra', 'ngoài', 'hào', 'hoa']
# ['vào trong nhã ra'] ---> phong
# ['vào', 'trong', 'phong', 'nhã', 'ra', 'ngoài', 'hào', 'hoa']
# ['trong phong ra ngoài'] ---> nhã
# ['vào', 'trong', 'phong', 'nhã', 'ra', 'ngoài', 'hào', 'hoa']
# ['phong nhã ngoài hào'] ---> ra
# ['vào', 'trong', 'phong', 'nhã', 'ra', 'ngoài', 'hào', 'hoa']
# ['nhã ra hào hoa'] ---> ngoài
# ['chung', 'quanh', 'vẫn', 'đất', 'nước', 'nhà']
# ['chung quanh đất nước'] ---> vẫn
# ['chung', 'quanh', 'vẫn', 'đất', 'nước', 'nhà']
# ['quanh vẫn nước nhà'] ---> đất
# ['với', 'vương', 'quan', 'trước', 'vẫn', 'là', 'đồng', 'thân']
# ['với vương trước vẫn'] ---> quan
# ['với', 'vương', 'quan', 'trước', 'vẫn', 'là', 'đồng', 'thân']
# ['vương quan vẫn là'] ---> trước
# ['với', 'vương', 'quan', 'trước', 'vẫn', 'là', 'đồng', 'thân']
# ['quan trước là đồng'] ---> vẫn
# ['với', 'vương', 'quan', 'trước', 'vẫn', 'là', 'đồng', 'thân']
# ['trước vẫn đồng thân'] ---> là
# ['vẫn', 'nghe', 'thơm', 'nức', 'hương', 'lân']
# ['vẫn nghe nức hương'] ---> thơm
# ['vẫn', 'nghe', 'thơm', 'nức', 'hương', 'lân']
# ['nghe thơm hương lân'] ---> nức
# ['một', 'nền', 'đồng', 'tước', 'khoá', 'xuân', 'hai', 'kiều']
# ['một nền tước khoá'] ---> đồng
# ['một', 'nền', 'đồng', 'tước', 'khoá', 'xuân', 'hai', 'kiều']
# ['nền đồng khoá xuân'] ---> tước
# ['một', 'nền', 'đồng', 'tước', 'khoá', 'xuân', 'hai', 'kiều']
# ['đồng tước xuân hai'] ---> khoá
# ['một', 'nền', 'đồng', 'tước', 'khoá', 'xuân', 'hai', 'kiều']
# ['tước khoá hai kiều'] ---> xuân
# ['nước', 'non', 'cách', 'mấy', 'buồng', 'thêu']
# ['nước non mấy buồng'] ---> cách
# ['nước', 'non', 'cách', 'mấy', 'buồng', 'thêu']
# ['non cách buồng thêu'] ---> mấy
# ['những', 'là', 'trộm', 'nhớ', 'thầm', 'yêu', 'chốc', 'mòng']
# ['những là nhớ thầm'] ---> trộm
# ['những', 'là', 'trộm', 'nhớ', 'thầm', 'yêu', 'chốc', 'mòng']
# ['là trộm thầm yêu'] ---> nhớ
# ['những', 'là', 'trộm', 'nhớ', 'thầm', 'yêu', 'chốc', 'mòng']
# ['trộm nhớ yêu chốc'] ---> thầm
# ['những', 'là', 'trộm', 'nhớ', 'thầm', 'yêu', 'chốc', 'mòng']
# ['nhớ thầm chốc mòng'] ---> yêu
# ['may', 'thay', 'giải', 'cấu', 'tương', 'phùng']
# ['may thay cấu tương'] ---> giải
# ['may', 'thay', 'giải', 'cấu', 'tương', 'phùng']
# ['thay giải tương phùng'] ---> cấu
# ['gặp', 'tuần', 'đố', 'lá', 'thoả', 'lòng', 'tìm', 'hoa']
# ['gặp tuần lá thoả'] ---> đố
# ['gặp', 'tuần', 'đố', 'lá', 'thoả', 'lòng', 'tìm', 'hoa']
# ['tuần đố thoả lòng'] ---> lá
# ['gặp', 'tuần', 'đố', 'lá', 'thoả', 'lòng', 'tìm', 'hoa']
# ['đố lá lòng tìm'] ---> thoả
# ['gặp', 'tuần', 'đố', 'lá', 'thoả', 'lòng', 'tìm', 'hoa']
# ['lá thoả tìm hoa'] ---> lòng
# ['bóng', 'hồng', 'nhác', 'thấy', 'nẻo', 'xa']
# ['bóng hồng thấy nẻo'] ---> nhác
# ['bóng', 'hồng', 'nhác', 'thấy', 'nẻo', 'xa']
# ['hồng nhác nẻo xa'] ---> thấy
# ['xuân', 'lan', 'thu', 'cúc', 'mặn', 'mà', 'cả', 'hai']
# ['xuân lan cúc mặn'] ---> thu
# ['xuân', 'lan', 'thu', 'cúc', 'mặn', 'mà', 'cả', 'hai']
# ['lan thu mặn mà'] ---> cúc
# ['xuân', 'lan', 'thu', 'cúc', 'mặn', 'mà', 'cả', 'hai']
# ['thu cúc mà cả'] ---> mặn
# ['xuân', 'lan', 'thu', 'cúc', 'mặn', 'mà', 'cả', 'hai']
# ['cúc mặn cả hai'] ---> mà
# ['người', 'quốc', 'sắc', 'kẻ', 'thiên', 'tài']
# ['người quốc kẻ thiên'] ---> sắc
# ['người', 'quốc', 'sắc', 'kẻ', 'thiên', 'tài']
# ['quốc sắc thiên tài'] ---> kẻ
# ['tình', 'trong', 'như', 'đã', 'mặt', 'ngoài', 'còn', 'e']
# ['tình trong đã mặt'] ---> như
# ['tình', 'trong', 'như', 'đã', 'mặt', 'ngoài', 'còn', 'e']
# ['trong như mặt ngoài'] ---> đã
# ['tình', 'trong', 'như', 'đã', 'mặt', 'ngoài', 'còn', 'e']
# ['như đã ngoài còn'] ---> mặt
# ['tình', 'trong', 'như', 'đã', 'mặt', 'ngoài', 'còn', 'e']
# ['đã mặt còn e'] ---> ngoài
# ['chập', 'chờn', 'cơn', 'tỉnh', 'cơn', 'mê']
# ['chập chờn tỉnh cơn'] ---> cơn
# ['chập', 'chờn', 'cơn', 'tỉnh', 'cơn', 'mê']
# ['chờn cơn cơn mê'] ---> tỉnh
# ['rốn', 'ngồi', 'chẳng', 'tiện', 'dứt', 'về', 'chỉn', 'khôn']
# ['rốn ngồi tiện dứt'] ---> chẳng
# ['rốn', 'ngồi', 'chẳng', 'tiện', 'dứt', 'về', 'chỉn', 'khôn']
# ['ngồi chẳng dứt về'] ---> tiện
# ['rốn', 'ngồi', 'chẳng', 'tiện', 'dứt', 'về', 'chỉn', 'khôn']
# ['chẳng tiện về chỉn'] ---> dứt
# ['rốn', 'ngồi', 'chẳng', 'tiện', 'dứt', 'về', 'chỉn', 'khôn']
# ['tiện dứt chỉn khôn'] ---> về
# ['bóng', 'tà', 'như', 'giục', 'cơn', 'buồn']
# ['bóng tà giục cơn'] ---> như
# ['bóng', 'tà', 'như', 'giục', 'cơn', 'buồn']
# ['tà như cơn buồn'] ---> giục
# ['khách', 'đà', 'lên', 'ngựa', 'người', 'còn', 'nghé', 'theo']
# ['khách đà ngựa người'] ---> lên
# ['khách', 'đà', 'lên', 'ngựa', 'người', 'còn', 'nghé', 'theo']
# ['đà lên người còn'] ---> ngựa
# ['khách', 'đà', 'lên', 'ngựa', 'người', 'còn', 'nghé', 'theo']
# ['lên ngựa còn nghé'] ---> người
# ['khách', 'đà', 'lên', 'ngựa', 'người', 'còn', 'nghé', 'theo']
# ['ngựa người nghé theo'] ---> còn
# ['dưới', 'cầu', 'nước', 'chảy', 'trong', 'veo']
# ['dưới cầu chảy trong'] ---> nước
# ['dưới', 'cầu', 'nước', 'chảy', 'trong', 'veo']
# ['cầu nước trong veo'] ---> chảy
# ['bên', 'cầu', 'tơ', 'liễu', 'bóng', 'chiều', 'thướt', 'tha']
# ['bên cầu liễu bóng'] ---> tơ
# ['bên', 'cầu', 'tơ', 'liễu', 'bóng', 'chiều', 'thướt', 'tha']
# ['cầu tơ bóng chiều'] ---> liễu
# ['bên', 'cầu', 'tơ', 'liễu', 'bóng', 'chiều', 'thướt', 'tha']
# ['tơ liễu chiều thướt'] ---> bóng
# ['bên', 'cầu', 'tơ', 'liễu', 'bóng', 'chiều', 'thướt', 'tha']
# ['liễu bóng thướt tha'] ---> chiều
# ['kiều', 'từ', 'trở', 'gót', 'trướng', 'hoa']
# ['kiều từ gót trướng'] ---> trở
# ['kiều', 'từ', 'trở', 'gót', 'trướng', 'hoa']
# ['từ trở trướng hoa'] ---> gót
# ['mặt', 'trời', 'gác', 'núi', 'chiêng', 'đà', 'thu', 'không']
# ['mặt trời núi chiêng'] ---> gác
# ['mặt', 'trời', 'gác', 'núi', 'chiêng', 'đà', 'thu', 'không']
# ['trời gác chiêng đà'] ---> núi
# ['mặt', 'trời', 'gác', 'núi', 'chiêng', 'đà', 'thu', 'không']
# ['gác núi đà thu'] ---> chiêng
# ['mặt', 'trời', 'gác', 'núi', 'chiêng', 'đà', 'thu', 'không']
# ['núi chiêng thu không'] ---> đà
# ['gương', 'nga', 'chênh', 'chếch', 'dòm', 'song']
# ['gương nga chếch dòm'] ---> chênh
# ['gương', 'nga', 'chênh', 'chếch', 'dòm', 'song']
# ['nga chênh dòm song'] ---> chếch
# ['vàng', 'gieo', 'ngấn', 'nước', 'cây', 'lồng', 'bóng', 'sân']
# ['vàng gieo nước cây'] ---> ngấn
# ['vàng', 'gieo', 'ngấn', 'nước', 'cây', 'lồng', 'bóng', 'sân']
# ['gieo ngấn cây lồng'] ---> nước
# ['vàng', 'gieo', 'ngấn', 'nước', 'cây', 'lồng', 'bóng', 'sân']
# ['ngấn nước lồng bóng'] ---> cây
# ['vàng', 'gieo', 'ngấn', 'nước', 'cây', 'lồng', 'bóng', 'sân']
# ['nước cây bóng sân'] ---> lồng
# ['hải', 'đường', 'lả', 'ngọn', 'đông', 'lân']
# ['hải đường ngọn đông'] ---> lả
# ['hải', 'đường', 'lả', 'ngọn', 'đông', 'lân']
# ['đường lả đông lân'] ---> ngọn
# ['giọt', 'sương', 'gieo', 'nặng', 'cành', 'xuân', 'la', 'đà']
# ['giọt sương nặng cành'] ---> gieo
# ['giọt', 'sương', 'gieo', 'nặng', 'cành', 'xuân', 'la', 'đà']
# ['sương gieo cành xuân'] ---> nặng
# ['giọt', 'sương', 'gieo', 'nặng', 'cành', 'xuân', 'la', 'đà']
# ['gieo nặng xuân la'] ---> cành
# ['giọt', 'sương', 'gieo', 'nặng', 'cành', 'xuân', 'la', 'đà']
# ['nặng cành la đà'] ---> xuân
# ['một', 'mình', 'lặng', 'ngắm', 'bóng', 'nga']
# ['một mình ngắm bóng'] ---> lặng
# ['một', 'mình', 'lặng', 'ngắm', 'bóng', 'nga']
# ['mình lặng bóng nga'] ---> ngắm
# ['rộn', 'đường', 'gần', 'với', 'nỗi', 'xa', 'bời', 'bời']
# ['rộn đường với nỗi'] ---> gần
# ['rộn', 'đường', 'gần', 'với', 'nỗi', 'xa', 'bời', 'bời']
# ['đường gần nỗi xa'] ---> với
# ['rộn', 'đường', 'gần', 'với', 'nỗi', 'xa', 'bời', 'bời']
# ['gần với xa bời'] ---> nỗi
# ['rộn', 'đường', 'gần', 'với', 'nỗi', 'xa', 'bời', 'bời']
# ['với nỗi bời bời'] ---> xa
# ['người', 'mà', 'đến', 'thế', 'thì', 'thôi']
# ['người mà thế thì'] ---> đến
# ['người', 'mà', 'đến', 'thế', 'thì', 'thôi']
# ['mà đến thì thôi'] ---> thế
# ['đời', 'phồn', 'hoa', 'cũng', 'là', 'đời', 'bỏ', 'đi']
# ['đời phồn cũng là'] ---> hoa
# ['đời', 'phồn', 'hoa', 'cũng', 'là', 'đời', 'bỏ', 'đi']
# ['phồn hoa là đời'] ---> cũng
# ['đời', 'phồn', 'hoa', 'cũng', 'là', 'đời', 'bỏ', 'đi']
# ['hoa cũng đời bỏ'] ---> là
# ['đời', 'phồn', 'hoa', 'cũng', 'là', 'đời', 'bỏ', 'đi']
# ['cũng là bỏ đi'] ---> đời
# ['người', 'đâu', 'gặp', 'gỡ', 'làm', 'chi']
# ['người đâu gỡ làm'] ---> gặp
# ['người', 'đâu', 'gặp', 'gỡ', 'làm', 'chi']
# ['đâu gặp làm chi'] ---> gỡ
# ['trăm', 'năm', 'biết', 'có', 'duyên', 'gì', 'hay', 'không']
# ['trăm năm có duyên'] ---> biết
# ['trăm', 'năm', 'biết', 'có', 'duyên', 'gì', 'hay', 'không']
# ['năm biết duyên gì'] ---> có
# ['trăm', 'năm', 'biết', 'có', 'duyên', 'gì', 'hay', 'không']
# ['biết có gì hay'] ---> duyên
# ['trăm', 'năm', 'biết', 'có', 'duyên', 'gì', 'hay', 'không']
# ['có duyên hay không'] ---> gì
# ['ngổn', 'ngang', 'trăm', 'mối', 'bên', 'lòng']
# ['ngổn ngang mối bên'] ---> trăm
# ['ngổn', 'ngang', 'trăm', 'mối', 'bên', 'lòng']
# ['ngang trăm bên lòng'] ---> mối
# ['nên', 'câu', 'tuyệt', 'diệu', 'ngụ', 'trong', 'tính', 'tình']
# ['nên câu diệu ngụ'] ---> tuyệt
# ['nên', 'câu', 'tuyệt', 'diệu', 'ngụ', 'trong', 'tính', 'tình']
# ['câu tuyệt ngụ trong'] ---> diệu
# ['nên', 'câu', 'tuyệt', 'diệu', 'ngụ', 'trong', 'tính', 'tình']
# ['tuyệt diệu trong tính'] ---> ngụ
# ['nên', 'câu', 'tuyệt', 'diệu', 'ngụ', 'trong', 'tính', 'tình']
# ['diệu ngụ tính tình'] ---> trong
# ['chênh', 'chênh', 'bóng', 'nguyệt', 'xế', 'mành']
# ['chênh chênh nguyệt xế'] ---> bóng
# ['chênh', 'chênh', 'bóng', 'nguyệt', 'xế', 'mành']
# ['chênh bóng xế mành'] ---> nguyệt
# ['tựa', 'nương', 'bên', 'triện', 'một', 'mình', 'thiu', 'thiu']
# ['tựa nương triện một'] ---> bên
# ['tựa', 'nương', 'bên', 'triện', 'một', 'mình', 'thiu', 'thiu']
# ['nương bên một mình'] ---> triện
# ...
# ['còn ngờ mộng đêm'] ---> giấc
# ['còn', 'ngờ', 'giấc', 'mộng', 'đêm', 'xuân', 'mơ', 'màng']
# ['ngờ giấc đêm xuân'] ---> mộng
# ['còn', 'ngờ', 'giấc', 'mộng', 'đêm', 'xuân', 'mơ', 'màng']
# ['giấc mộng xuân mơ'] ---> đêm
# ['còn', 'ngờ', 'giấc', 'mộng', 'đêm', 'xuân', 'mơ', 'màng']
# ['mộng đêm mơ màng'] ---> xuân
# ['nàng', 'rằng', 'khoảng', 'vắng', 'đêm', 'trường']
# ['nàng rằng vắng đêm'] ---> khoảng
# ['nàng', 'rằng', 'khoảng', 'vắng', 'đêm', 'trường']
# ['rằng khoảng đêm trường'] ---> vắng
# ['vì', 'hoa', 'nên', 'phải', 'đánh', 'đường', 'tìm', 'hoa']
# ['vì hoa phải đánh'] ---> nên
# ['vì', 'hoa', 'nên', 'phải', 'đánh', 'đường', 'tìm', 'hoa']
# ['hoa nên đánh đường'] ---> phải
# ['vì', 'hoa', 'nên', 'phải', 'đánh', 'đường', 'tìm', 'hoa']
# ['nên phải đường tìm'] ---> đánh
# ['vì', 'hoa', 'nên', 'phải', 'đánh', 'đường', 'tìm', 'hoa']
# ['phải đánh tìm hoa'] ---> đường
# ['bây', 'giờ', 'rõ', 'mặt', 'đôi', 'ta']
# ['bây giờ mặt đôi'] ---> rõ
# ['bây', 'giờ', 'rõ', 'mặt', 'đôi', 'ta']
# ['giờ rõ đôi ta'] ---> mặt
# ['biết', 'đâu', 'rồi', 'nữa', 'chẳng', 'là', 'chiêm', 'bao']
# ['biết đâu nữa chẳng'] ---> rồi
# ['biết', 'đâu', 'rồi', 'nữa', 'chẳng', 'là', 'chiêm', 'bao']
# ['đâu rồi chẳng là'] ---> nữa
# ['biết', 'đâu', 'rồi', 'nữa', 'chẳng', 'là', 'chiêm', 'bao']
# ['rồi nữa là chiêm'] ---> chẳng
# ['biết', 'đâu', 'rồi', 'nữa', 'chẳng', 'là', 'chiêm', 'bao']
# ['nữa chẳng chiêm bao'] ---> là
# ['vội', 'mừng', 'làm', 'lễ', 'rước', 'vào']
# ['vội mừng lễ rước'] ---> làm
# ['vội', 'mừng', 'làm', 'lễ', 'rước', 'vào']
# ['mừng làm rước vào'] ---> lễ
# ['đài', 'sen', 'nối', 'sáp', 'song', 'đào', 'thêm', 'hương']
# ['đài sen sáp song'] ---> nối
# ['đài', 'sen', 'nối', 'sáp', 'song', 'đào', 'thêm', 'hương']
# ['sen nối song đào'] ---> sáp
# ['đài', 'sen', 'nối', 'sáp', 'song', 'đào', 'thêm', 'hương']
# ['nối sáp đào thêm'] ---> song
# ['đài', 'sen', 'nối', 'sáp', 'song', 'đào', 'thêm', 'hương']
# ['sáp song thêm hương'] ---> đào
# ['tiên', 'thề', 'cùng', 'thảo', 'một', 'chương']
# ['tiên thề thảo một'] ---> cùng
# ['tiên', 'thề', 'cùng', 'thảo', 'một', 'chương']
# ['thề cùng một chương'] ---> thảo
# ['tóc', 'mây', 'một', 'món', 'dao', 'vàng', 'chia', 'đôi']
# ['tóc mây món dao'] ---> một
# ['tóc', 'mây', 'một', 'món', 'dao', 'vàng', 'chia', 'đôi']
# ['mây một dao vàng'] ---> món
# ['tóc', 'mây', 'một', 'món', 'dao', 'vàng', 'chia', 'đôi']
# ['một món vàng chia'] ---> dao
# ['tóc', 'mây', 'một', 'món', 'dao', 'vàng', 'chia', 'đôi']
# ['món dao chia đôi'] ---> vàng
# ['vầng', 'trăng', 'vằng', 'vặc', 'giữa', 'trời']
# ['vầng trăng vặc giữa'] ---> vằng
# ['vầng', 'trăng', 'vằng', 'vặc', 'giữa', 'trời']
# ['trăng vằng giữa trời'] ---> vặc
# ['đinh', 'ninh', 'hai', 'mặt', 'một', 'lời', 'song', 'song']
# ['đinh ninh mặt một'] ---> hai
# ['đinh', 'ninh', 'hai', 'mặt', 'một', 'lời', 'song', 'song']
# ['ninh hai một lời'] ---> mặt
# ['đinh', 'ninh', 'hai', 'mặt', 'một', 'lời', 'song', 'song']
# ['hai mặt lời song'] ---> một
# ['đinh', 'ninh', 'hai', 'mặt', 'một', 'lời', 'song', 'song']
# ['mặt một song song'] ---> lời
# ['tóc', 'tơ', 'căn', 'vặn', 'tấc', 'lòng']
# ['tóc tơ vặn tấc'] ---> căn
# ['tóc', 'tơ', 'căn', 'vặn', 'tấc', 'lòng']
# ['tơ căn tấc lòng'] ---> vặn
# ['trăm', 'năm', 'tạc', 'một', 'chữ', 'đồng', 'đến', 'xương']
# ['trăm năm một chữ'] ---> tạc
# ['trăm', 'năm', 'tạc', 'một', 'chữ', 'đồng', 'đến', 'xương']
# ['năm tạc chữ đồng'] ---> một
# ['trăm', 'năm', 'tạc', 'một', 'chữ', 'đồng', 'đến', 'xương']
# ['tạc một đồng đến'] ---> chữ
# ['trăm', 'năm', 'tạc', 'một', 'chữ', 'đồng', 'đến', 'xương']
# ['một chữ đến xương'] ---> đồng
# ['chén', 'hà', 'sánh', 'giọng', 'quỳnh', 'tương']
# ['chén hà giọng quỳnh'] ---> sánh
# ['chén', 'hà', 'sánh', 'giọng', 'quỳnh', 'tương']
# ['hà sánh quỳnh tương'] ---> giọng
# ['dải', 'là', 'hương', 'lộn', 'bình', 'gương', 'bóng', 'lồng']
# ['dải là lộn bình'] ---> hương
# ['dải', 'là', 'hương', 'lộn', 'bình', 'gương', 'bóng', 'lồng']
# ['là hương bình gương'] ---> lộn
# ['dải', 'là', 'hương', 'lộn', 'bình', 'gương', 'bóng', 'lồng']
# ['hương lộn gương bóng'] ---> bình
# ['dải', 'là', 'hương', 'lộn', 'bình', 'gương', 'bóng', 'lồng']
# ['lộn bình bóng lồng'] ---> gương
# ['sinh', 'rằng', 'gió', 'mát', 'trăng', 'trong']
# ['sinh rằng mát trăng'] ---> gió
# ['sinh', 'rằng', 'gió', 'mát', 'trăng', 'trong']
# ['rằng gió trăng trong'] ---> mát
# ['bấy', 'lâu', 'nay', 'một', 'chút', 'lòng', 'chưa', 'cam']
# ['bấy lâu một chút'] ---> nay
# ['bấy', 'lâu', 'nay', 'một', 'chút', 'lòng', 'chưa', 'cam']
# ['lâu nay chút lòng'] ---> một
# ['bấy', 'lâu', 'nay', 'một', 'chút', 'lòng', 'chưa', 'cam']
# ['nay một lòng chưa'] ---> chút
# ['bấy', 'lâu', 'nay', 'một', 'chút', 'lòng', 'chưa', 'cam']
# ['một chút chưa cam'] ---> lòng
# ['chày', 'sương', 'chưa', 'nện', 'cầu', 'lam']
# ['chày sương nện cầu'] ---> chưa
# ['chày', 'sương', 'chưa', 'nện', 'cầu', 'lam']
# ['sương chưa cầu lam'] ---> nện
# ['sợ', 'lần', 'khân', 'quá', 'ra', 'sàm', 'sỡ', 'chăng']
# ['sợ lần quá ra'] ---> khân
# ['sợ', 'lần', 'khân', 'quá', 'ra', 'sàm', 'sỡ', 'chăng']
# ['lần khân ra sàm'] ---> quá
# ['sợ', 'lần', 'khân', 'quá', 'ra', 'sàm', 'sỡ', 'chăng']
# ['khân quá sàm sỡ'] ---> ra
# ['sợ', 'lần', 'khân', 'quá', 'ra', 'sàm', 'sỡ', 'chăng']
# ['quá ra sỡ chăng'] ---> sàm
# ['nàng', 'rằng', 'hồng', 'diệp', 'xích', 'thằng']
# ['nàng rằng diệp xích'] ---> hồng
# ['nàng', 'rằng', 'hồng', 'diệp', 'xích', 'thằng']
# ['rằng hồng xích thằng'] ---> diệp
# ['một', 'lời', 'cũng', 'đã', 'tiếng', 'rằng', 'tương', 'tri']
# ['một lời đã tiếng'] ---> cũng
# ['một', 'lời', 'cũng', 'đã', 'tiếng', 'rằng', 'tương', 'tri']
# ['lời cũng tiếng rằng'] ---> đã
# ['một', 'lời', 'cũng', 'đã', 'tiếng', 'rằng', 'tương', 'tri']
# ['cũng đã rằng tương'] ---> tiếng
# ['một', 'lời', 'cũng', 'đã', 'tiếng', 'rằng', 'tương', 'tri']
# ['đã tiếng tương tri'] ---> rằng
# ['đừng', 'điều', 'nguyệt', 'nọ', 'hoa', 'kia']
# ['đừng điều nọ hoa'] ---> nguyệt
# ['đừng', 'điều', 'nguyệt', 'nọ', 'hoa', 'kia']
# ['điều nguyệt hoa kia'] ---> nọ
# ['ngoài', 'ra', 'ai', 'lại', 'tiếc', 'gì', 'với', 'ai']
# ['ngoài ra lại tiếc'] ---> ai
# ['ngoài', 'ra', 'ai', 'lại', 'tiếc', 'gì', 'với', 'ai']
# ['ra ai tiếc gì'] ---> lại
# ['ngoài', 'ra', 'ai', 'lại', 'tiếc', 'gì', 'với', 'ai']
# ['ai lại gì với'] ---> tiếc
# ['ngoài', 'ra', 'ai', 'lại', 'tiếc', 'gì', 'với', 'ai']
# ['lại tiếc với ai'] ---> gì
# ['rằng', 'nghe', 'nổi', 'tiếng', 'cầm', 'đài']
# ['rằng nghe tiếng cầm'] ---> nổi
# ['rằng', 'nghe', 'nổi', 'tiếng', 'cầm', 'đài']
# ['nghe nổi cầm đài'] ---> tiếng
# ['nước', 'non', 'luống', 'những', 'lắng', 'tai', 'chung', 'kỳ']
# ['nước non những lắng'] ---> luống
# ['nước', 'non', 'luống', 'những', 'lắng', 'tai', 'chung', 'kỳ']
# ['non luống lắng tai'] ---> những
# ['nước', 'non', 'luống', 'những', 'lắng', 'tai', 'chung', 'kỳ']
# ['luống những tai chung'] ---> lắng
# ['nước', 'non', 'luống', 'những', 'lắng', 'tai', 'chung', 'kỳ']
# ['những lắng chung kỳ'] ---> tai
# ['thưa', 'rằng', 'tiện', 'kỹ', 'sá', 'chi']
# ['thưa rằng kỹ sá'] ---> tiện
# ['thưa', 'rằng', 'tiện', 'kỹ', 'sá', 'chi']
# ['rằng tiện sá chi'] ---> kỹ
# ['đã', 'lòng', 'dạy', 'đến', 'dạy', 'thì', 'phải', 'vâng']
# ['đã lòng đến dạy'] ---> dạy
# ['đã', 'lòng', 'dạy', 'đến', 'dạy', 'thì', 'phải', 'vâng']
# ['lòng dạy dạy thì'] ---> đến
# ['đã', 'lòng', 'dạy', 'đến', 'dạy', 'thì', 'phải', 'vâng']
# ['dạy đến thì phải'] ---> dạy
# ['đã', 'lòng', 'dạy', 'đến', 'dạy', 'thì', 'phải', 'vâng']
# ['đến dạy phải vâng'] ---> thì
# ['hiên', 'sau', 'treo', 'sẵn', 'cầm', 'trăng']
# ['hiên sau sẵn cầm'] ---> treo
# ['hiên', 'sau', 'treo', 'sẵn', 'cầm', 'trăng']
# ['sau treo cầm trăng'] ---> sẵn
# ['vội', 'vàng', 'sinh', 'đã', 'tay', 'nâng', 'ngang', 'mày']
# ['vội vàng đã tay'] ---> sinh
# ['vội', 'vàng', 'sinh', 'đã', 'tay', 'nâng', 'ngang', 'mày']
# ['vàng sinh tay nâng'] ---> đã
# ['vội', 'vàng', 'sinh', 'đã', 'tay', 'nâng', 'ngang', 'mày']
# ['sinh đã nâng ngang'] ---> tay
# ['vội', 'vàng', 'sinh', 'đã', 'tay', 'nâng', 'ngang', 'mày']
# ['đã tay ngang mày'] ---> nâng
# ['nàng', 'rằng', 'nghề', 'mọn', 'riêng', 'tay']
# ['nàng rằng mọn riêng'] ---> nghề
# ['nàng', 'rằng', 'nghề', 'mọn', 'riêng', 'tay']
# ['rằng nghề riêng tay'] ---> mọn
# ['làm', 'chi', 'cho', 'bận', 'lòng', 'này', 'lắm', 'thân']
# ['làm chi bận lòng'] ---> cho
# ['làm', 'chi', 'cho', 'bận', 'lòng', 'này', 'lắm', 'thân']
# ['chi cho lòng này'] ---> bận
# ['làm', 'chi', 'cho', 'bận', 'lòng', 'này', 'lắm', 'thân']
# ['cho bận này lắm'] ---> lòng
# ['làm', 'chi', 'cho', 'bận', 'lòng', 'này', 'lắm', 'thân']
# ['bận lòng lắm thân'] ---> này
# ['so', 'dần', 'dây', 'vũ', 'dây', 'văn']
# ['so dần vũ dây'] ---> dây
# ['so', 'dần', 'dây', 'vũ', 'dây', 'văn']
# ['dần dây dây văn'] ---> vũ
# ['bốn', 'dây', 'to', 'nhỏ', 'theo', 'vần', 'cung', 'thương']
# ['bốn dây nhỏ theo'] ---> to
# ['bốn', 'dây', 'to', 'nhỏ', 'theo', 'vần', 'cung', 'thương']
# ['dây to theo vần'] ---> nhỏ
# ['bốn', 'dây', 'to', 'nhỏ', 'theo', 'vần', 'cung', 'thương']
# ['to nhỏ vần cung'] ---> theo
# ['bốn', 'dây', 'to', 'nhỏ', 'theo', 'vần', 'cung', 'thương']
# ['nhỏ theo cung thương'] ---> vần
# ['khúc', 'đâu', 'hán', 'sở', 'chiến', 'trường']
# ['khúc đâu sở chiến'] ---> hán
# ['khúc', 'đâu', 'hán', 'sở', 'chiến', 'trường']
# ['đâu hán chiến trường'] ---> sở
# ['nghe', 'ra', 'tiếng', 'sắt', 'tiếng', 'vàng', 'chen', 'nhau']
# ['nghe ra sắt tiếng'] ---> tiếng
# ['nghe', 'ra', 'tiếng', 'sắt', 'tiếng', 'vàng', 'chen', 'nhau']
# ['ra tiếng tiếng vàng'] ---> sắt
# ['nghe', 'ra', 'tiếng', 'sắt', 'tiếng', 'vàng', 'chen', 'nhau']
# ['tiếng sắt vàng chen'] ---> tiếng
# ['nghe', 'ra', 'tiếng', 'sắt', 'tiếng', 'vàng', 'chen', 'nhau']
# ['sắt tiếng chen nhau'] ---> vàng
# ['khúc', 'đâu', 'tư', 'mã', 'phượng', 'cầu']
# ['khúc đâu mã phượng'] ---> tư
# ['khúc', 'đâu', 'tư', 'mã', 'phượng', 'cầu']
# ['đâu tư phượng cầu'] ---> mã
# ['nghe', 'ra', 'như', 'oán', 'như', 'sầu', 'phải', 'chăng']
# ['nghe ra oán như'] ---> như
# ['nghe', 'ra', 'như', 'oán', 'như', 'sầu', 'phải', 'chăng']
# ['ra như như sầu'] ---> oán
# ['nghe', 'ra', 'như', 'oán', 'như', 'sầu', 'phải', 'chăng']
# ['như oán sầu phải'] ---> như
# ['nghe', 'ra', 'như', 'oán', 'như', 'sầu', 'phải', 'chăng']
# ['oán như phải chăng'] ---> sầu
# ['kê', 'khang', 'này', 'khúc', 'quảng', 'lăng']
# ['kê khang khúc quảng'] ---> này
# ['kê', 'khang', 'này', 'khúc', 'quảng', 'lăng']
# ['khang này quảng lăng'] ---> khúc
# ['một', 'rằng', 'lưu', 'thủy', 'hai', 'rằng', 'hành', 'vân']
# ['một rằng thủy hai'] ---> lưu
# ['một', 'rằng', 'lưu', 'thủy', 'hai', 'rằng', 'hành', 'vân']
# ['rằng lưu hai rằng'] ---> thủy
# ['một', 'rằng', 'lưu', 'thủy', 'hai', 'rằng', 'hành', 'vân']
# ['lưu thủy rằng hành'] ---> hai
# ['một', 'rằng', 'lưu', 'thủy', 'hai', 'rằng', 'hành', 'vân']
# ['thủy hai hành vân'] ---> rằng
# ['qua', 'quan', 'này', 'khúc', 'chiêu', 'quân']
# ['qua quan khúc chiêu'] ---> này
# ['qua', 'quan', 'này', 'khúc', 'chiêu', 'quân']
# ['quan này chiêu quân'] ---> khúc
# ['nửa', 'phần', 'luyến', 'chúa', 'nửa', 'phần', 'tư', 'gia']
# ['nửa phần chúa nửa'] ---> luyến
# ['nửa', 'phần', 'luyến', 'chúa', 'nửa', 'phần', 'tư', 'gia']
# ['phần luyến nửa phần'] ---> chúa
# ['nửa', 'phần', 'luyến', 'chúa', 'nửa', 'phần', 'tư', 'gia']
# ['luyến chúa phần tư'] ---> nửa
# ['nửa', 'phần', 'luyến', 'chúa', 'nửa', 'phần', 'tư', 'gia']
# ['chúa nửa tư gia'] ---> phần
# ['trong', 'như', 'tiếng', 'hạc', 'bay', 'qua']
# ['trong như hạc bay'] ---> tiếng
# ['trong', 'như', 'tiếng', 'hạc', 'bay', 'qua']
# ['như tiếng bay qua'] ---> hạc
# ['đục', 'như', 'tiếng', 'suối', 'mới', 'sa', 'nửa', 'vời']
# ['đục như suối mới'] ---> tiếng
# ['đục', 'như', 'tiếng', 'suối', 'mới', 'sa', 'nửa', 'vời']
# ['như tiếng mới sa'] ---> suối
# ['đục', 'như', 'tiếng', 'suối', 'mới', 'sa', 'nửa', 'vời']
# ['tiếng suối sa nửa'] ---> mới
# ['đục', 'như', 'tiếng', 'suối', 'mới', 'sa', 'nửa', 'vời']
# ['suối mới nửa vời'] ---> sa
# ['tiếng', 'khoan', 'như', 'gió', 'thoảng', 'ngoài']
# ['tiếng khoan gió thoảng'] ---> như
# ['tiếng', 'khoan', 'như', 'gió', 'thoảng', 'ngoài']
# ['khoan như thoảng ngoài'] ---> gió
# ['tiếng', 'mau', 'sầm', 'sập', 'như', 'trời', 'đổ', 'mưa']
# ['tiếng mau sập như'] ---> sầm
# ['tiếng', 'mau', 'sầm', 'sập', 'như', 'trời', 'đổ', 'mưa']
# ['mau sầm như trời'] ---> sập
# ['tiếng', 'mau', 'sầm', 'sập', 'như', 'trời', 'đổ', 'mưa']
# ['sầm sập trời đổ'] ---> như
# ['tiếng', 'mau', 'sầm', 'sập', 'như', 'trời', 'đổ', 'mưa']
# ['sập như đổ mưa'] ---> trời
# ['ngọn', 'đèn', 'khi', 'tỏ', 'khi', 'mờ']
# ['ngọn đèn tỏ khi'] ---> khi
# ['ngọn', 'đèn', 'khi', 'tỏ', 'khi', 'mờ']
# ['đèn khi khi mờ'] ---> tỏ
# ['khiến', 'người', 'ngồi', 'đó', 'cũng', 'ngơ', 'ngẩn', 'sầu']
# ['khiến người đó cũng'] ---> ngồi
# ['khiến', 'người', 'ngồi', 'đó', 'cũng', 'ngơ', 'ngẩn', 'sầu']
# ['người ngồi cũng ngơ'] ---> đó
# ['khiến', 'người', 'ngồi', 'đó', 'cũng', 'ngơ', 'ngẩn', 'sầu']
# ['ngồi đó ngơ ngẩn'] ---> cũng
# ['khiến', 'người', 'ngồi', 'đó', 'cũng', 'ngơ', 'ngẩn', 'sầu']
# ['đó cũng ngẩn sầu'] ---> ngơ
# ['khi', 'tựa', 'gối', 'khi', 'cúi', 'đầu']
# ['khi tựa khi cúi'] ---> gối
# ['khi', 'tựa', 'gối', 'khi', 'cúi', 'đầu']
# ['tựa gối cúi đầu'] ---> khi
# ['khi', 'vò', 'chín', 'khúc', 'khi', 'chau', 'đôi', 'mày']
# ['khi vò khúc khi'] ---> chín
# ['khi', 'vò', 'chín', 'khúc', 'khi', 'chau', 'đôi', 'mày']
# ['vò chín khi chau'] ---> khúc
# ['khi', 'vò', 'chín', 'khúc', 'khi', 'chau', 'đôi', 'mày']
# ['chín khúc chau đôi'] ---> khi
# ['khi', 'vò', 'chín', 'khúc', 'khi', 'chau', 'đôi', 'mày']
# ['khúc khi đôi mày'] ---> chau
# ['rằng', 'hay', 'thì', 'thật', 'là', 'hay']
# ['rằng hay thật là'] ---> thì
# ['rằng', 'hay', 'thì', 'thật', 'là', 'hay']
# ['hay thì là hay'] ---> thật
# ['nghe', 'ra', 'ngậm', 'đắng', 'nuốt', 'cay', 'thế', 'nào']
# ['nghe ra đắng nuốt'] ---> ngậm
# ['nghe', 'ra', 'ngậm', 'đắng', 'nuốt', 'cay', 'thế', 'nào']
# ['ra ngậm nuốt cay'] ---> đắng
# ['nghe', 'ra', 'ngậm', 'đắng', 'nuốt', 'cay', 'thế', 'nào']
# ['ngậm đắng cay thế'] ---> nuốt
# ['nghe', 'ra', 'ngậm', 'đắng', 'nuốt', 'cay', 'thế', 'nào']
# ['đắng nuốt thế nào'] ---> cay
# ['lựa', 'chi', 'những', 'bậc', 'tiêu', 'tao']
# ['lựa chi bậc tiêu'] ---> những
# ['lựa', 'chi', 'những', 'bậc', 'tiêu', 'tao']
# ['chi những tiêu tao'] ---> bậc
# ['dột', 'lòng', 'mình', 'cũng', 'nao', 'nao', 'lòng', 'người']
# ['dột lòng cũng nao'] ---> mình
# ['dột', 'lòng', 'mình', 'cũng', 'nao', 'nao', 'lòng', 'người']
# ['lòng mình nao nao'] ---> cũng
# ['dột', 'lòng', 'mình', 'cũng', 'nao', 'nao', 'lòng', 'người']
# ['mình cũng nao lòng'] ---> nao
# ['dột', 'lòng', 'mình', 'cũng', 'nao', 'nao', 'lòng', 'người']
# ['cũng nao lòng người'] ---> nao
# ['rằng', 'quen', 'mất', 'nết', 'đi', 'rồi']
# ['rằng quen nết đi'] ---> mất
# ['rằng', 'quen', 'mất', 'nết', 'đi', 'rồi']
# ['quen mất đi rồi'] ---> nết
# ['tẻ', 'vui', 'thôi', 'cũng', 'tính', 'trời', 'biết', 'sao']
# ['tẻ vui cũng tính'] ---> thôi
# ['tẻ', 'vui', 'thôi', 'cũng', 'tính', 'trời', 'biết', 'sao']
# ['vui thôi tính trời'] ---> cũng
# ['tẻ', 'vui', 'thôi', 'cũng', 'tính', 'trời', 'biết', 'sao']
# ['thôi cũng trời biết'] ---> tính
# ['tẻ', 'vui', 'thôi', 'cũng', 'tính', 'trời', 'biết', 'sao']
# ['cũng tính biết sao'] ---> trời
# ['lời', 'vàng', 'âm', 'lĩnh', 'ý', 'cao']
# ['lời vàng lĩnh ý'] ---> âm
# ['lời', 'vàng', 'âm', 'lĩnh', 'ý', 'cao']
# ['vàng âm ý cao'] ---> lĩnh
# ['họa', 'dần', 'dần', 'bớt', 'chút', 'nào', 'được', 'không']
# ['họa dần bớt chút'] ---> dần
# ['họa', 'dần', 'dần', 'bớt', 'chút', 'nào', 'được', 'không']
# ['dần dần chút nào'] ---> bớt
# ['họa', 'dần', 'dần', 'bớt', 'chút', 'nào', 'được', 'không']
# ['dần bớt nào được'] ---> chút
# ['họa', 'dần', 'dần', 'bớt', 'chút', 'nào', 'được', 'không']
# ['bớt chút được không'] ---> nào
# ['hoa', 'hương', 'càng', 'tỏ', 'thức', 'hồng']
# ['hoa hương tỏ thức'] ---> càng
# ['hoa', 'hương', 'càng', 'tỏ', 'thức', 'hồng']
# ['hương càng thức hồng'] ---> tỏ
# ['đầu', 'mày', 'cuối', 'mắt', 'càng', 'nồng', 'tấm', 'yêu']
# ['đầu mày mắt càng'] ---> cuối
# ['đầu', 'mày', 'cuối', 'mắt', 'càng', 'nồng', 'tấm', 'yêu']
# ['mày cuối càng nồng'] ---> mắt
# ['đầu', 'mày', 'cuối', 'mắt', 'càng', 'nồng', 'tấm', 'yêu']
# ['cuối mắt nồng tấm'] ---> càng
# ['đầu', 'mày', 'cuối', 'mắt', 'càng', 'nồng', 'tấm', 'yêu']
# ['mắt càng tấm yêu'] ---> nồng
# ['sóng', 'tình', 'dường', 'đã', 'xiêu', 'xiêu']
# ['sóng tình đã xiêu'] ---> dường
# ['sóng', 'tình', 'dường', 'đã', 'xiêu', 'xiêu']
# ['tình dường xiêu xiêu'] ---> đã
# ['xem', 'trong', 'âu', 'yếm', 'có', 'chiều', 'lả', 'lơi']
# ['xem trong yếm có'] ---> âu
# ['xem', 'trong', 'âu', 'yếm', 'có', 'chiều', 'lả', 'lơi']
# ['trong âu có chiều'] ---> yếm
# ['xem', 'trong', 'âu', 'yếm', 'có', 'chiều', 'lả', 'lơi']
# ['âu yếm chiều lả'] ---> có
# ['xem', 'trong', 'âu', 'yếm', 'có', 'chiều', 'lả', 'lơi']
# ['yếm có lả lơi'] ---> chiều

# %%
X_train
# Out:
# <tf.Tensor: shape=(1507, 4), dtype=int32, numpy=
# array([[ 199,  119,  600,    4],
#        [ 119,   20,    4,   77],
#        [ 148,   51,  149,  200],
#        ...,
#        [  20,  253,    9,   74],
#        [ 253, 1163,   74,  511],
#        [1163,    9,  511, 1164]], dtype=int32)>

# %% [markdown]
# ## 4. Xây dựng mô hình

# %% [markdown]
# Mô hình CBOW bao gồm
# - 1 lớp Embedding với chiều được định sẵn
# - 1 lớp Dense để phóng về chiều từ điển

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Lambda
from tensorflow.keras.backend import mean

# %% [markdown]
# Kiểm tra mô hình

# %%
embedding_size = 128
cbow = Sequential()
cbow.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=window_size*2))
cbow.add(Lambda(lambda x: mean(x, axis=1), output_shape=(embedding_size,) ))
cbow.add(Dense(vocab_size, activation='softmax'))

# %%
cbow.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 128)            149120
#
#  lambda (Lambda)             (None, 128)               0
#
#  dense (Dense)               (None, 1165)              150285
#
# =================================================================
# Total params: 299,405
# Trainable params: 299,405
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Tiến hành training

# %%
cbow.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
cbow.fit(X_train, y_train, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 48/48 [==============================] - 9s 58ms/step - loss: 7.0547 - acc: 0.0086
# Epoch 2/30
# 48/48 [==============================] - 1s 11ms/step - loss: 7.0019 - acc: 0.0902
# Epoch 3/30
# 48/48 [==============================] - 0s 10ms/step - loss: 6.9149 - acc: 0.0683
# Epoch 4/30
# 48/48 [==============================] - 0s 7ms/step - loss: 6.7432 - acc: 0.0338
# Epoch 5/30
# 48/48 [==============================] - 0s 4ms/step - loss: 6.5153 - acc: 0.0232
# Epoch 6/30
# 48/48 [==============================] - 0s 4ms/step - loss: 6.2945 - acc: 0.0239
# Epoch 7/30
# 48/48 [==============================] - 0s 5ms/step - loss: 6.1040 - acc: 0.0226
# Epoch 8/30
# 48/48 [==============================] - 0s 7ms/step - loss: 5.9368 - acc: 0.0285
# Epoch 9/30
# 48/48 [==============================] - 0s 4ms/step - loss: 5.7752 - acc: 0.0425
# Epoch 10/30
# 48/48 [==============================] - 0s 4ms/step - loss: 5.6053 - acc: 0.0677
# Epoch 11/30
# 48/48 [==============================] - 0s 4ms/step - loss: 5.4208 - acc: 0.0843
# Epoch 12/30
# 48/48 [==============================] - 0s 4ms/step - loss: 5.2192 - acc: 0.1214
# Epoch 13/30
# 48/48 [==============================] - 0s 4ms/step - loss: 5.0003 - acc: 0.1725
# Epoch 14/30
# 48/48 [==============================] - 0s 4ms/step - loss: 4.7662 - acc: 0.2196
# Epoch 15/30
# 48/48 [==============================] - 0s 7ms/step - loss: 4.5174 - acc: 0.2847
# Epoch 16/30
# 48/48 [==============================] - 0s 4ms/step - loss: 4.2558 - acc: 0.3265
# Epoch 17/30
# 48/48 [==============================] - 0s 8ms/step - loss: 3.9865 - acc: 0.3756
# Epoch 18/30
# 48/48 [==============================] - 0s 7ms/step - loss: 3.7124 - acc: 0.4174
# Epoch 19/30
# 48/48 [==============================] - 0s 4ms/step - loss: 3.4376 - acc: 0.4678
# Epoch 20/30
# 48/48 [==============================] - 0s 4ms/step - loss: 3.1652 - acc: 0.5169
# Epoch 21/30
# 48/48 [==============================] - 0s 7ms/step - loss: 2.9034 - acc: 0.5640
# Epoch 22/30
# 48/48 [==============================] - 0s 4ms/step - loss: 2.6526 - acc: 0.6025
# Epoch 23/30
# 48/48 [==============================] - 0s 4ms/step - loss: 2.4127 - acc: 0.6496
# Epoch 24/30
# 48/48 [==============================] - 0s 4ms/step - loss: 2.1900 - acc: 0.6921
# Epoch 25/30
# 48/48 [==============================] - 0s 4ms/step - loss: 1.9852 - acc: 0.7240
# Epoch 26/30
# 48/48 [==============================] - 0s 8ms/step - loss: 1.7967 - acc: 0.7664
# Epoch 27/30
# 48/48 [==============================] - 0s 5ms/step - loss: 1.6259 - acc: 0.7976
# Epoch 28/30
# 48/48 [==============================] - 0s 5ms/step - loss: 1.4707 - acc: 0.8288
# Epoch 29/30
# 48/48 [==============================] - 0s 5ms/step - loss: 1.3315 - acc: 0.8573
# Epoch 30/30
# 48/48 [==============================] - 0s 5ms/step - loss: 1.2071 - acc: 0.8792

# %% [markdown]
# 6. Kiểm tra sinh từ

# %%
example = 'Trăm năm cõi người'
example = text_to_word_sequence(example)
example = tokenizer.texts_to_sequences([example])
example = tf.convert_to_tensor(example)
cbow.predict(example)
tokenizer.index_word[np.argmax(cbow.predict(example))]
# Out:
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 27ms/step
# 'trong'

# %% [markdown]
# ## 6. Hiển thị Embedding

# %%
weights = cbow.get_weights()[0]

# %%
weights
# Out:
# array([[ 7.5990185e-03,  2.4730336e-02, -2.9007085e-03, ...,
#         -6.4679161e-03,  6.2787533e-03,  3.7921082e-02],
#        [ 3.2300837e-03,  2.9805850e-02, -3.6912788e-02, ...,
#          2.1508161e-02, -2.5477886e-02,  1.8250197e-05],
#        [-1.5149704e-01, -8.2380779e-02,  5.5324459e-01, ...,
#         -1.2575044e-01,  8.9185357e-01,  2.8546250e-01],
#        ...,
#        [ 2.5822058e-01, -2.7968338e-01,  1.9820078e-01, ...,
#         -2.9764467e-01, -3.2461637e-01,  3.1100342e-01],
#        [ 1.7546186e-01, -2.3975278e-01, -3.1542158e-01, ...,
#         -2.0626585e-01, -3.8642687e-01,  1.7157379e-01],
#        [ 4.9452052e-02, -1.9606557e-01, -2.5353080e-01, ...,
#          2.9148585e-01, -2.9566008e-01, -2.4046199e-01]], dtype=float32)

# %%
import pandas as pd
weights = cbow.get_weights()[0]
weights = weights[1:]
print(weights.shape)

pd.DataFrame(weights, index=list(tokenizer.index_word.values())).head()
# Out:
# (1164, 128)
#             0         1         2         3         4         5         6    \
# <OOV>  0.003230  0.029806 -0.036913  0.000364  0.005872  0.042677  0.005550
# một   -0.151497 -0.082381  0.553245 -0.249071 -0.077462  0.091786 -0.611780
# lòng  -0.476478  0.571136  0.576249  0.459336  0.099817 -0.305948 -0.092679
# người -0.005049 -0.313319  0.391138  0.428091 -0.326943  0.193533 -0.207483
# rằng   0.379343 -0.209849  0.606102 -0.200337 -0.416056  0.117830  0.028680
#
#             7         8         9    ...       118       119       120  \
# <OOV> -0.030372 -0.016401 -0.019105  ...  0.045576 -0.005967  0.012212
# một   -0.764466 -0.679431  0.402287  ...  0.417555  0.065829 -0.464943
# lòng  -0.054355  0.528509 -0.053340  ...  0.096631  0.522503  0.059526
# người -0.374916  0.587723 -0.799213  ... -0.341847  0.234027 -0.255211
# rằng   0.275391  0.627618  0.864311  ...  0.255991 -0.192569 -0.360405
#
#             121       122       123       124       125       126       127
# <OOV> -0.033329 -0.000055  0.017794  0.003747  0.021508 -0.025478  0.000018
# một   -0.195937 -0.480294  0.083139 -0.631046 -0.125750  0.891854  0.285462
# lòng   0.281494  0.751450  0.309532 -0.071502 -0.807272 -0.442282  0.532161
# người -0.036164 -0.116566  0.208139  0.614110  0.066376 -0.775032  0.387547
# rằng   0.588564 -0.317897  0.716519 -1.120867 -0.170527  0.164192 -0.254950
#
# [5 rows x 128 columns]
